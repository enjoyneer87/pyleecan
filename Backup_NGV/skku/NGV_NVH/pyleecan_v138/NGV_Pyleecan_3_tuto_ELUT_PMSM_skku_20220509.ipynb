# %% [markdown]
# # Version information

# %%
from datetime import date
print("Running date:", date.today().strftime("%B %d, %Y"))
import pyleecan
print("Pyleecan version:" + pyleecan.__version__)
import SciDataTool
print("SciDataTool version:" + SciDataTool.__version__)
# Out:
# Running date: June 10, 2022
# Pyleecan version:1.3.8
# SciDataTool version:2.3.10

# %%
from os.path import join
import numpy as np


from SciDataTool.Functions.Plot.plot_2D import plot_2D
from SciDataTool.Functions.Plot.plot_3D import plot_3D
from pyleecan.Functions.Plot import dict_2D, dict_3D

from pyleecan.Classes.OPdq import OPdq
from pyleecan.Classes.Simu1 import Simu1
from pyleecan.Classes.InputCurrent import InputCurrent
from pyleecan.Classes.VarLoadCurrent import VarLoadCurrent
from pyleecan.Classes.MagFEMM import MagFEMM
from pyleecan.Classes.PostLUT import PostLUT
from pyleecan.Classes.Electrical import Electrical
from pyleecan.Classes.EEC_PMSM import EEC_PMSM
from pyleecan.Functions.load import load
from pyleecan.Functions.Plot import dict_2D
from pyleecan.Functions.Electrical.dqh_transformation import (
    get_phase_dir_DataTime,
    n2dqh_DataTime,
)
from pyleecan.definitions import DATA_DIR
from pyleecan.Classes.Simu1 import Simu1
from pyleecan.Classes.ForceMT import ForceMT

# %% [markdown]
# # ELUT 생성

# %%
n_Id=5
n_Iq=5
Toyota_Prius = load(join(DATA_DIR, "Machine", "Toyota_Prius.json"))

# Generate ELUT
name = "tuto_EEC_ELUT_PMSM"
simu = Simu1(name=name, machine=Toyota_Prius)

# Definition of the input
simu.input = InputCurrent(
Nt_tot=8 * 12,
Na_tot=8 * 200,
OP=OPdq(N0=1000, Id_ref=0, Iq_ref=0),
)

# Build OP_matrix with a meshgrid of Id/Iq
Id_min, Id_max = -200, 200
Iq_min, Iq_max = -200, 200
Id, Iq = np.meshgrid(
np.linspace(Id_min, Id_max, n_Id), np.linspace(Iq_min, Iq_max, n_Iq)
)

# %%
OP_matrix = np.zeros((n_Id * n_Iq, 3))
OP_matrix[:, 0] = simu.input.OP.N0
OP_matrix[:, 1] = Id.ravel() #ravel() 다차원 배열 1차원 변환 함수
OP_matrix[:, 2] = Iq.ravel()

# %%
# Set varspeed simulation
simu.var_simu = VarLoadCurrent(
type_OP_matrix=1,
OP_matrix=OP_matrix,
is_keep_all_output=True,
stop_if_error=True,
)
# simu for FEMM comparison
simu.mag = MagFEMM(is_periodicity_a=True, is_periodicity_t=True, nb_worker=16)
simu.force = ForceMT(is_periodicity_a=True, is_periodicity_t=True,is_agsf_transfer=True,max_wavenumber_transfer=96)

simu.var_simu.postproc_list = [PostLUT(is_save_LUT=True)]

out = simu.run()

ELUT = out.simu.var_simu.postproc_list[0].LUT
# Out:
# [03:17:15] Starting running simulation tuto_EEC_ELUT_PMSM (machine=Toyota_Prius)
# [03:17:15] Computing reference simulation for Variable Load
# [03:17:15] Starting Magnetic module
# [03:17:16] Parallelization is set on 16 threads while your computer only has 12.
# [03:17:18] Computing Airgap Flux in FEMM
# [03:17:25] Starting Force module
# [03:17:25] Variable Load Reference Results: N0=1000 [rpm], Id=0 [Arms], Iq=0 [Arms], Tem_av=0.1263 [N.m], Tem_rip_pp=0.1196 [N.m], Tem_rip_norm=0.947 [-], Pem_av=13.23 [W]
# [=                                                 ]   3%
# [03:17:25] Variable Load: Using same FEMM file for all simulations (C:\Users\KDH2018-PC\anaconda3\envs\py38_pcan138_SDT_2310\Lib\site-packages\pyleecan\Results\tuto_EEC_ELUT_PMSM\Femm\Toyota_Prius_model.fem)
# [03:17:25] Running simulation 1/25 with N0=1000 [rpm], Id=-200 [Arms], Iq=-200 [Arms]
# [03:17:25] Starting Magnetic module
# [03:17:25] Parallelization is set on 16 threads while your computer only has 12.
# [03:17:26] Computing Airgap Flux in FEMM
# [03:17:35] Starting Force module
# [03:17:35] Variable Load Results: N0=1000 [rpm], Id=-200 [Arms], Iq=-200 [Arms], Tem_av=-489 [N.m], Tem_rip_pp=97.6 [N.m], Tem_rip_norm=-0.1996 [-], Pem_av=-5.121e+04 [W]
# [===                                               ]   7%
# [03:17:35] Running simulation 2/25 with N0=1000 [rpm], Id=-100 [Arms], Iq=-200 [Arms]
# [03:17:35] Starting Magnetic module
# [03:17:35] Parallelization is set on 16 threads while your computer only has 12.
# [03:17:39] Computing Airgap Flux in FEMM
# [03:17:43] Starting Force module
# [03:17:43] Variable Load Results: N0=1000 [rpm], Id=-100 [Arms], Iq=-200 [Arms], Tem_av=-375.5 [N.m], Tem_rip_pp=32.89 [N.m], Tem_rip_norm=-0.0876 [-], Pem_av=-3.932e+04 [W]
# [=====                                             ]  11%
# [03:17:43] Running simulation 3/25 with N0=1000 [rpm], Id=0 [Arms], Iq=-200 [Arms]
# [03:17:43] Starting Magnetic module
# [03:17:43] Parallelization is set on 16 threads while your computer only has 12.
# [03:17:44] Computing Airgap Flux in FEMM
# [03:17:52] Starting Force module
# [03:17:52] Variable Load Results: N0=1000 [rpm], Id=0 [Arms], Iq=-200 [Arms], Tem_av=-242.1 [N.m], Tem_rip_pp=23.18 [N.m], Tem_rip_norm=-0.09576 [-], Pem_av=-2.535e+04 [W]
# [=======                                           ]  15%
# [03:17:52] Running simulation 4/25 with N0=1000 [rpm], Id=100 [Arms], Iq=-200 [Arms]
# [03:17:52] Starting Magnetic module
# [03:17:52] Parallelization is set on 16 threads while your computer only has 12.
# [03:17:54] Computing Airgap Flux in FEMM
# [03:17:59] Starting Force module
# [03:17:59] Variable Load Results: N0=1000 [rpm], Id=100 [Arms], Iq=-200 [Arms], Tem_av=-118 [N.m], Tem_rip_pp=32.66 [N.m], Tem_rip_norm=-0.2768 [-], Pem_av=-1.235e+04 [W]
# [=========                                         ]  19%
# [03:17:59] Running simulation 5/25 with N0=1000 [rpm], Id=200 [Arms], Iq=-200 [Arms]
# [03:17:59] Starting Magnetic module
# [03:17:59] Parallelization is set on 16 threads while your computer only has 12.
# [03:18:00] Computing Airgap Flux in FEMM
# [03:18:08] Starting Force module
# [03:18:08] Variable Load Results: N0=1000 [rpm], Id=200 [Arms], Iq=-200 [Arms], Tem_av=-34.05 [N.m], Tem_rip_pp=6.012 [N.m], Tem_rip_norm=-0.1766 [-], Pem_av=-3565 [W]
# [===========                                       ]  23%
# [03:18:08] Running simulation 6/25 with N0=1000 [rpm], Id=-200 [Arms], Iq=-100 [Arms]
# [03:18:08] Starting Magnetic module
# [03:18:08] Parallelization is set on 16 threads while your computer only has 12.
# [03:18:10] Computing Airgap Flux in FEMM
# [03:18:16] Starting Force module
# [03:18:16] Variable Load Results: N0=1000 [rpm], Id=-200 [Arms], Iq=-100 [Arms], Tem_av=-399 [N.m], Tem_rip_pp=65.95 [N.m], Tem_rip_norm=-0.1653 [-], Pem_av=-4.178e+04 [W]
# [=============                                     ]  26%
# [03:18:16] Running simulation 7/25 with N0=1000 [rpm], Id=-100 [Arms], Iq=-100 [Arms]
# [03:18:16] Starting Magnetic module
# [03:18:16] Parallelization is set on 16 threads while your computer only has 12.
# [03:18:23] Computing Airgap Flux in FEMM
# [03:18:25] Starting Force module
# [03:18:25] Variable Load Results: N0=1000 [rpm], Id=-100 [Arms], Iq=-100 [Arms], Tem_av=-299.6 [N.m], Tem_rip_pp=49.13 [N.m], Tem_rip_norm=-0.164 [-], Pem_av=-3.138e+04 [W]
# [===============                                   ]  30%
# [03:18:25] Running simulation 8/25 with N0=1000 [rpm], Id=0 [Arms], Iq=-100 [Arms]
# [03:18:25] Starting Magnetic module
# [03:18:25] Parallelization is set on 16 threads while your computer only has 12.
# [03:18:25] Computing Airgap Flux in FEMM
# [03:18:32] Starting Force module
# [03:18:32] Variable Load Results: N0=1000 [rpm], Id=0 [Arms], Iq=-100 [Arms], Tem_av=-149.9 [N.m], Tem_rip_pp=6.024 [N.m], Tem_rip_norm=-0.04019 [-], Pem_av=-1.57e+04 [W]
# [=================                                 ]  34%
# [03:18:32] Running simulation 9/25 with N0=1000 [rpm], Id=100 [Arms], Iq=-100 [Arms]
# [03:18:32] Starting Magnetic module
# [03:18:32] Parallelization is set on 16 threads while your computer only has 12.
# [03:18:34] Computing Airgap Flux in FEMM
# [03:18:41] Starting Force module
# [03:18:41] Variable Load Results: N0=1000 [rpm], Id=100 [Arms], Iq=-100 [Arms], Tem_av=-32.18 [N.m], Tem_rip_pp=5.951 [N.m], Tem_rip_norm=-0.1849 [-], Pem_av=-3370 [W]
# [===================                               ]  38%
# [03:18:41] Running simulation 10/25 with N0=1000 [rpm], Id=200 [Arms], Iq=-100 [Arms]
# [03:18:41] Starting Magnetic module
# [03:18:41] Parallelization is set on 16 threads while your computer only has 12.
# [03:18:43] Computing Airgap Flux in FEMM
# [03:18:48] Starting Force module
# [03:18:48] Variable Load Results: N0=1000 [rpm], Id=200 [Arms], Iq=-100 [Arms], Tem_av=2.877 [N.m], Tem_rip_pp=11.91 [N.m], Tem_rip_norm=4.138 [-], Pem_av=301.3 [W]
# [=====================                             ]  42%
# [03:18:48] Running simulation 11/25 with N0=1000 [rpm], Id=-200 [Arms], Iq=0 [Arms]
# [03:18:48] Starting Magnetic module
# [03:18:48] Parallelization is set on 16 threads while your computer only has 12.
# [03:18:50] Computing Airgap Flux in FEMM
# [03:18:58] Starting Force module
# [03:18:58] Variable Load Results: N0=1000 [rpm], Id=-200 [Arms], Iq=0 [Arms], Tem_av=-0.05139 [N.m], Tem_rip_pp=24.95 [N.m], Tem_rip_norm=-485.5 [-], Pem_av=-5.381 [W]
# [=======================                           ]  46%
# [03:18:58] Running simulation 12/25 with N0=1000 [rpm], Id=-100 [Arms], Iq=0 [Arms]
# [03:18:58] Starting Magnetic module
# [03:18:58] Parallelization is set on 16 threads while your computer only has 12.
# [03:18:58] Computing Airgap Flux in FEMM
# [03:19:05] Starting Force module
# [03:19:05] Variable Load Results: N0=1000 [rpm], Id=-100 [Arms], Iq=0 [Arms], Tem_av=-0.4564 [N.m], Tem_rip_pp=4.755 [N.m], Tem_rip_norm=-10.42 [-], Pem_av=-47.79 [W]
# [=========================                         ]  50%
# [03:19:05] Running simulation 13/25 with N0=1000 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [03:19:05] Simulation matches reference one: Skipping computation
# [03:19:05] Variable Load Results: N0=1000 [rpm], Id=0 [Arms], Iq=0 [Arms], Tem_av=0.1263 [N.m], Tem_rip_pp=0.1196 [N.m], Tem_rip_norm=0.947 [-], Pem_av=13.23 [W]
# [==========================                        ]  53%
# [03:19:05] Running simulation 14/25 with N0=1000 [rpm], Id=100 [Arms], Iq=0 [Arms]
# [03:19:05] Starting Magnetic module
# [03:19:05] Parallelization is set on 16 threads while your computer only has 12.
# [03:19:06] Computing Airgap Flux in FEMM
# [03:19:14] Starting Force module
# [03:19:14] Variable Load Results: N0=1000 [rpm], Id=100 [Arms], Iq=0 [Arms], Tem_av=-0.06572 [N.m], Tem_rip_pp=0.1501 [N.m], Tem_rip_norm=-2.283 [-], Pem_av=-6.882 [W]
# [============================                      ]  57%
# [03:19:14] Running simulation 15/25 with N0=1000 [rpm], Id=200 [Arms], Iq=0 [Arms]
# [03:19:14] Starting Magnetic module
# [03:19:14] Parallelization is set on 16 threads while your computer only has 12.
# [03:19:15] Computing Airgap Flux in FEMM
# [03:19:21] Starting Force module
# [03:19:21] Variable Load Results: N0=1000 [rpm], Id=200 [Arms], Iq=0 [Arms], Tem_av=-0.3039 [N.m], Tem_rip_pp=1.846 [N.m], Tem_rip_norm=-6.072 [-], Pem_av=-31.83 [W]
# [==============================                    ]  61%
# [03:19:21] Running simulation 16/25 with N0=1000 [rpm], Id=-200 [Arms], Iq=100 [Arms]
# [03:19:21] Starting Magnetic module
# [03:19:21] Parallelization is set on 16 threads while your computer only has 12.
# [03:19:24] Computing Airgap Flux in FEMM
# [03:19:27] Starting Force module
# [03:19:27] Variable Load Results: N0=1000 [rpm], Id=-200 [Arms], Iq=100 [Arms], Tem_av=399.3 [N.m], Tem_rip_pp=63.88 [N.m], Tem_rip_norm=0.16 [-], Pem_av=4.181e+04 [W]
# [================================                  ]  65%
# [03:19:27] Running simulation 17/25 with N0=1000 [rpm], Id=-100 [Arms], Iq=100 [Arms]
# [03:19:27] Starting Magnetic module
# [03:19:27] Parallelization is set on 16 threads while your computer only has 12.
# [03:19:29] Computing Airgap Flux in FEMM
# [03:19:33] Starting Force module
# [03:19:33] Variable Load Results: N0=1000 [rpm], Id=-100 [Arms], Iq=100 [Arms], Tem_av=299.9 [N.m], Tem_rip_pp=46.68 [N.m], Tem_rip_norm=0.1556 [-], Pem_av=3.141e+04 [W]
# [==================================                ]  69%
# [03:19:33] Running simulation 18/25 with N0=1000 [rpm], Id=0 [Arms], Iq=100 [Arms]
# [03:19:33] Starting Magnetic module
# [03:19:33] Parallelization is set on 16 threads while your computer only has 12.
# [03:19:33] Computing Airgap Flux in FEMM
# [03:19:38] Starting Force module
# [03:19:38] Variable Load Results: N0=1000 [rpm], Id=0 [Arms], Iq=100 [Arms], Tem_av=150.1 [N.m], Tem_rip_pp=6.278 [N.m], Tem_rip_norm=0.04182 [-], Pem_av=1.572e+04 [W]
# [====================================              ]  73%
# [03:19:38] Running simulation 19/25 with N0=1000 [rpm], Id=100 [Arms], Iq=100 [Arms]
# [03:19:38] Starting Magnetic module
# [03:19:38] Parallelization is set on 16 threads while your computer only has 12.
# [03:19:38] Computing Airgap Flux in FEMM
# [03:19:43] Starting Force module
# [03:19:43] Variable Load Results: N0=1000 [rpm], Id=100 [Arms], Iq=100 [Arms], Tem_av=32.71 [N.m], Tem_rip_pp=6.282 [N.m], Tem_rip_norm=0.1921 [-], Pem_av=3425 [W]
# [======================================            ]  76%
# [03:19:43] Running simulation 20/25 with N0=1000 [rpm], Id=200 [Arms], Iq=100 [Arms]
# [03:19:43] Starting Magnetic module
# [03:19:43] Parallelization is set on 16 threads while your computer only has 12.
# [03:19:46] Computing Airgap Flux in FEMM
# [03:19:48] Starting Force module
# [03:19:48] Variable Load Results: N0=1000 [rpm], Id=200 [Arms], Iq=100 [Arms], Tem_av=-2.76 [N.m], Tem_rip_pp=11.53 [N.m], Tem_rip_norm=-4.177 [-], Pem_av=-289.1 [W]
# [========================================          ]  80%
# [03:19:48] Running simulation 21/25 with N0=1000 [rpm], Id=-200 [Arms], Iq=200 [Arms]
# [03:19:48] Starting Magnetic module
# [03:19:48] Parallelization is set on 16 threads while your computer only has 12.
# [03:19:48] Computing Airgap Flux in FEMM
# [03:19:52] Starting Force module
# [03:19:52] Variable Load Results: N0=1000 [rpm], Id=-200 [Arms], Iq=200 [Arms], Tem_av=489.8 [N.m], Tem_rip_pp=93.72 [N.m], Tem_rip_norm=0.1914 [-], Pem_av=5.129e+04 [W]
# [==========================================        ]  84%
# [03:19:52] Running simulation 22/25 with N0=1000 [rpm], Id=-100 [Arms], Iq=200 [Arms]
# [03:19:52] Starting Magnetic module
# [03:19:52] Parallelization is set on 16 threads while your computer only has 12.
# [03:19:53] Computing Airgap Flux in FEMM
# [03:19:57] Starting Force module
# [03:19:57] Variable Load Results: N0=1000 [rpm], Id=-100 [Arms], Iq=200 [Arms], Tem_av=375.8 [N.m], Tem_rip_pp=30.25 [N.m], Tem_rip_norm=0.08049 [-], Pem_av=3.936e+04 [W]
# [============================================      ]  88%
# [03:19:57] Running simulation 23/25 with N0=1000 [rpm], Id=0 [Arms], Iq=200 [Arms]
# [03:19:57] Starting Magnetic module
# [03:19:57] Parallelization is set on 16 threads while your computer only has 12.
# [03:19:58] Computing Airgap Flux in FEMM
# [03:20:02] Starting Force module
# [03:20:02] Variable Load Results: N0=1000 [rpm], Id=0 [Arms], Iq=200 [Arms], Tem_av=242.2 [N.m], Tem_rip_pp=21.83 [N.m], Tem_rip_norm=0.09016 [-], Pem_av=2.536e+04 [W]
# [==============================================    ]  92%
# [03:20:02] Running simulation 24/25 with N0=1000 [rpm], Id=100 [Arms], Iq=200 [Arms]
# [03:20:02] Starting Magnetic module
# [03:20:02] Parallelization is set on 16 threads while your computer only has 12.
# [03:20:03] Computing Airgap Flux in FEMM
# [03:20:07] Starting Force module
# [03:20:07] Variable Load Results: N0=1000 [rpm], Id=100 [Arms], Iq=200 [Arms], Tem_av=118.7 [N.m], Tem_rip_pp=33.32 [N.m], Tem_rip_norm=0.2806 [-], Pem_av=1.243e+04 [W]
# [================================================  ]  96%
# [03:20:07] Running simulation 25/25 with N0=1000 [rpm], Id=200 [Arms], Iq=200 [Arms]
# [03:20:07] Starting Magnetic module
# [03:20:07] Parallelization is set on 16 threads while your computer only has 12.
# [03:20:07] Computing Airgap Flux in FEMM
# [03:20:12] Starting Force module
# [03:20:12] Variable Load Results: N0=1000 [rpm], Id=200 [Arms], Iq=200 [Arms], Tem_av=34.58 [N.m], Tem_rip_pp=6.823 [N.m], Tem_rip_norm=0.1973 [-], Pem_av=3621 [W]
# [==================================================] 100%
# [03:20:12] Running Variable Load postprocessings...
# [03:20:12] Saving LUT at: C:\Users\KDH2018-PC\anaconda3\envs\py38_pcan138_SDT_2310\Lib\site-packages\pyleecan\Results\tuto_EEC_ELUT_PMSM\LUT.h5
# [03:20:20] End of simulation tuto_EEC_ELUT_PMSM
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\KDH201~1\AppData\Local\Temp/ipykernel_53548/3569076800.py in <module>
#      14 out = simu.run()
#      15
# ---> 16 ELUT = out.simu.var_simu.postproc_list[0].LUT
#
# AttributeError: 'PostLUT' object has no attribute 'LUT'

# %%
OP_list = OP_matrix[:, 1:3].tolist() # tolist list형태로 변환하는 method

ELUT = out.simu.var_simu.postproc_list[0].LUT
#ELUT1=out.simu.var_simu.postproc_list[1].LUT
Phi_dqh_mean = ELUT.get_Phidqh_mean()
Phi_dqh_mean.size
ii = OP_list.index([0, 0])  #[0,0 ]이 있는 위치 반환
print(type(OP_list))


# 무부하에서의 Phi_dqh0
Phi_dqh0 = n2dqh_DataTime(
    ELUT.Phi_wind[ii],
    is_dqh_rms=True,
    phase_dir=ELUT.get_phase_dir(),
)

Phi_dqh0_mean = Phi_dqh0.get_along("time=mean", "phase")[Phi_dqh0.symbol]

Phi_dqh0 = n2dqh_DataTime(
    ELUT.Phi_wind[ii],
    is_dqh_rms=True,
    phase_dir=ELUT.get_phase_dir(),
)


Phi_dqh0.plot_2D_Data(
"time",
"phase[]"
)

# ELUT.Phi_wind[1].plot_2D_Data(
# "time",
# "phase[]"
# )
ELUT.Phi_wind[ii].plot_2D_Data(
"time",
"phase[]"
)
# Out:
# <class 'list'>
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
type(ii)
# Out:
# int

# %%
# Phi_dqh0.plot_2D_Data("time")
for ii in range(12, 24):
    Phi_dqh0 = n2dqh_DataTime(
        ELUT.Phi_wind[ii],
        is_dqh_rms=True,
        phase_dir=ELUT.get_phase_dir(),
    )


    Phi_dqh0.plot_2D_Data(
    "time",
    "phase[]"
    )

    # ELUT.Phi_wind[1].plot_2D_Data(
    # "time",
    # "phase[]"
    # )
    ELUT.Phi_wind[ii].plot_2D_Data(
    "time",
    "phase[]"
    )
# Out:
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\init_fig.py:37: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = subplots(tight_layout=True, figsize=(8, 4))
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
ELUT = out.simu.var_simu.postproc_list[0].LUT
test_ELUT=ELUT

# %% [markdown]
# ## MTPA

# %%
"""Validation of the PMSM Electrical Equivalent Circuit with the Prius machine for MTPA calculation"""

n_Id=51
n_Iq=101
Toyota_Prius = load(join(DATA_DIR, "Machine", "Toyota_Prius.json"))
qs = Toyota_Prius.stator.winding.qs
p = Toyota_Prius.get_pole_pair_number()
Tsta = 20  # stator winding temperature

# %%
name = "test_EEC_ELUT_PMSM_MTPA"
simu_MTPA = Simu1(name=name, machine=Toyota_Prius)

# Definition of the input
OP_ref = OPdq(N0=1000, Id_ref=50, Iq_ref=100)
simu_MTPA.input = InputCurrent(
    Na_tot=1024,
    Nt_tot=1024,
    OP=OP_ref,
)

OP_matrix = test_ELUT.OP_matrix

# Get Id_min, Id_max, Iq_min, Iq_max from OP_matrix
Id_min = np.min(OP_matrix[:, 1])
Id_max = np.max(OP_matrix[:, 1])
Iq_min = np.min(OP_matrix[:, 2])
Iq_max = np.max(OP_matrix[:, 2])

Id, Iq = np.meshgrid(
    np.linspace(Id_min, Id_max, n_Id), np.linspace(Iq_min, Iq_max, n_Iq)
)

Id, Iq = Id.ravel(), Iq.ravel()  #ravel()_numpy 다차원 배열을 1차원 변환
Imax_interp = np.sqrt(Id ** 2 + Iq ** 2)
OP_matrix
# Out:
# array([[1000., -200., -200.,   nan,   nan],
#        [1000., -100., -200.,   nan,   nan],
#        [1000.,    0., -200.,   nan,   nan],
#        [1000.,  100., -200.,   nan,   nan],
#        [1000.,  200., -200.,   nan,   nan],
#        [1000., -200., -100.,   nan,   nan],
#        [1000., -100., -100.,   nan,   nan],
#        [1000.,    0., -100.,   nan,   nan],
#        [1000.,  100., -100.,   nan,   nan],
#        [1000.,  200., -100.,   nan,   nan],
#        [1000., -200.,    0.,   nan,   nan],
#        [1000., -100.,    0.,   nan,   nan],
#        [1000.,    0.,    0.,   nan,   nan],
#        [1000.,  100.,    0.,   nan,   nan],
#        [1000.,  200.,    0.,   nan,   nan],
#        [1000., -200.,  100.,   nan,   nan],
#        [1000., -100.,  100.,   nan,   nan],
#        [1000.,    0.,  100.,   nan,   nan],
#        [1000.,  100.,  100.,   nan,   nan],
#        [1000.,  200.,  100.,   nan,   nan],
#        [1000., -200.,  200.,   nan,   nan],
#        [1000., -100.,  200.,   nan,   nan],
#        [1000.,    0.,  200.,   nan,   nan],
#        [1000.,  100.,  200.,   nan,   nan],
#        [1000.,  200.,  200.,   nan,   nan]])

# %%
# Electrical 모듈 

elec_model = Electrical(eec=EEC_PMSM(LUT_enforced=test_ELUT), Tsta=Tsta, Tmag=20, Trot=20)
elec_model_2 =Electrical(eec=EEC_PMSM(LUT_enforced=test_ELUT), Tsta=Tsta, Tmag=20, Trot=20)

# Interpolate stator winding flux in dqh frame for all Id/Iq
elec_model.eec.comp_parameters(
    machine=Toyota_Prius, OP=OP_ref, Tsta=elec_model.Tsta, Id_array=Id, Iq_array=Iq
)

#아직 stator권선의 온도영향도만 반영되어있음
elec_model_2.eec.comp_parameters(
    machine=Toyota_Prius, OP=OP_ref, Tsta=elec_model.Tsta, Trot=elec_model_2, Id_array=Id, Iq_array=Iq
)

# Compute torque
Tem_sync, Tem_rel = elec_model.eec.comp_torque_sync_rel(qs, p)
Tem_interp = Tem_sync + Tem_rel

Tem_sync2, Tem_rel2 = elec_model_2.eec.comp_torque_sync_rel(qs, p)
Tem_interp2 = Tem_sync2 + Tem_rel2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KDH201~1\AppData\Local\Temp/ipykernel_36524/2593132383.py in <module>
#       1 # Electrical 모듈
#       2
# ----> 3 elec_model = Electrical(eec=EEC_PMSM(LUT_enforced=test_ELUT), Tsta=Tsta, Tmag=20, Trot=20)
#       4 elec_model_2 =Electrical(eec=EEC_PMSM(LUT_enforced=test_ELUT), Tsta=Tsta, Tmag=20, Trot=20)
#       5
#
# TypeError: __init__() got an unexpected keyword argument 'LUT_enforced'

# %% [markdown]
# ## Plot - dq평면 토크contour, 전압원

# %%
import matplotlib.pyplot as plt


# Init plot map
dict_map = {
    "Xdata": Id.reshape((n_Iq, n_Id))[0, :],
    "Ydata": Iq.reshape((n_Iq, n_Id))[:, 0],
    "xlabel": "d-axis current [Arms]",
    "ylabel": "q-axis current [Arms]",
    "type_plot": "pcolor",
    "is_contour": True,
#     "is_show_fig": is_show_fig,
}
# Plot torque maps
plot_3D(
    Zdata=Tem_interp.reshape((n_Iq, n_Id)).T,
    zlabel="Average Torque [N.m]",
    title="Torque map in dq plane",
   #save_path=join(save_path, name + "_torque_map.png"),
    **dict_map,
)
# plot 전압원 

plt.contour(
    dict_map["Xdata"],
    dict_map["Ydata"],
    U_max_interp.reshape((n_Iq, n_Id)),
    colors="blue",
    linewidths=0.8,
)
# plot_3D(
#     Zdata=Id.reshape((n_Iq, n_Id)).T,
#     zlabel="Average Torque [N.m]",
#     title="Torque map in dq plane",
#     # save_path=join(save_path, name + "_torque_map.png"),
#     **dict_map,
# )
# plot_3D(
#     Zdata=Iq.reshape((n_Iq, n_Id)).T,
#     zlabel="Average Torque [N.m]",
#     title="Torque map in dq plane",
#     # save_path=join(save_path, name + "_torque_map.png"),
# #     **dict_map,
# )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\KDH201~1\AppData\Local\Temp/ipykernel_36524/2057664309.py in <module>
#      14 # Plot torque maps
#      15 plot_3D(
# ---> 16     Zdata=Tem_interp.reshape((n_Iq, n_Id)).T,
#      17     zlabel="Average Torque [N.m]",
#      18     title="Torque map in dq plane",
#
# NameError: name 'Tem_interp' is not defined

# %% [markdown]
# ## 자속맵 (dq평면)

# %%
# Plot Phi_d map
plot_3D(
    Zdata=elec_model.eec.parameters["Phid"].reshape((n_Iq, n_Id)).T,
    zlabel="$\Phi_d$ [Wb]",
    title="Flux linkage map in dq plane (d-axis)",
    #save_path=join(save_path, name + "_phid_map.png"),
    **dict_map,
)

# Plot Phi_q map
plot_3D(
    Zdata=elec_model.eec.parameters["Phiq"].reshape((n_Iq, n_Id)).T,
    zlabel="$\Phi_q$ [Wb]",
    title="Flux linkage map in dq plane (q-axis)",
    #save_path=join(save_path, name + "_phiq_map.png"),
    **dict_map,
)

# plot_3D(
#     Zdata=Tem_sync.reshape((n_Iq, n_Id)).T,
#     zlabel="Synchrnous Torque [N.m]",
#     title="Torque map in dq plane",
#     #save_path=join(save_path, name + "_torque_sync_map.png"),
#     **dict_map,
# )
# plot_3D(
#     Zdata=Tem_rel.reshape((n_Iq, n_Id)).T,
#     zlabel="Reluctant Torque [N.m]",
#     title="Torque map in dq plane",
#     #save_path=join(save_path, name + "_torque_rel_map.png"),
#     **dict_map,
# )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\KDH201~1\AppData\Local\Temp/ipykernel_36524/1395300077.py in <module>
#       1 # Plot Phi_d map
#       2 plot_3D(
# ----> 3     Zdata=elec_model.eec.parameters["Phid"].reshape((n_Iq, n_Id)).T,
#       4     zlabel="$\Phi_d$ [Wb]",
#       5     title="Flux linkage map in dq plane (d-axis)",
#
# NameError: name 'elec_model' is not defined

# %% [markdown]
# ## MTPA 계산을 통한 TN curve 작성

# %%
# Maximum current [Arms]
I_max = 250 / np.sqrt(2)
# Maximum voltage [Vrms]
U_max = 400
# Speed vector
Nspeed = 50
N0_min = 50
N0_max = 8000
N0_vect = np.linspace(N0_min, N0_max, Nspeed)
# Maximum load vector
Ntorque = 1
is_braking = False  # True to include negative torque (braking)

if is_braking:
    Ntorque = (
        2 * Ntorque + 1
    )  # Take twice the number of torques + odd to include zero torque
if not is_braking and Ntorque == 1:
    I_max_vect = np.array([I_max])
elif is_braking:
    I_max_vect = np.linspace(-I_max, I_max, Ntorque)
else:
    I_max_vect = np.linspace(0, I_max, Ntorque)

# Init OP_matrix
OP_matrix_MTPA = np.zeros((Nspeed, Ntorque, 4))
U_MTPA = np.zeros((Nspeed, Ntorque, 3))
I_MTPA = np.zeros((Nspeed, Ntorque, 3))

for ii, N0 in enumerate(N0_vect):

    print("Speed " + str(ii + 1) + "/" + str(Nspeed))

    # Update operating point
    OP_ref.N0 = N0
    OP_ref.felec = None

    # Update stator resistance with skin effect
    elec_model.eec.comp_parameters(
        Toyota_Prius,
        OP=OP_ref,
        Tsta=elec_model.Tsta,
        Trot=elec_model.Trot,
    )

    # Calculate voltage
    out_dict = elec_model.eec.solve()
    U_max_interp = np.sqrt(out_dict["Ud"] ** 2 + out_dict["Uq"] ** 2)
    
# ii는 속도의 인덱스
## kk는 토크 인덱스
# j0는 현재 index
# jmax는 MTPA 토크

    for kk, I_max0 in enumerate(I_max_vect):

        if I_max0 == 0:
            # Finding indices of operating points satisfying Vmax voltage for Iq=0 (no torque production)
            j0 = np.logical_and(U_max_interp <= U_max, np.abs(Iq) == 0)

            # Finding index of operating point giving lowest current
            jmax = np.argmin(np.abs(Imax_interp[j0]))

        else:
            # Finding indices of operating points satisfying Vmax and XImax(i) voltage and torque limitations
            j0 = np.logical_and(
                U_max_interp <= U_max, Imax_interp <= np.abs(I_max0)
            )

            if I_max0 > 0:
                # Finding index of operating point giving maximum positive torque among feasible operating points
                jmax = np.argmax(Tem_interp[j0])
            else:
                # Finding index of operating point giving maximum negative torque among feasible operating points
                jmax = np.argmin(Tem_interp[j0])

        # Store values in MTPA
        OP_matrix_MTPA[ii, kk, 0] = N0
        OP_matrix_MTPA[ii, kk, 1] = Id[j0][jmax]
        OP_matrix_MTPA[ii, kk, 2] = Iq[j0][jmax]
        OP_matrix_MTPA[ii, kk, 3] = Tem_interp[j0][jmax]
        U_MTPA[ii, kk, 0] = out_dict["Ud"][j0][jmax]
        U_MTPA[ii, kk, 1] = out_dict["Uq"][j0][jmax]
        U_MTPA[ii, kk, 2] = U_max_interp[j0][jmax]
        I_MTPA[ii, kk, 0] = OP_matrix_MTPA[ii, kk, 1]
        I_MTPA[ii, kk, 1] = OP_matrix_MTPA[ii, kk, 2]
        I_MTPA[ii, kk, 2] = Imax_interp[j0][jmax]

if Ntorque == 1:
    # Plot torque speed curve for each load level
    y_list = list()
    legend_list = list()
    for i_load in range(Ntorque):
        y_list.append(OP_matrix_MTPA[:, i_load, 3])
        #legend_list.append(
        #    "Load level = " + str(int(round(100 * (i_load) / (Ntorque - 1)))) + " %"
        #)
    plot_2D(
        [OP_matrix_MTPA[:, i_load, 0]],
        y_list,
        xlabel="Speed [rpm]",
        ylabel="Average torque [N.m]",
        legend_list=legend_list,
#         save_path=join(save_path, name + "_MTPA_torque_speed.png"),
#         is_show_fig=is_show_fig,
    )
if Ntorque > 1:
    # Plot torque speed curve for each load level
    y_list = list()
    legend_list = list()
    for i_load in range(Ntorque):
        y_list.append(OP_matrix_MTPA[:, i_load, 3])
        #legend_list.append(
        #    "Load level = " + str(int(round(100 * (i_load) / (Ntorque - 1)))) + " %"
        #)
    plot_2D(
        [OP_matrix_MTPA[:, i_load, 0]],
        y_list,
        xlabel="Speed [rpm]",
        ylabel="Average torque [N.m]",
        legend_list=legend_list,
#         save_path=join(save_path, name + "_MTPA_torque_speed.png"),
#         is_show_fig=is_show_fig,
    )


i_load = -1

plot_2D(
    [OP_matrix_MTPA[:, i_load, 0]],
    [I_MTPA[:, i_load, 0], I_MTPA[:, i_load, 1], I_MTPA[:, i_load, 2]],
    xlabel="Speed [rpm]",
    ylabel="Current [Arms]",
    legend_list=["Id", "Iq", "Imax"],
#     save_path=join(save_path, name + "_current_MTPA_OP" + str(i_load) + ".png"),
#     is_show_fig=is_show_fig,
)

plot_2D(
    [OP_matrix_MTPA[:, i_load, 0]],
    [U_MTPA[:, i_load, 0], U_MTPA[:, i_load, 1], U_MTPA[:, i_load, 2]],
    xlabel="Speed [rpm]",
    ylabel="Voltage [Vrms]",
    legend_list=["Ud", "Uq", "Umax"],
#     save_path=join(save_path, name + "_voltage_MTPA_OP" + str(i_load) + ".png"),
#     is_show_fig=is_show_fig,
)
# Out:
# Speed 1/50
# Speed 2/50
# Speed 3/50
# Speed 4/50
# Speed 5/50
# Speed 6/50
# Speed 7/50
# Speed 8/50
# Speed 9/50
# Speed 10/50
# Speed 11/50
# Speed 12/50
# Speed 13/50
# Speed 14/50
# Speed 15/50
# Speed 16/50
# Speed 17/50
# Speed 18/50
# Speed 19/50
# Speed 20/50
# Speed 21/50
# Speed 22/50
# Speed 23/50
# Speed 24/50
# Speed 25/50
# Speed 26/50
# Speed 27/50
# Speed 28/50
# Speed 29/50
# Speed 30/50
# Speed 31/50
# Speed 32/50
# Speed 33/50
# Speed 34/50
# Speed 35/50
# Speed 36/50
# Speed 37/50
# Speed 38/50
# Speed 39/50
# Speed 40/50
# Speed 41/50
# Speed 42/50
# Speed 43/50
# Speed 44/50
# Speed 45/50
# Speed 46/50
# Speed 47/50
# Speed 48/50
# Speed 49/50
# Speed 50/50
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
