# %% [markdown]
# # Tutorial about using PYLEECAN's loss model

# %% [markdown]
# ### Version information

# %%
import sys
import matplotlib.pyplot as plt
#sys.path.append(r"C:\Users\LAP10\Documents\Loss\pyleecan")
from datetime import date
print("Running date:", date.today().strftime("%B %d, %Y"))
import pyleecan
print(f'Pyleecan version : {pyleecan.__version__}')
import SciDataTool
print(f'SciDataTool version : {SciDataTool.__version__}')
# Out:
# Running date: June 09, 2022
# Pyleecan version : 1.3.8
# SciDataTool version : 2.3.10

# %% [markdown]
# ### 기계 가져오기
#
# 이 튜토리얼에서 사용되는 기계는 Toyota Prius 기계입니다.

# %%
# Load the machine
from os.path import join
from pyleecan.Functions.load import load
from pyleecan.definitions import DATA_DIR

machine = load(join(DATA_DIR, "Machine", "Toyota_Prius.json"))

# %% [markdown]
# ## First loss Simulation
#
# A first loss simulation on one operating point will be carried out in this section.

# %% [markdown]
# ### Definition of the simulation
#
# A simulation is defined using the Pyleecan objects.

# %%
# %matplotlib inline
from pyleecan.Classes.Simu1 import Simu1
from pyleecan.Classes.InputCurrent import InputCurrent
from pyleecan.Classes.OPdq import OPdq
from pyleecan.Classes.MagFEMM import MagFEMM
from pyleecan.Classes.LossFEMM import LossFEMM
from pyleecan.Classes.LossModelSteinmetz import LossModelSteinmetz
from pyleecan.Classes.OutLoss import OutLoss
import numpy as np

from SciDataTool.Functions.Plot.plot_2D import plot_2D 

plt.rcParams['figure.dpi'] = 120

simu = Simu1(name="test_FEMM_Loss_Prius", machine=machine)

Cprox=0

Ic = 230 * np.exp(1j * 140 * np.pi / 180)

simu.input = InputCurrent(
    Nt_tot=40 * 8,
    Na_tot=200 * 8,
    OP=OPdq(N0=1200, Id_ref=Ic.real, Iq_ref=Ic.imag),
    is_periodicity_t=True,
    is_periodicity_a=True,
)

simu.mag = MagFEMM(
    is_periodicity_a=True,
    is_periodicity_t=True,
    nb_worker=4,
    is_get_meshsolution=True,
    is_fast_draw=True,
    is_calc_torque_energy=False,
)

# A loss model is created. is_show_fig is set to True to see the curve-fitting figure, otherwise to False
loss_model = LossModelSteinmetz(is_show_fig=True)
simu.loss = LossFEMM(
    Cp=Cprox,
    is_get_meshsolution=True,
    Tsta=100,
    type_skin_effect=0,
    model_dict={"stator core": loss_model, "rotor core": loss_model},
)

# %% [markdown]
# Once set up, the simulation can simply be run using the *run* method.

# %%
out = simu.run()
# Out:
# [18:54:04] Starting running simulation test_FEMM_Loss_Prius (machine=Toyota_Prius)
# [18:54:04] Starting Magnetic module
# [18:54:05] Solving time steps: 0%
# [18:54:05] Solving time steps: 0%
# [18:54:05] Solving time steps: 0%
# [18:54:05] Solving time steps: 0%
# [18:54:06] Solving time steps: 25%
# [18:54:07] Solving time steps: 25%
# [18:54:07] Solving time steps: 25%
# [18:54:07] Solving time steps: 25%
# [18:54:08] Solving time steps: 50%
# [18:54:09] Solving time steps: 50%
# [18:54:09] Solving time steps: 50%
# [18:54:09] Solving time steps: 50%
# [18:54:10] Solving time steps: 75%
# [18:54:11] Solving time steps: 75%
# [18:54:11] Solving time steps: 75%
# [18:54:11] Solving time steps: 75%
# [18:54:12] Solving time step: 100%
# [18:54:12] Solving time step: 100%
# [18:54:12] Solving time step: 100%
# [18:54:12] Solving time step: 100%
# [18:54:12] Running LossFEMM module
# [18:54:14] End of simulation test_FEMM_Loss_Prius

# %% [markdown]
# Now, the results are stored in the Output object named out. The loss powers can be printed.

# %%
power_dict = {
    "total_power": out.mag.Pem_av,
    "overall_losses": out.loss.get_loss_overall(),
    "stator_loss": out.loss.Pstator,
    "copper_loss": out.loss.Pjoule,
    "rotor_loss": out.loss.Protor,
    "magnet_loss": out.loss.Pmagnet,
    "proximity_loss": out.loss.Pprox,
    "efficiency": out.loss.efficiency
}
print(power_dict)
# Out:
# {'total_power': 54596.16454513997, 'overall_losses': 7818.753785218238, 'stator_loss': 292.64231427566983, 'copper_loss': 7499.124524961877, 'rotor_loss': 14.808162839541831, 'magnet_loss': 12.17878314114945, 'proximity_loss': 0, 'efficiency': 0.8567893211847563}

# %% [markdown]
# ### Plotting the distribution of the losses in the machine
#
# The meshsolution is stored in the output of the ismulation, allowing to plot the machine with the loss values in each elements.

# %%
out.loss.meshsol_list[0].plot_contour(
    "freqs=sum",
    label="Loss",
    group_names=[
        "stator core",
        # "stator winding",
        "rotor core",
        "rotor magnets",
    ],
    # clim=[2e4, 2e7],
)
# Out:
# WARNING:root:VTK requires 3D points, but 2D points given. Appending 0 third component.

# %% [markdown]
# ## Plotting loss with respect to the rotation speed
#
# The lossFEMM object stores coefficients computed from the first simu. These coefficients allow to plot the losses with respect to the rotation speed of the machine without carrying other simulations.

# %%
speed_array = np.linspace(10, 8000, 100)
p = machine.get_pole_pair_number()
outloss_list = list()
OP = out.elec.OP.copy()
for speed in speed_array:
    OP.felec = speed / 60 * p
    out_dict = {"coeff_dict": out.loss.coeff_dict}
    outloss = OutLoss()
    outloss.store(out_dict, lam=machine.stator, OP=OP, type_skin_effect=0, Tsta=120, Pem=out.mag.Pem_av)
    outloss_list.append(outloss)

joule_list = [o.Pjoule for o in outloss_list]
sc_list = [o.Pstator for o in outloss_list]
rc_list = [o.Protor for o in outloss_list]
prox_list = [o.Pprox for o in outloss_list]
mag_list = [o.Pmagnet for o in outloss_list]
ovl_list = [o.get_loss_overall() for o in outloss_list]
eff_list = [o.efficiency for o in outloss_list]

plot_2D(
[speed_array],
[ovl_list, joule_list, sc_list, rc_list, prox_list, mag_list],
xlabel="Speed [rpm]",
ylabel="Losses [W]",
legend_list=[
    "Overall",
    "Winding Joule",
    "Stator core",
    "Rotor core",
    "Winding proximity",
    "Magnets",
])
# Out:
# C:\Users\KDH2018-PC\anaconda3\envs\py38_pcan138_SDT_2310\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:482: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Efficiency map of the machine
#
# The efficiency map of the machine can be constructed by going through several steps.
#
# ### Defining a Look up table (LUT)
#
# A look up table is first needed to allow faster computation  during all the simulations. This LUT stores several quantities with respect to the currents $I_d$ and $I_q$.
#
# The LUT can be stored so it is not calculated each time the scipt is run. If this is the first time and the LUT does not exists, it is set to None and will be computed before running other simulations.

# %%
from os.path import exists, split

path_to_LUT = r"Z:\01_Codes_Projects\git_pyleecan_public\pyleecan\Tutorials\LUT.h5"

if not exists(split(path_to_LUT)[0]):
    raise Exception("The path to LUT is not valid.")
try:
    LUT_enforced = load(path_to_LUT)
    is_LUT_exists = True
except FileNotFoundError:
    print("The LUT could not be loaded, so it will be computed.")
    LUT_enforced = None
    is_LUT_exists = False
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\KDH201~1\AppData\Local\Temp/ipykernel_13136/3521834776.py in <module>
#       6     raise Exception("The path to LUT is not valid.")
#       7 try:
# ----> 8     LUT_enforced = load(path_to_LUT)
#       9     is_LUT_exists = True
#      10 except FileNotFoundError:
#
# NameError: name 'load' is not defined

# %% [markdown]
# The next step is to define Simulation containing a *var_simu* attribute with a *VarLoadCurrent*. The *VarLoadCurrent* object needs an *OP_matrix* to define several operating points to carry out multiple simulations. The *OP_matrix* is a matrix with 3 columns representing the following quantities :
# 1. Rotation speed
# 2. $I_d$
# 3. $I_q$

# %%
from pyleecan.Classes.VarLoadCurrent import VarLoadCurrent

simu = Simu1(name="test_ElecLUTdq_efficiency_map", machine=machine)

Nspeed = 50

OP_matrix = np.zeros((Nspeed, 3))
OP_matrix[:, 0] = np.linspace(500, 8000, Nspeed)
simu.var_simu = VarLoadCurrent(
    OP_matrix=OP_matrix, type_OP_matrix=1, is_keep_all_output=True
)

simu.input = InputCurrent(
    OP=OPdq(),
    Nt_tot=4 * 8,
    Na_tot=200 * 8,
    is_periodicity_a=True,
    is_periodicity_t=True,
)
simu.input.set_OP_from_array(OP_matrix, type_OP_matrix=1)

# %% [markdown]
# The electrical module of the simulation needs to be an ElecLUTdq object to take into account the LUT previously defined.

# %%
from pyleecan.Classes.ElecLUTdq import ElecLUTdq
from pyleecan.Classes.PostLUT import PostLUT

# Definition of a loss model
loss_model = LossModelSteinmetz()

simu.elec = ElecLUTdq(
    Urms_max=400,
    Jrms_max=30e6,
    n_interp=100,
    n_Id=5,
    n_Iq=5,
    Id_max=0,
    Iq_min=0,
    LUT_enforced=LUT_enforced,
    is_grid_dq=True,
    LUT_simu=Simu1(
        input=InputCurrent(
            OP=OPdq(),
            Nt_tot=4 * 8,
            Na_tot=200 * 8,
            is_periodicity_a=True,
            is_periodicity_t=True,
        ),
        var_simu=VarLoadCurrent(
            type_OP_matrix=1,
            postproc_list=[PostLUT(is_save_LUT=False)],
            is_keep_all_output=True,
        ),
        mag=MagFEMM(
            is_periodicity_a=True,
            is_periodicity_t=True,
            nb_worker=4,
            is_get_meshsolution=True,
        ),
        loss=LossFEMM(
            Cp=1,
            is_get_meshsolution=True,
            Tsta=100,
            type_skin_effect=1,
            model_dict={"stator core": loss_model, "rotor core": loss_model},
        )
    ),
)

# %% [markdown]
# Now comes the core of the algorithms. For several values of load rates (defining the required torque), a simlation will be run for every values of speed in the *OP_matrix*. The simulations will be very fast as the magnetic and loss quantities are interpolated from the LUT previously computed.

# %%
# Nload simulations will be carried out with load values between 0.1 and 1
Nload = 3
load_vect = np.linspace(0.1, 1, Nload)

# Several matrixes that will contain relevant data for post_processing are created
OP_matrix_MTPA = np.zeros((Nspeed, Nload, 5))
U_MTPA = np.zeros((Nspeed, Nload, 3))
I_MTPA = np.zeros((Nspeed, Nload, 3))
Phidq_MTPA = np.zeros((Nspeed, Nload, 2))

# An output list is created to contain the Nload outputs that will be computed
out_load = list()

for ii, load_rate in enumerate(load_vect):
    # Re using the LUT computed during the first step
    if ii > 0 and LUT_enforced is None:
        simu.elec.LUT_enforced = out.output_list[0].simu.elec.LUT_enforced

    simu.elec.load_rate = load_rate

    out = simu.run()

    # Store values in MTPA, the five columns of the OP_matrix_MTPA will be filled
    # First column is rotational speed
    OP_matrix_MTPA[:, ii, 0] = out["N0"].result
    # Second columns is Id
    OP_matrix_MTPA[:, ii, 1] = out["Id"].result
    # Third column is Iq
    OP_matrix_MTPA[:, ii, 2] = out["Iq"].result
    # Fourth column is the average torque
    OP_matrix_MTPA[:, ii, 3] = [out_ii.elec.Tem_av for out_ii in out.output_list]
    # Fifth column is the efficiency
    OP_matrix_MTPA[:, ii, 4] = [out_ii.elec.OP.efficiency for out_ii in out.output_list]
    
    # Store the voltages and currents in two dedicated matrixes
    # First column is Ud
    U_MTPA[:, ii, 0] = [out_ii.elec.OP.Ud_ref for out_ii in out.output_list]
    # Second column is Uq
    U_MTPA[:, ii, 1] = [out_ii.elec.OP.Uq_ref for out_ii in out.output_list]
    # Third column is U0
    U_MTPA[:, ii, 2] = [
        out_ii.elec.OP.get_U0_UPhi0()["U0"] for out_ii in out.output_list
    ]
    # First column is Id
    I_MTPA[:, ii, 0] = OP_matrix_MTPA[:, ii, 1]
    # Second column is Iq
    I_MTPA[:, ii, 1] = OP_matrix_MTPA[:, ii, 2]
    # Third column is I0
    I_MTPA[:, ii, 2] = [
        out_ii.elec.OP.get_I0_Phi0()["I0"] for out_ii in out.output_list
    ]
    # The fluxes are also stored in their dedicated matrix
    # First column is phid
    Phidq_MTPA[:, ii, 0] = [out_ii.elec.eec.Phid for out_ii in out.output_list]
    # second column is phiq
    Phidq_MTPA[:, ii, 1] = [out_ii.elec.eec.Phiq for out_ii in out.output_list]
    # The output of the current simulation is appended to the list of outputs
    out_load.append(out)
# Out:
# [18:54:58] Starting running simulation test_ElecLUTdq_efficiency_map (machine=Toyota_Prius)
# [18:54:58] Computing reference simulation for Variable Load
# [18:54:58] Starting Electrical module
# [18:54:58] Starting running simulation (machine=Toyota_Prius)
# [18:54:58] Computing reference simulation for Variable Load
# [18:54:58] Starting Magnetic module
# [18:54:59] Computing Airgap Flux in FEMM
# [18:55:01] Running LossFEMM module
# [18:55:01] Variable Load Reference Results: N0=500 [rpm], Id=-254.8 [Arms], Iq=0 [Arms], Tem_av=-0.3026 [N.m], Tem_rip_pp=25.87 [N.m], Tem_rip_norm=-85.48 [-], Pem_av=-15.85 [W]
# [=                                                 ]   3%
# [18:55:02] Variable Load: Using same FEMM file for all simulations (C:\Users\KDH2018-PC\anaconda3\envs\py38_pcan138_SDT_2310\Lib\site-packages\pyleecan\Results\Femm\Toyota_Prius_model.fem)
# [18:55:02] Running simulation 1/25 with N0=500 [rpm], Id=-254.8 [Arms], Iq=0 [Arms]
# [18:55:02] Simulation matches reference one: Skipping computation
# [18:55:02] Variable Load Results: N0=500 [rpm], Id=-254.8 [Arms], Iq=0 [Arms], Tem_av=-0.3026 [N.m], Tem_rip_pp=25.87 [N.m], Tem_rip_norm=-85.48 [-], Pem_av=-15.85 [W]
# [===                                               ]   7%
# [18:55:02] Running simulation 2/25 with N0=500 [rpm], Id=-191.1 [Arms], Iq=0 [Arms]
# [18:55:02] Starting Magnetic module
# [18:55:02] Computing Airgap Flux in FEMM
# [18:55:04] Running LossFEMM module
# [18:55:04] Variable Load Results: N0=500 [rpm], Id=-191.1 [Arms], Iq=0 [Arms], Tem_av=-0.6589 [N.m], Tem_rip_pp=23.42 [N.m], Tem_rip_norm=-35.55 [-], Pem_av=-34.5 [W]
# [=====                                             ]  11%
# [18:55:04] Running simulation 3/25 with N0=500 [rpm], Id=-127.4 [Arms], Iq=0 [Arms]
# [18:55:04] Starting Magnetic module
# [18:55:05] Computing Airgap Flux in FEMM
# [18:55:06] Running LossFEMM module
# [18:55:07] Variable Load Results: N0=500 [rpm], Id=-127.4 [Arms], Iq=0 [Arms], Tem_av=-0.7567 [N.m], Tem_rip_pp=9.877 [N.m], Tem_rip_norm=-13.05 [-], Pem_av=-39.62 [W]
# [=======                                           ]  15%
# [18:55:07] Running simulation 4/25 with N0=500 [rpm], Id=-63.69 [Arms], Iq=0 [Arms]
# [18:55:07] Starting Magnetic module
# [18:55:07] Computing Airgap Flux in FEMM
# [18:55:09] Running LossFEMM module
# [18:55:10] Variable Load Results: N0=500 [rpm], Id=-63.69 [Arms], Iq=0 [Arms], Tem_av=-0.1679 [N.m], Tem_rip_pp=1.586 [N.m], Tem_rip_norm=-9.442 [-], Pem_av=-8.793 [W]
# [=========                                         ]  19%
# [18:55:10] Running simulation 5/25 with N0=500 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:55:10] Starting Magnetic module
# [18:55:10] Computing Airgap Flux in FEMM
# [18:55:12] Running LossFEMM module
# [18:55:12] Variable Load Results: N0=500 [rpm], Id=0 [Arms], Iq=0 [Arms], Tem_av=0.1252 [N.m], Tem_rip_pp=0.1122 [N.m], Tem_rip_norm=0.8964 [-], Pem_av=6.555 [W]
# [===========                                       ]  23%
# [18:55:12] Running simulation 6/25 with N0=500 [rpm], Id=-254.8 [Arms], Iq=63.69 [Arms]
# [18:55:13] Starting Magnetic module
# [18:55:13] Computing Airgap Flux in FEMM
# [18:55:15] Running LossFEMM module
# [18:55:15] Variable Load Results: N0=500 [rpm], Id=-254.8 [Arms], Iq=63.69 [Arms], Tem_av=300.8 [N.m], Tem_rip_pp=30.52 [N.m], Tem_rip_norm=0.1014 [-], Pem_av=1.575e+04 [W]
# [=============                                     ]  26%
# [18:55:15] Running simulation 7/25 with N0=500 [rpm], Id=-191.1 [Arms], Iq=63.69 [Arms]
# [18:55:15] Starting Magnetic module
# [18:55:15] Computing Airgap Flux in FEMM
# [18:55:17] Running LossFEMM module
# [18:55:18] Variable Load Results: N0=500 [rpm], Id=-191.1 [Arms], Iq=63.69 [Arms], Tem_av=298.3 [N.m], Tem_rip_pp=31.95 [N.m], Tem_rip_norm=0.1071 [-], Pem_av=1.562e+04 [W]
# [===============                                   ]  30%
# [18:55:18] Running simulation 8/25 with N0=500 [rpm], Id=-127.4 [Arms], Iq=63.69 [Arms]
# [18:55:18] Starting Magnetic module
# [18:55:18] Computing Airgap Flux in FEMM
# [18:55:20] Running LossFEMM module
# [18:55:20] Variable Load Results: N0=500 [rpm], Id=-127.4 [Arms], Iq=63.69 [Arms], Tem_av=264.7 [N.m], Tem_rip_pp=44.06 [N.m], Tem_rip_norm=0.1665 [-], Pem_av=1.386e+04 [W]
# [=================                                 ]  34%
# [18:55:20] Running simulation 9/25 with N0=500 [rpm], Id=-63.69 [Arms], Iq=63.69 [Arms]
# [18:55:20] Starting Magnetic module
# [18:55:20] Computing Airgap Flux in FEMM
# [18:55:22] Running LossFEMM module
# [18:55:23] Variable Load Results: N0=500 [rpm], Id=-63.69 [Arms], Iq=63.69 [Arms], Tem_av=193.9 [N.m], Tem_rip_pp=26 [N.m], Tem_rip_norm=0.1341 [-], Pem_av=1.015e+04 [W]
# [===================                               ]  38%
# [18:55:23] Running simulation 10/25 with N0=500 [rpm], Id=0 [Arms], Iq=63.69 [Arms]
# [18:55:23] Starting Magnetic module
# [18:55:23] Computing Airgap Flux in FEMM
# [18:55:25] Running LossFEMM module
# [18:55:25] Variable Load Results: N0=500 [rpm], Id=0 [Arms], Iq=63.69 [Arms], Tem_av=104.6 [N.m], Tem_rip_pp=6.268 [N.m], Tem_rip_norm=0.05995 [-], Pem_av=5475 [W]
# [=====================                             ]  42%
# [18:55:25] Running simulation 11/25 with N0=500 [rpm], Id=-254.8 [Arms], Iq=127.4 [Arms]
# [18:55:25] Starting Magnetic module
# [18:55:25] Computing Airgap Flux in FEMM
# [18:55:27] Running LossFEMM module
# [18:55:28] Variable Load Results: N0=500 [rpm], Id=-254.8 [Arms], Iq=127.4 [Arms], Tem_av=459.1 [N.m], Tem_rip_pp=59.98 [N.m], Tem_rip_norm=0.1306 [-], Pem_av=2.404e+04 [W]
# [=======================                           ]  46%
# [18:55:28] Running simulation 12/25 with N0=500 [rpm], Id=-191.1 [Arms], Iq=127.4 [Arms]
# [18:55:28] Starting Magnetic module
# [18:55:28] Computing Airgap Flux in FEMM
# [18:55:30] Running LossFEMM module
# [18:55:30] Variable Load Results: N0=500 [rpm], Id=-191.1 [Arms], Iq=127.4 [Arms], Tem_av=433.4 [N.m], Tem_rip_pp=85.13 [N.m], Tem_rip_norm=0.1964 [-], Pem_av=2.269e+04 [W]
# [=========================                         ]  50%
# [18:55:30] Running simulation 13/25 with N0=500 [rpm], Id=-127.4 [Arms], Iq=127.4 [Arms]
# [18:55:30] Starting Magnetic module
# [18:55:30] Computing Airgap Flux in FEMM
# [18:55:32] Running LossFEMM module
# [18:55:32] Variable Load Results: N0=500 [rpm], Id=-127.4 [Arms], Iq=127.4 [Arms], Tem_av=364.8 [N.m], Tem_rip_pp=61.63 [N.m], Tem_rip_norm=0.1689 [-], Pem_av=1.91e+04 [W]
# [==========================                        ]  53%
# [18:55:32] Running simulation 14/25 with N0=500 [rpm], Id=-63.69 [Arms], Iq=127.4 [Arms]
# [18:55:32] Starting Magnetic module
# [18:55:33] Computing Airgap Flux in FEMM
# [18:55:34] Running LossFEMM module
# [18:55:35] Variable Load Results: N0=500 [rpm], Id=-63.69 [Arms], Iq=127.4 [Arms], Tem_av=273.6 [N.m], Tem_rip_pp=21.68 [N.m], Tem_rip_norm=0.07923 [-], Pem_av=1.433e+04 [W]
# [============================                      ]  57%
# [18:55:35] Running simulation 15/25 with N0=500 [rpm], Id=0 [Arms], Iq=127.4 [Arms]
# [18:55:35] Starting Magnetic module
# [18:55:35] Computing Airgap Flux in FEMM
# [18:55:37] Running LossFEMM module
# [18:55:37] Variable Load Results: N0=500 [rpm], Id=0 [Arms], Iq=127.4 [Arms], Tem_av=178.7 [N.m], Tem_rip_pp=10.93 [N.m], Tem_rip_norm=0.06116 [-], Pem_av=9359 [W]
# [==============================                    ]  61%
# [18:55:37] Running simulation 16/25 with N0=500 [rpm], Id=-254.8 [Arms], Iq=191.1 [Arms]
# [18:55:37] Starting Magnetic module
# [18:55:38] Computing Airgap Flux in FEMM
# [18:55:39] Running LossFEMM module
# [18:55:40] Variable Load Results: N0=500 [rpm], Id=-254.8 [Arms], Iq=191.1 [Arms], Tem_av=523.5 [N.m], Tem_rip_pp=86.99 [N.m], Tem_rip_norm=0.1662 [-], Pem_av=2.741e+04 [W]
# [================================                  ]  65%
# [18:55:40] Running simulation 17/25 with N0=500 [rpm], Id=-191.1 [Arms], Iq=191.1 [Arms]
# [18:55:40] Starting Magnetic module
# [18:55:40] Computing Airgap Flux in FEMM
# [18:55:42] Running LossFEMM module
# [18:55:42] Variable Load Results: N0=500 [rpm], Id=-191.1 [Arms], Iq=191.1 [Arms], Tem_av=477 [N.m], Tem_rip_pp=90.25 [N.m], Tem_rip_norm=0.1892 [-], Pem_av=2.497e+04 [W]
# [==================================                ]  69%
# [18:55:42] Running simulation 18/25 with N0=500 [rpm], Id=-127.4 [Arms], Iq=191.1 [Arms]
# [18:55:42] Starting Magnetic module
# [18:55:43] Computing Airgap Flux in FEMM
# [18:55:44] Running LossFEMM module
# [18:55:45] Variable Load Results: N0=500 [rpm], Id=-127.4 [Arms], Iq=191.1 [Arms], Tem_av=405.8 [N.m], Tem_rip_pp=50 [N.m], Tem_rip_norm=0.1232 [-], Pem_av=2.125e+04 [W]
# [====================================              ]  73%
# [18:55:45] Running simulation 19/25 with N0=500 [rpm], Id=-63.69 [Arms], Iq=191.1 [Arms]
# [18:55:45] Starting Magnetic module
# [18:55:45] Computing Airgap Flux in FEMM
# [18:55:47] Running LossFEMM module
# [18:55:47] Variable Load Results: N0=500 [rpm], Id=-63.69 [Arms], Iq=191.1 [Arms], Tem_av=321.2 [N.m], Tem_rip_pp=23.87 [N.m], Tem_rip_norm=0.07432 [-], Pem_av=1.682e+04 [W]
# [======================================            ]  76%
# [18:55:47] Running simulation 20/25 with N0=500 [rpm], Id=0 [Arms], Iq=191.1 [Arms]
# [18:55:47] Starting Magnetic module
# [18:55:47] Computing Airgap Flux in FEMM
# [18:55:49] Running LossFEMM module
# [18:55:49] Variable Load Results: N0=500 [rpm], Id=0 [Arms], Iq=191.1 [Arms], Tem_av=235.1 [N.m], Tem_rip_pp=19.9 [N.m], Tem_rip_norm=0.08465 [-], Pem_av=1.231e+04 [W]
# [========================================          ]  80%
# [18:55:49] Running simulation 21/25 with N0=500 [rpm], Id=-254.8 [Arms], Iq=254.8 [Arms]
# [18:55:49] Starting Magnetic module
# [18:55:50] Computing Airgap Flux in FEMM
# [18:55:51] Running LossFEMM module
# [18:55:52] Variable Load Results: N0=500 [rpm], Id=-254.8 [Arms], Iq=254.8 [Arms], Tem_av=552.3 [N.m], Tem_rip_pp=92.2 [N.m], Tem_rip_norm=0.1669 [-], Pem_av=2.892e+04 [W]
# [==========================================        ]  84%
# [18:55:52] Running simulation 22/25 with N0=500 [rpm], Id=-191.1 [Arms], Iq=254.8 [Arms]
# [18:55:52] Starting Magnetic module
# [18:55:52] Computing Airgap Flux in FEMM
# [18:55:54] Running LossFEMM module
# [18:55:54] Variable Load Results: N0=500 [rpm], Id=-191.1 [Arms], Iq=254.8 [Arms], Tem_av=502.1 [N.m], Tem_rip_pp=85.74 [N.m], Tem_rip_norm=0.1708 [-], Pem_av=2.629e+04 [W]
# [============================================      ]  88%
# [18:55:54] Running simulation 23/25 with N0=500 [rpm], Id=-127.4 [Arms], Iq=254.8 [Arms]
# [18:55:54] Starting Magnetic module
# [18:55:54] Computing Airgap Flux in FEMM
# [18:55:56] Running LossFEMM module
# [18:55:57] Variable Load Results: N0=500 [rpm], Id=-127.4 [Arms], Iq=254.8 [Arms], Tem_av=434.6 [N.m], Tem_rip_pp=36.11 [N.m], Tem_rip_norm=0.08309 [-], Pem_av=2.276e+04 [W]
# [==============================================    ]  92%
# [18:55:57] Running simulation 24/25 with N0=500 [rpm], Id=-63.69 [Arms], Iq=254.8 [Arms]
# [18:55:57] Starting Magnetic module
# [18:55:57] Computing Airgap Flux in FEMM
# [18:55:59] Running LossFEMM module
# [18:55:59] Variable Load Results: N0=500 [rpm], Id=-63.69 [Arms], Iq=254.8 [Arms], Tem_av=357.1 [N.m], Tem_rip_pp=28.54 [N.m], Tem_rip_norm=0.07993 [-], Pem_av=1.87e+04 [W]
# [================================================  ]  96%
# [18:55:59] Running simulation 25/25 with N0=500 [rpm], Id=0 [Arms], Iq=254.8 [Arms]
# [18:55:59] Starting Magnetic module
# [18:56:00] Computing Airgap Flux in FEMM
# [18:56:01] Running LossFEMM module
# [18:56:02] Variable Load Results: N0=500 [rpm], Id=0 [Arms], Iq=254.8 [Arms], Tem_av=280.8 [N.m], Tem_rip_pp=21.2 [N.m], Tem_rip_norm=0.07551 [-], Pem_av=1.47e+04 [W]
# [==================================================] 100%
# [18:56:02] Running Variable Load postprocessings...
# [18:56:02] End of simulation
# [18:56:02] Variable Load Reference Results: N0=500 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [                                                  ]   1%
# [18:56:02] Variable Load: Using same LUT for all simulations
# [18:56:02] Running simulation 1/50 with N0=500 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:02] Simulation matches reference one: Skipping computation
# [18:56:02] Variable Load Results: N0=500 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [=                                                 ]   3%
# [18:56:02] Running simulation 2/50 with N0=653.061 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:02] Starting Electrical module
# [18:56:02] Variable Load Results: N0=653.1 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [==                                                ]   5%
# [18:56:02] Running simulation 3/50 with N0=806.122 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:02] Starting Electrical module
# [18:56:03] Variable Load Results: N0=806.1 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [===                                               ]   7%
# [18:56:03] Running simulation 4/50 with N0=959.184 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:03] Starting Electrical module
# [18:56:03] Variable Load Results: N0=959.2 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [====                                              ]   9%
# [18:56:03] Running simulation 5/50 with N0=1112.24 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:03] Starting Electrical module
# [18:56:03] Variable Load Results: N0=1112 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [=====                                             ]  11%
# [18:56:03] Running simulation 6/50 with N0=1265.31 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:03] Starting Electrical module
# [18:56:03] Variable Load Results: N0=1265 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [======                                            ]  13%
# [18:56:03] Running simulation 7/50 with N0=1418.37 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:03] Starting Electrical module
# [18:56:03] Variable Load Results: N0=1418 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [=======                                           ]  15%
# [18:56:03] Running simulation 8/50 with N0=1571.43 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:03] Starting Electrical module
# [18:56:03] Variable Load Results: N0=1571 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [========                                          ]  17%
# [18:56:03] Running simulation 9/50 with N0=1724.49 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:03] Starting Electrical module
# [18:56:03] Variable Load Results: N0=1724 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [=========                                         ]  19%
# [18:56:03] Running simulation 10/50 with N0=1877.55 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:03] Starting Electrical module
# [18:56:03] Variable Load Results: N0=1878 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [==========                                        ]  21%
# [18:56:03] Running simulation 11/50 with N0=2030.61 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:03] Starting Electrical module
# [18:56:03] Variable Load Results: N0=2031 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [===========                                       ]  23%
# [18:56:03] Running simulation 12/50 with N0=2183.67 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:03] Starting Electrical module
# [18:56:04] Variable Load Results: N0=2184 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [============                                      ]  25%
# [18:56:04] Running simulation 13/50 with N0=2336.73 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:04] Starting Electrical module
# [18:56:04] Variable Load Results: N0=2337 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [=============                                     ]  27%
# [18:56:04] Running simulation 14/50 with N0=2489.8 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:04] Starting Electrical module
# [18:56:04] Variable Load Results: N0=2490 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [==============                                    ]  29%
# [18:56:04] Running simulation 15/50 with N0=2642.86 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:04] Starting Electrical module
# [18:56:04] Variable Load Results: N0=2643 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [===============                                   ]  31%
# [18:56:04] Running simulation 16/50 with N0=2795.92 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:04] Starting Electrical module
# [18:56:04] Variable Load Results: N0=2796 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [================                                  ]  33%
# [18:56:04] Running simulation 17/50 with N0=2948.98 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:04] Starting Electrical module
# [18:56:04] Variable Load Results: N0=2949 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [=================                                 ]  35%
# [18:56:04] Running simulation 18/50 with N0=3102.04 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:04] Starting Electrical module
# [18:56:04] Variable Load Results: N0=3102 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [==================                                ]  37%
# [18:56:04] Running simulation 19/50 with N0=3255.1 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:04] Starting Electrical module
# [18:56:04] Variable Load Results: N0=3255 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [===================                               ]  39%
# [18:56:04] Running simulation 20/50 with N0=3408.16 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:04] Starting Electrical module
# [18:56:04] Variable Load Results: N0=3408 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [====================                              ]  41%
# [18:56:05] Running simulation 21/50 with N0=3561.22 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:05] Starting Electrical module
# [18:56:05] Variable Load Results: N0=3561 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [=====================                             ]  43%
# [18:56:05] Running simulation 22/50 with N0=3714.29 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:05] Starting Electrical module
# [18:56:05] Variable Load Results: N0=3714 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [======================                            ]  45%
# [18:56:05] Running simulation 23/50 with N0=3867.35 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:05] Starting Electrical module
# [18:56:05] Variable Load Results: N0=3867 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [=======================                           ]  47%
# [18:56:05] Running simulation 24/50 with N0=4020.41 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:05] Starting Electrical module
# [18:56:05] Variable Load Results: N0=4020 [rpm], Id=-2.92e-07 [Arms], Iq=20.8 [Arms]
# [========================                          ]  49%
# [18:56:05] Running simulation 25/50 with N0=4173.47 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:05] Starting Electrical module
# [18:56:05] Variable Load Results: N0=4173 [rpm], Id=-5.199 [Arms], Iq=15.6 [Arms]
# [=========================                         ]  50%
# [18:56:05] Running simulation 26/50 with N0=4326.53 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:05] Starting Electrical module
# [18:56:05] Variable Load Results: N0=4327 [rpm], Id=-1.192e-07 [Arms], Iq=15.6 [Arms]
# [==========================                        ]  52%
# [18:56:05] Running simulation 27/50 with N0=4479.59 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:05] Starting Electrical module
# [18:56:05] Variable Load Results: N0=4480 [rpm], Id=-1.192e-07 [Arms], Iq=15.6 [Arms]
# [===========================                       ]  54%
# [18:56:05] Running simulation 28/50 with N0=4632.65 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:05] Starting Electrical module
# [18:56:05] Variable Load Results: N0=4633 [rpm], Id=-1.192e-07 [Arms], Iq=15.6 [Arms]
# [============================                      ]  56%
# [18:56:05] Running simulation 29/50 with N0=4785.71 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:05] Starting Electrical module
# [18:56:05] Variable Load Results: N0=4786 [rpm], Id=-1.192e-07 [Arms], Iq=15.6 [Arms]
# [=============================                     ]  58%
# [18:56:05] Running simulation 30/50 with N0=4938.78 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:05] Starting Electrical module
# [18:56:06] Variable Load Results: N0=4939 [rpm], Id=-1.192e-07 [Arms], Iq=15.6 [Arms]
# [==============================                    ]  60%
# [18:56:06] Running simulation 31/50 with N0=5091.84 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:06] Starting Electrical module
# [18:56:06] Variable Load Results: N0=5092 [rpm], Id=-10.4 [Arms], Iq=15.6 [Arms]
# [===============================                   ]  62%
# [18:56:06] Running simulation 32/50 with N0=5244.9 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:06] Starting Electrical module
# [18:56:06] Variable Load Results: N0=5245 [rpm], Id=-5.199 [Arms], Iq=10.4 [Arms]
# [================================                  ]  64%
# [18:56:06] Running simulation 33/50 with N0=5397.96 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:06] Starting Electrical module
# [18:56:06] Variable Load Results: N0=5398 [rpm], Id=-1.46e-07 [Arms], Iq=10.4 [Arms]
# [=================================                 ]  66%
# [18:56:06] Running simulation 34/50 with N0=5551.02 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:06] Starting Electrical module
# [18:56:06] Variable Load Results: N0=5551 [rpm], Id=-1.46e-07 [Arms], Iq=10.4 [Arms]
# [==================================                ]  68%
# [18:56:06] Running simulation 35/50 with N0=5704.08 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:06] Starting Electrical module
# [18:56:06] Variable Load Results: N0=5704 [rpm], Id=-1.46e-07 [Arms], Iq=10.4 [Arms]
# [===================================               ]  70%
# [18:56:06] Running simulation 36/50 with N0=5857.14 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:06] Starting Electrical module
# [18:56:06] Variable Load Results: N0=5857 [rpm], Id=-1.46e-07 [Arms], Iq=10.4 [Arms]
# [====================================              ]  72%
# [18:56:06] Running simulation 37/50 with N0=6010.2 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:06] Starting Electrical module
# [18:56:06] Variable Load Results: N0=6010 [rpm], Id=-1.46e-07 [Arms], Iq=10.4 [Arms]
# [=====================================             ]  74%
# [18:56:06] Running simulation 38/50 with N0=6163.27 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:06] Starting Electrical module
# [18:56:06] Variable Load Results: N0=6163 [rpm], Id=-1.46e-07 [Arms], Iq=10.4 [Arms]
# [======================================            ]  76%
# [18:56:06] Running simulation 39/50 with N0=6316.33 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:06] Starting Electrical module
# [18:56:06] Variable Load Results: N0=6316 [rpm], Id=-1.46e-07 [Arms], Iq=10.4 [Arms]
# [=======================================           ]  78%
# [18:56:06] Running simulation 40/50 with N0=6469.39 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:07] Starting Electrical module
# [18:56:07] Variable Load Results: N0=6469 [rpm], Id=-1.264 [Arms], Iq=10.4 [Arms]
# [========================================          ]  80%
# [18:56:07] Running simulation 41/50 with N0=6622.45 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:07] Starting Electrical module
# [18:56:07] Variable Load Results: N0=6622 [rpm], Id=-5.199 [Arms], Iq=10.4 [Arms]
# [=========================================         ]  82%
# [18:56:07] Running simulation 42/50 with N0=6775.51 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:07] Starting Electrical module
# [18:56:07] Variable Load Results: N0=6776 [rpm], Id=-6.122 [Arms], Iq=10.4 [Arms]
# [==========================================        ]  84%
# [18:56:07] Running simulation 43/50 with N0=6928.57 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:07] Starting Electrical module
# [18:56:07] Variable Load Results: N0=6929 [rpm], Id=-7.048 [Arms], Iq=5.199 [Arms]
# [===========================================       ]  86%
# [18:56:07] Running simulation 44/50 with N0=7081.63 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:07] Starting Electrical module
# [18:56:07] Variable Load Results: N0=7082 [rpm], Id=-10.4 [Arms], Iq=5.199 [Arms]
# [============================================      ]  88%
# [18:56:07] Running simulation 45/50 with N0=7234.69 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:07] Starting Electrical module
# [18:56:07] Variable Load Results: N0=7235 [rpm], Id=-11.14 [Arms], Iq=5.199 [Arms]
# [=============================================     ]  90%
# [18:56:07] Running simulation 46/50 with N0=7387.76 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:07] Starting Electrical module
# [18:56:07] Variable Load Results: N0=7388 [rpm], Id=-13.06 [Arms], Iq=5.199 [Arms]
# [==============================================    ]  92%
# [18:56:07] Running simulation 47/50 with N0=7540.82 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:07] Starting Electrical module
# [18:56:07] Variable Load Results: N0=7541 [rpm], Id=-15.6 [Arms], Iq=5.199 [Arms]
# [===============================================   ]  94%
# [18:56:07] Running simulation 48/50 with N0=7693.88 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:07] Starting Electrical module
# [18:56:07] Variable Load Results: N0=7694 [rpm], Id=-16.67 [Arms], Iq=5.199 [Arms]
# [================================================  ]  96%
# [18:56:07] Running simulation 49/50 with N0=7846.94 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:07] Starting Electrical module
# [18:56:08] Variable Load Results: N0=7847 [rpm], Id=-18.37 [Arms], Iq=5.199 [Arms]
# [================================================= ]  98%
# [18:56:08] Running simulation 50/50 with N0=8000 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:08] Starting Electrical module
# [18:56:08] Variable Load Results: N0=8000 [rpm], Id=-20.8 [Arms], Iq=5.199 [Arms]
# [==================================================] 100%
# [18:56:08] End of simulation test_ElecLUTdq_efficiency_map
# [18:56:08] Starting running simulation test_ElecLUTdq_efficiency_map (machine=Toyota_Prius)
# [18:56:08] Computing reference simulation for Variable Load
# [18:56:08] Starting Electrical module
# [18:56:08] Variable Load Reference Results: N0=500 [rpm], Id=-72.79 [Arms], Iq=88.39 [Arms]
# [                                                  ]   1%
# [18:56:08] Variable Load: Using same LUT for all simulations
# [18:56:08] Running simulation 1/50 with N0=500 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:08] Simulation matches reference one: Skipping computation
# [18:56:08] Variable Load Results: N0=500 [rpm], Id=-72.79 [Arms], Iq=88.39 [Arms]
# [=                                                 ]   3%
# [18:56:08] Running simulation 2/50 with N0=653.061 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:08] Starting Electrical module
# [18:56:08] Variable Load Results: N0=653.1 [rpm], Id=-72.79 [Arms], Iq=88.39 [Arms]
# [==                                                ]   5%
# [18:56:08] Running simulation 3/50 with N0=806.122 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:08] Starting Electrical module
# [18:56:08] Variable Load Results: N0=806.1 [rpm], Id=-72.79 [Arms], Iq=88.39 [Arms]
# [===                                               ]   7%
# [18:56:08] Running simulation 4/50 with N0=959.184 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:08] Starting Electrical module
# [18:56:09] Variable Load Results: N0=959.2 [rpm], Id=-72.79 [Arms], Iq=88.39 [Arms]
# [====                                              ]   9%
# [18:56:09] Running simulation 5/50 with N0=1112.24 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:09] Starting Electrical module
# [18:56:09] Variable Load Results: N0=1112 [rpm], Id=-72.79 [Arms], Iq=88.39 [Arms]
# [=====                                             ]  11%
# [18:56:09] Running simulation 6/50 with N0=1265.31 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:09] Starting Electrical module
# [18:56:09] Variable Load Results: N0=1265 [rpm], Id=-72.79 [Arms], Iq=88.39 [Arms]
# [======                                            ]  13%
# [18:56:09] Running simulation 7/50 with N0=1418.37 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:09] Starting Electrical module
# [18:56:09] Variable Load Results: N0=1418 [rpm], Id=-72.79 [Arms], Iq=88.39 [Arms]
# [=======                                           ]  15%
# [18:56:09] Running simulation 8/50 with N0=1571.43 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:09] Starting Electrical module
# [18:56:09] Variable Load Results: N0=1571 [rpm], Id=-72.79 [Arms], Iq=88.39 [Arms]
# [========                                          ]  17%
# [18:56:09] Running simulation 9/50 with N0=1724.49 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:09] Starting Electrical module
# [18:56:09] Variable Load Results: N0=1724 [rpm], Id=-72.79 [Arms], Iq=88.39 [Arms]
# [=========                                         ]  19%
# [18:56:09] Running simulation 10/50 with N0=1877.55 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:09] Starting Electrical module
# [18:56:09] Variable Load Results: N0=1878 [rpm], Id=-72.79 [Arms], Iq=88.39 [Arms]
# [==========                                        ]  21%
# [18:56:09] Running simulation 11/50 with N0=2030.61 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:09] Starting Electrical module
# [18:56:09] Variable Load Results: N0=2031 [rpm], Id=-72.79 [Arms], Iq=88.39 [Arms]
# [===========                                       ]  23%
# [18:56:09] Running simulation 12/50 with N0=2183.67 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:09] Starting Electrical module
# [18:56:09] Variable Load Results: N0=2184 [rpm], Id=-72.79 [Arms], Iq=88.39 [Arms]
# [============                                      ]  25%
# [18:56:09] Running simulation 13/50 with N0=2336.73 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:09] Starting Electrical module
# [18:56:10] Variable Load Results: N0=2337 [rpm], Id=-72.79 [Arms], Iq=88.39 [Arms]
# [=============                                     ]  27%
# [18:56:10] Running simulation 14/50 with N0=2489.8 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:10] Starting Electrical module
# [18:56:10] Variable Load Results: N0=2490 [rpm], Id=-72.79 [Arms], Iq=88.39 [Arms]
# [==============                                    ]  29%
# [18:56:10] Running simulation 15/50 with N0=2642.86 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:10] Starting Electrical module
# [18:56:10] Variable Load Results: N0=2643 [rpm], Id=-72.79 [Arms], Iq=88.39 [Arms]
# [===============                                   ]  31%
# [18:56:10] Running simulation 16/50 with N0=2795.92 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:10] Starting Electrical module
# [18:56:10] Variable Load Results: N0=2796 [rpm], Id=-72.79 [Arms], Iq=88.39 [Arms]
# [================                                  ]  33%
# [18:56:10] Running simulation 17/50 with N0=2948.98 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:10] Starting Electrical module
# [18:56:10] Variable Load Results: N0=2949 [rpm], Id=-72.79 [Arms], Iq=88.39 [Arms]
# [=================                                 ]  35%
# [18:56:10] Running simulation 18/50 with N0=3102.04 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:10] Starting Electrical module
# [18:56:10] Variable Load Results: N0=3102 [rpm], Id=-72.79 [Arms], Iq=88.39 [Arms]
# [==================                                ]  37%
# [18:56:10] Running simulation 19/50 with N0=3255.1 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:10] Starting Electrical module
# [18:56:10] Variable Load Results: N0=3255 [rpm], Id=-72.79 [Arms], Iq=88.39 [Arms]
# [===================                               ]  39%
# [18:56:10] Running simulation 20/50 with N0=3408.16 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:10] Starting Electrical module
# [18:56:10] Variable Load Results: N0=3408 [rpm], Id=-72.79 [Arms], Iq=88.39 [Arms]
# [====================                              ]  41%
# [18:56:10] Running simulation 21/50 with N0=3561.22 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:10] Starting Electrical module
# [18:56:10] Variable Load Results: N0=3561 [rpm], Id=-72.79 [Arms], Iq=88.39 [Arms]
# [=====================                             ]  43%
# [18:56:10] Running simulation 22/50 with N0=3714.29 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:10] Starting Electrical module
# [18:56:11] Variable Load Results: N0=3714 [rpm], Id=-83.19 [Arms], Iq=77.99 [Arms]
# [======================                            ]  45%
# [18:56:11] Running simulation 23/50 with N0=3867.35 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:11] Starting Electrical module
# [18:56:11] Variable Load Results: N0=3867 [rpm], Id=-77.99 [Arms], Iq=77.99 [Arms]
# [=======================                           ]  47%
# [18:56:11] Running simulation 24/50 with N0=4020.41 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:11] Starting Electrical module
# [18:56:11] Variable Load Results: N0=4020 [rpm], Id=-72.79 [Arms], Iq=72.79 [Arms]
# [========================                          ]  49%
# [18:56:11] Running simulation 25/50 with N0=4173.47 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:11] Starting Electrical module
# [18:56:11] Variable Load Results: N0=4173 [rpm], Id=-67.59 [Arms], Iq=67.59 [Arms]
# [=========================                         ]  50%
# [18:56:11] Running simulation 26/50 with N0=4326.53 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:11] Starting Electrical module
# [18:56:11] Variable Load Results: N0=4327 [rpm], Id=-67.59 [Arms], Iq=62.39 [Arms]
# [==========================                        ]  52%
# [18:56:11] Running simulation 27/50 with N0=4479.59 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:11] Starting Electrical module
# [18:56:11] Variable Load Results: N0=4480 [rpm], Id=-62.39 [Arms], Iq=57.19 [Arms]
# [===========================                       ]  54%
# [18:56:11] Running simulation 28/50 with N0=4632.65 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:11] Starting Electrical module
# [18:56:11] Variable Load Results: N0=4633 [rpm], Id=-57.19 [Arms], Iq=57.19 [Arms]
# [============================                      ]  56%
# [18:56:11] Running simulation 29/50 with N0=4785.71 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:11] Starting Electrical module
# [18:56:11] Variable Load Results: N0=4786 [rpm], Id=-67.59 [Arms], Iq=57.19 [Arms]
# [=============================                     ]  58%
# [18:56:11] Running simulation 30/50 with N0=4938.78 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:11] Starting Electrical module
# [18:56:11] Variable Load Results: N0=4939 [rpm], Id=-57.19 [Arms], Iq=51.99 [Arms]
# [==============================                    ]  60%
# [18:56:11] Running simulation 31/50 with N0=5091.84 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:11] Starting Electrical module
# [18:56:11] Variable Load Results: N0=5092 [rpm], Id=-57.19 [Arms], Iq=51.99 [Arms]
# [===============================                   ]  62%
# [18:56:11] Running simulation 32/50 with N0=5244.9 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:11] Starting Electrical module
# [18:56:12] Variable Load Results: N0=5245 [rpm], Id=-62.39 [Arms], Iq=46.79 [Arms]
# [================================                  ]  64%
# [18:56:12] Running simulation 33/50 with N0=5397.96 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:12] Starting Electrical module
# [18:56:12] Variable Load Results: N0=5398 [rpm], Id=-51.99 [Arms], Iq=46.79 [Arms]
# [=================================                 ]  66%
# [18:56:12] Running simulation 34/50 with N0=5551.02 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:12] Starting Electrical module
# [18:56:12] Variable Load Results: N0=5551 [rpm], Id=-57.19 [Arms], Iq=46.79 [Arms]
# [==================================                ]  68%
# [18:56:12] Running simulation 35/50 with N0=5704.08 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:12] Starting Electrical module
# [18:56:12] Variable Load Results: N0=5704 [rpm], Id=-62.39 [Arms], Iq=41.59 [Arms]
# [===================================               ]  70%
# [18:56:12] Running simulation 36/50 with N0=5857.14 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:12] Starting Electrical module
# [18:56:12] Variable Load Results: N0=5857 [rpm], Id=-51.99 [Arms], Iq=41.59 [Arms]
# [====================================              ]  72%
# [18:56:12] Running simulation 37/50 with N0=6010.2 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:12] Starting Electrical module
# [18:56:12] Variable Load Results: N0=6010 [rpm], Id=-51.99 [Arms], Iq=41.59 [Arms]
# [=====================================             ]  74%
# [18:56:12] Running simulation 38/50 with N0=6163.27 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:12] Starting Electrical module
# [18:56:12] Variable Load Results: N0=6163 [rpm], Id=-62.39 [Arms], Iq=41.59 [Arms]
# [======================================            ]  76%
# [18:56:12] Running simulation 39/50 with N0=6316.33 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:12] Starting Electrical module
# [18:56:12] Variable Load Results: N0=6316 [rpm], Id=-51.99 [Arms], Iq=36.4 [Arms]
# [=======================================           ]  78%
# [18:56:12] Running simulation 40/50 with N0=6469.39 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:12] Starting Electrical module
# [18:56:12] Variable Load Results: N0=6469 [rpm], Id=-51.99 [Arms], Iq=36.4 [Arms]
# [========================================          ]  80%
# [18:56:12] Running simulation 41/50 with N0=6622.45 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:12] Starting Electrical module
# [18:56:13] Variable Load Results: N0=6622 [rpm], Id=-51.99 [Arms], Iq=36.4 [Arms]
# [=========================================         ]  82%
# [18:56:13] Running simulation 42/50 with N0=6775.51 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:13] Starting Electrical module
# [18:56:13] Variable Load Results: N0=6776 [rpm], Id=-62.39 [Arms], Iq=36.4 [Arms]
# [==========================================        ]  84%
# [18:56:13] Running simulation 43/50 with N0=6928.57 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:13] Starting Electrical module
# [18:56:13] Variable Load Results: N0=6929 [rpm], Id=-62.39 [Arms], Iq=31.2 [Arms]
# [===========================================       ]  86%
# [18:56:13] Running simulation 44/50 with N0=7081.63 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:13] Starting Electrical module
# [18:56:13] Variable Load Results: N0=7082 [rpm], Id=-51.99 [Arms], Iq=31.2 [Arms]
# [============================================      ]  88%
# [18:56:13] Running simulation 45/50 with N0=7234.69 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:13] Starting Electrical module
# [18:56:13] Variable Load Results: N0=7235 [rpm], Id=-51.99 [Arms], Iq=31.2 [Arms]
# [=============================================     ]  90%
# [18:56:13] Running simulation 46/50 with N0=7387.76 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:13] Starting Electrical module
# [18:56:13] Variable Load Results: N0=7388 [rpm], Id=-57.19 [Arms], Iq=31.2 [Arms]
# [==============================================    ]  92%
# [18:56:13] Running simulation 47/50 with N0=7540.82 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:13] Starting Electrical module
# [18:56:13] Variable Load Results: N0=7541 [rpm], Id=-62.39 [Arms], Iq=31.2 [Arms]
# [===============================================   ]  94%
# [18:56:13] Running simulation 48/50 with N0=7693.88 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:13] Starting Electrical module
# [18:56:13] Variable Load Results: N0=7694 [rpm], Id=-62.39 [Arms], Iq=31.2 [Arms]
# [================================================  ]  96%
# [18:56:13] Running simulation 49/50 with N0=7846.94 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:13] Starting Electrical module
# [18:56:13] Variable Load Results: N0=7847 [rpm], Id=-57.19 [Arms], Iq=26 [Arms]
# [================================================= ]  98%
# [18:56:13] Running simulation 50/50 with N0=8000 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:13] Starting Electrical module
# [18:56:14] Variable Load Results: N0=8000 [rpm], Id=-51.99 [Arms], Iq=26 [Arms]
# [==================================================] 100%
# [18:56:14] End of simulation test_ElecLUTdq_efficiency_map
# [18:56:14] Starting running simulation test_ElecLUTdq_efficiency_map (machine=Toyota_Prius)
# [18:56:14] Computing reference simulation for Variable Load
# [18:56:14] Starting Electrical module
# [18:56:14] Variable Load Reference Results: N0=500 [rpm], Id=-191 [Arms], Iq=168.6 [Arms]
# [                                                  ]   1%
# [18:56:14] Variable Load: Using same LUT for all simulations
# [18:56:14] Running simulation 1/50 with N0=500 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:14] Simulation matches reference one: Skipping computation
# [18:56:14] Variable Load Results: N0=500 [rpm], Id=-191 [Arms], Iq=168.6 [Arms]
# [=                                                 ]   3%
# [18:56:14] Running simulation 2/50 with N0=653.061 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:14] Starting Electrical module
# [18:56:14] Variable Load Results: N0=653.1 [rpm], Id=-191 [Arms], Iq=168.6 [Arms]
# [==                                                ]   5%
# [18:56:14] Running simulation 3/50 with N0=806.122 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:14] Starting Electrical module
# [18:56:14] Variable Load Results: N0=806.1 [rpm], Id=-191 [Arms], Iq=168.6 [Arms]
# [===                                               ]   7%
# [18:56:14] Running simulation 4/50 with N0=959.184 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:14] Starting Electrical module
# [18:56:14] Variable Load Results: N0=959.2 [rpm], Id=-191 [Arms], Iq=168.6 [Arms]
# [====                                              ]   9%
# [18:56:14] Running simulation 5/50 with N0=1112.24 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:14] Starting Electrical module
# [18:56:14] Variable Load Results: N0=1112 [rpm], Id=-191 [Arms], Iq=168.6 [Arms]
# [=====                                             ]  11%
# [18:56:14] Running simulation 6/50 with N0=1265.31 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:14] Starting Electrical module
# [18:56:14] Variable Load Results: N0=1265 [rpm], Id=-191 [Arms], Iq=168.6 [Arms]
# [======                                            ]  13%
# [18:56:14] Running simulation 7/50 with N0=1418.37 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:14] Starting Electrical module
# [18:56:14] Variable Load Results: N0=1418 [rpm], Id=-191 [Arms], Iq=168.6 [Arms]
# [=======                                           ]  15%
# [18:56:14] Running simulation 8/50 with N0=1571.43 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:14] Starting Electrical module
# [18:56:14] Variable Load Results: N0=1571 [rpm], Id=-191 [Arms], Iq=168.6 [Arms]
# [========                                          ]  17%
# [18:56:14] Running simulation 9/50 with N0=1724.49 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:14] Starting Electrical module
# [18:56:14] Variable Load Results: N0=1724 [rpm], Id=-191 [Arms], Iq=168.6 [Arms]
# [=========                                         ]  19%
# [18:56:14] Running simulation 10/50 with N0=1877.55 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:14] Starting Electrical module
# [18:56:14] Variable Load Results: N0=1878 [rpm], Id=-191 [Arms], Iq=168.6 [Arms]
# [==========                                        ]  21%
# [18:56:14] Running simulation 11/50 with N0=2030.61 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:14] Starting Electrical module
# [18:56:14] Variable Load Results: N0=2031 [rpm], Id=-191 [Arms], Iq=168.6 [Arms]
# [===========                                       ]  23%
# [18:56:14] Running simulation 12/50 with N0=2183.67 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:14] Starting Electrical module
# [18:56:14] Variable Load Results: N0=2184 [rpm], Id=-191 [Arms], Iq=168.6 [Arms]
# [============                                      ]  25%
# [18:56:14] Running simulation 13/50 with N0=2336.73 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:14] Starting Electrical module
# [18:56:14] Variable Load Results: N0=2337 [rpm], Id=-191 [Arms], Iq=168.6 [Arms]
# [=============                                     ]  27%
# [18:56:14] Running simulation 14/50 with N0=2489.8 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:14] Starting Electrical module
# [18:56:14] Variable Load Results: N0=2490 [rpm], Id=-191 [Arms], Iq=168.6 [Arms]
# [==============                                    ]  29%
# [18:56:14] Running simulation 15/50 with N0=2642.86 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:14] Starting Electrical module
# [18:56:14] Variable Load Results: N0=2643 [rpm], Id=-191 [Arms], Iq=168.6 [Arms]
# [===============                                   ]  31%
# [18:56:14] Running simulation 16/50 with N0=2795.92 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:14] Starting Electrical module
# [18:56:14] Variable Load Results: N0=2796 [rpm], Id=-191 [Arms], Iq=168.6 [Arms]
# [================                                  ]  33%
# [18:56:14] Running simulation 17/50 with N0=2948.98 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:14] Starting Electrical module
# [18:56:14] Variable Load Results: N0=2949 [rpm], Id=-191 [Arms], Iq=168.6 [Arms]
# [=================                                 ]  35%
# [18:56:14] Running simulation 18/50 with N0=3102.04 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:14] Starting Electrical module
# [18:56:14] Variable Load Results: N0=3102 [rpm], Id=-191 [Arms], Iq=168.6 [Arms]
# [==================                                ]  37%
# [18:56:14] Running simulation 19/50 with N0=3255.1 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:14] Starting Electrical module
# [18:56:14] Variable Load Results: N0=3255 [rpm], Id=-191 [Arms], Iq=168.6 [Arms]
# [===================                               ]  39%
# [18:56:14] Running simulation 20/50 with N0=3408.16 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:14] Starting Electrical module
# [18:56:14] Variable Load Results: N0=3408 [rpm], Id=-191 [Arms], Iq=168.6 [Arms]
# [====================                              ]  41%
# [18:56:14] Running simulation 21/50 with N0=3561.22 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:14] Starting Electrical module
# [18:56:15] Variable Load Results: N0=3561 [rpm], Id=-191 [Arms], Iq=168.6 [Arms]
# [=====================                             ]  43%
# [18:56:15] Running simulation 22/50 with N0=3714.29 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=3714 [rpm], Id=-203.1 [Arms], Iq=153.8 [Arms]
# [======================                            ]  45%
# [18:56:15] Running simulation 23/50 with N0=3867.35 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=3867 [rpm], Id=-220.2 [Arms], Iq=127.2 [Arms]
# [=======================                           ]  47%
# [18:56:15] Running simulation 24/50 with N0=4020.41 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=4020 [rpm], Id=-226.4 [Arms], Iq=116.8 [Arms]
# [========================                          ]  49%
# [18:56:15] Running simulation 25/50 with N0=4173.47 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=4173 [rpm], Id=-223.8 [Arms], Iq=107.5 [Arms]
# [=========================                         ]  50%
# [18:56:15] Running simulation 26/50 with N0=4326.53 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=4327 [rpm], Id=-215 [Arms], Iq=99.52 [Arms]
# [==========================                        ]  52%
# [18:56:15] Running simulation 27/50 with N0=4479.59 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=4480 [rpm], Id=-218.4 [Arms], Iq=90.44 [Arms]
# [===========================                       ]  54%
# [18:56:15] Running simulation 28/50 with N0=4632.65 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=4633 [rpm], Id=-205.3 [Arms], Iq=84.17 [Arms]
# [============================                      ]  56%
# [18:56:15] Running simulation 29/50 with N0=4785.71 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=4786 [rpm], Id=-192.4 [Arms], Iq=77.97 [Arms]
# [=============================                     ]  58%
# [18:56:15] Running simulation 30/50 with N0=4938.78 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=4939 [rpm], Id=-186.5 [Arms], Iq=72.25 [Arms]
# [==============================                    ]  60%
# [18:56:15] Running simulation 31/50 with N0=5091.84 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=5092 [rpm], Id=-181.8 [Arms], Iq=66.83 [Arms]
# [===============================                   ]  62%
# [18:56:15] Running simulation 32/50 with N0=5244.9 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=5245 [rpm], Id=-179.4 [Arms], Iq=62.72 [Arms]
# [================================                  ]  64%
# [18:56:15] Running simulation 33/50 with N0=5397.96 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=5398 [rpm], Id=-199.1 [Arms], Iq=58.18 [Arms]
# [=================================                 ]  66%
# [18:56:15] Running simulation 34/50 with N0=5551.02 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=5551 [rpm], Id=-182 [Arms], Iq=57.98 [Arms]
# [==================================                ]  68%
# [18:56:15] Running simulation 35/50 with N0=5704.08 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=5704 [rpm], Id=-171.1 [Arms], Iq=57.08 [Arms]
# [===================================               ]  70%
# [18:56:15] Running simulation 36/50 with N0=5857.14 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=5857 [rpm], Id=-187.2 [Arms], Iq=52.96 [Arms]
# [====================================              ]  72%
# [18:56:15] Running simulation 37/50 with N0=6010.2 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=6010 [rpm], Id=-172.9 [Arms], Iq=53.2 [Arms]
# [=====================================             ]  74%
# [18:56:15] Running simulation 38/50 with N0=6163.27 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=6163 [rpm], Id=-164.9 [Arms], Iq=52.34 [Arms]
# [======================================            ]  76%
# [18:56:15] Running simulation 39/50 with N0=6316.33 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=6316 [rpm], Id=-182 [Arms], Iq=48.22 [Arms]
# [=======================================           ]  78%
# [18:56:15] Running simulation 40/50 with N0=6469.39 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=6469 [rpm], Id=-172.7 [Arms], Iq=48.2 [Arms]
# [========================================          ]  80%
# [18:56:15] Running simulation 41/50 with N0=6622.45 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=6622 [rpm], Id=-166.4 [Arms], Iq=47.58 [Arms]
# [=========================================         ]  82%
# [18:56:15] Running simulation 42/50 with N0=6775.51 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=6776 [rpm], Id=-157.9 [Arms], Iq=47.14 [Arms]
# [==========================================        ]  84%
# [18:56:15] Running simulation 43/50 with N0=6928.57 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=6929 [rpm], Id=-145.5 [Arms], Iq=46.76 [Arms]
# [===========================================       ]  86%
# [18:56:15] Running simulation 44/50 with N0=7081.63 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=7082 [rpm], Id=-166.4 [Arms], Iq=43.46 [Arms]
# [============================================      ]  88%
# [18:56:15] Running simulation 45/50 with N0=7234.69 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=7235 [rpm], Id=-161.2 [Arms], Iq=42.98 [Arms]
# [=============================================     ]  90%
# [18:56:15] Running simulation 46/50 with N0=7387.76 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=7388 [rpm], Id=-157.1 [Arms], Iq=42.36 [Arms]
# [==============================================    ]  92%
# [18:56:15] Running simulation 47/50 with N0=7540.82 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=7541 [rpm], Id=-151.2 [Arms], Iq=41.93 [Arms]
# [===============================================   ]  94%
# [18:56:15] Running simulation 48/50 with N0=7693.88 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=7694 [rpm], Id=-144.7 [Arms], Iq=41.48 [Arms]
# [================================================  ]  96%
# [18:56:15] Running simulation 49/50 with N0=7846.94 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=7847 [rpm], Id=-161.2 [Arms], Iq=38.46 [Arms]
# [================================================= ]  98%
# [18:56:15] Running simulation 50/50 with N0=8000 [rpm], Id=0 [Arms], Iq=0 [Arms]
# [18:56:15] Starting Electrical module
# [18:56:15] Variable Load Results: N0=8000 [rpm], Id=-156.4 [Arms], Iq=38.23 [Arms]
# [==================================================] 100%
# [18:56:15] End of simulation test_ElecLUTdq_efficiency_map

# %% [markdown]
# At the end, the LUT can be stored if it did not exists and has been computed.

# %%
if not is_LUT_exists:
    simu.elec.LUT_enforced.save(save_path=path_to_LUT)
# Out:
# DEBUG:h5py._conv:Creating converter from 5 to 3

# %% [markdown]
# ## Plots

# %% [markdown]
# We need to import plots functions from SciDataTool.

# %%
from SciDataTool.Functions.Plot.plot_2D import plot_2D
from SciDataTool.Functions.Plot.plot_3D import plot_3D
#Set the resolution of the figure to make them bigger
plt.rcParams['figure.dpi'] = 150

# %% [markdown]
# Now we can simply plot the eficiency map using this code.

# %%
#init plot map for efficiency
dict_eff_map = {
    "Xdata": OP_matrix_MTPA[:, :, 0],  # Rotational speed
    "Ydata": OP_matrix_MTPA[:, :, 3],  # Torque
    "xlabel": "Rotational speed",
    "ylabel": "Torque",
    "type_plot": "pcolormesh",
    "is_contour": True,
}

plot_3D(
    Zdata=OP_matrix_MTPA[:, :, 4],
    zlabel="Efficiency",
    title="Efficiency map in torque, speed plane",
    **dict_eff_map,
)
# Out:
# DEBUG:matplotlib.colorbar:locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x000001238AD4AE50>
# DEBUG:matplotlib.colorbar:Using auto colorbar locator <matplotlib.colorbar._ColorbarAutoLocator object at 0x000001238AD4AE50> on colorbar
# DEBUG:matplotlib.colorbar:Setting pcolormesh

# %% [markdown]
# Also, the losses can be plotted as a function of $I_d$/$I_q$ thanks to the look up table.

# %%
LUT_grid = out.simu.elec.LUT_enforced

# Get Id_min, Id_max, Iq_min, Iq_max from OP_matrix
OP_matrix = LUT_grid.get_OP_matrix()
Id_min = OP_matrix[:, 1].min()
Id_max = OP_matrix[:, 1].max()
Iq_min = OP_matrix[:, 2].min()
Iq_max = OP_matrix[:, 2].max()

nd, nq = 100, 100
Id_vect = np.linspace(Id_min, Id_max, nd)
Iq_vect = np.linspace(Iq_min, Iq_max, nq)
Id, Iq = np.meshgrid(Id_vect, Iq_vect)
Id, Iq = Id.ravel(), Iq.ravel()

# Interpolate Phid/Phiq on the refined mesh

Ploss_dqh = LUT_grid.interp_Ploss_dqh(Id, Iq, N0=3000)
dict_map = {
    "Xdata": Id.reshape((nd, nq))[0, :],
    "Ydata": Iq.reshape((nd, nq))[:, 0],
    "xlabel": "d-axis current [Arms]",
    "ylabel": "q-axis current [Arms]",
    "type_plot": "pcolormesh",
    "is_contour": True,
}
loss_list = ["Joules losses",
            "Stator core losses",
            "Magnet losses",
            "Rotor core losses",
            "Proxmity losses"]
for i, loss in enumerate(loss_list):
    plot_3D(
            Zdata=Ploss_dqh[:, i].reshape((nd, nq)),
            zlabel=f"{loss} [W]",
            **dict_map,
        )
# Out:
# DEBUG:matplotlib.colorbar:locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x0000012389B18DC0>
# DEBUG:matplotlib.colorbar:Using auto colorbar locator <matplotlib.colorbar._ColorbarAutoLocator object at 0x0000012389B18DC0> on colorbar
# DEBUG:matplotlib.colorbar:Setting pcolormesh
# DEBUG:matplotlib.colorbar:locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x00000123801F1970>
# DEBUG:matplotlib.colorbar:Using auto colorbar locator <matplotlib.colorbar._ColorbarAutoLocator object at 0x00000123801F1970> on colorbar
# DEBUG:matplotlib.colorbar:Setting pcolormesh
# DEBUG:matplotlib.colorbar:locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x0000012380430D30>
# DEBUG:matplotlib.colorbar:Using auto colorbar locator <matplotlib.colorbar._ColorbarAutoLocator object at 0x0000012380430D30> on colorbar
# DEBUG:matplotlib.colorbar:Setting pcolormesh
# DEBUG:matplotlib.colorbar:locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x00000123805A74F0>
# DEBUG:matplotlib.colorbar:Using auto colorbar locator <matplotlib.colorbar._ColorbarAutoLocator object at 0x00000123805A74F0> on colorbar
# DEBUG:matplotlib.colorbar:Setting pcolormesh
# DEBUG:matplotlib.colorbar:locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x00000123818C7D30>
# DEBUG:matplotlib.colorbar:Using auto colorbar locator <matplotlib.colorbar._ColorbarAutoLocator object at 0x00000123818C7D30> on colorbar
# DEBUG:matplotlib.colorbar:Setting pcolormesh

# %% [markdown]
# Also, the torque can be plotted as a function of $I_d$/$I_q$.

# %%
# Init plot map
dict_map = {
    "Xdata": I_MTPA[:, :, 0],  # Id
    "Ydata": I_MTPA[:, :, 1],  # Iq
    "xlabel": "d-axis current [Arms]",
    "ylabel": "q-axis current [Arms]",
    "type_plot": "pcolormesh",
    "is_contour": True,
}

# Plot torque maps
plot_3D(
    Zdata=OP_matrix_MTPA[:, :, 3],
    zlabel="Average Torque [N.m]",
    title="Torque map in dq plane",
    **dict_map,
)
# Out:
# DEBUG:matplotlib.colorbar:locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x0000012381A06190>
# DEBUG:matplotlib.colorbar:Using auto colorbar locator <matplotlib.colorbar._ColorbarAutoLocator object at 0x0000012381A06190> on colorbar
# DEBUG:matplotlib.colorbar:Setting pcolormesh
