# %% [markdown]
# # Version information

# %%
from datetime import date
print("Running date:", date.today().strftime("%B %d, %Y"))
import pyleecan
print("Pyleecan version:" + pyleecan.__version__)
import SciDataTool
print("SciDataTool version:" + SciDataTool.__version__)
# Out:
# Running date: April 12, 2022
# Pyleecan version:1.3.7
# SciDataTool version:1.4.24

# %%
from os.path import join
import numpy as np
#from numpy.testing import assert_almost_equal

#import pytest

from SciDataTool.Functions.Plot.plot_2D import plot_2D
from SciDataTool.Functions.Plot.plot_3D import plot_3D
from pyleecan.Functions.Plot import dict_2D, dict_3D

from pyleecan.Classes.OPdq import OPdq
from pyleecan.Classes.Simu1 import Simu1
from pyleecan.Classes.InputCurrent import InputCurrent
from pyleecan.Classes.VarLoadCurrent import VarLoadCurrent
from pyleecan.Classes.MagFEMM import MagFEMM
from pyleecan.Classes.PostLUT import PostLUT
from pyleecan.Classes.Electrical import Electrical
from pyleecan.Classes.EEC_PMSM import EEC_PMSM
from pyleecan.Functions.load import load
from pyleecan.Functions.Plot import dict_2D
from pyleecan.Functions.Electrical.dqh_transformation import (
    get_phase_dir_DataTime,
    n2dqh_DataTime,
)
from pyleecan.definitions import DATA_DIR
from pyleecan.Classes.Simu1 import Simu1
from pyleecan.Classes.ForceMT import ForceMT
#from Tests import save_validation_path as save_path

# %% [markdown]
# # ELUT 생성

# %%
n_Id=5
n_Iq=5
Toyota_Prius = load(join(DATA_DIR, "Machine", "Toyota_Prius.json"))

# Generate ELUT
name = "test_EEC_ELUT_PMSM"
simu = Simu1(name=name, machine=Toyota_Prius)

# Definition of the input
simu.input = InputCurrent(
Nt_tot=8 * 12,
Na_tot=8 * 200,
OP=OPdq(N0=1000, Id_ref=0, Iq_ref=0),
)

# Build OP_matrix with a meshgrid of Id/Iq
Id_min, Id_max = -200, 200
Iq_min, Iq_max = -200, 200
Id, Iq = np.meshgrid(
np.linspace(Id_min, Id_max, n_Id), np.linspace(Iq_min, Iq_max, n_Iq)
)

# %%
OP_matrix = np.zeros((n_Id * n_Iq, 3))
OP_matrix[:, 0] = simu.input.OP.N0
OP_matrix[:, 1] = Id.ravel() #ravel() 다차원 배열 1차원 변환 함수
OP_matrix[:, 2] = Iq.ravel()

# %%
# Set varspeed simulation
simu.var_simu = VarLoadCurrent(
type_OP_matrix=1,
OP_matrix=OP_matrix,
is_keep_all_output=True,
stop_if_error=True,
)
# simu for FEMM comparison
simu.mag = MagFEMM(is_periodicity_a=True, is_periodicity_t=True, nb_worker=16)
simu.force = ForceMT(is_periodicity_a=True, is_periodicity_t=True,is_agsf_transfer=True,max_wavenumber_transfer=96)

simu.var_simu.postproc_list = [PostLUT(is_save_LUT=True)]

out = simu.run()

ELUT = out.simu.var_simu.postproc_list[0].LUT
# Out:
# [20:15:46] Starting running simulation test_EEC_ELUT_PMSM (machine=Toyota_Prius)
# [20:15:46] Reference Operating point is not in OP_matrix, one extra simulation will be computed
# [20:15:46] Computing reference simulation for Variable Load
# [20:15:46] Starting Magnetic module
# [20:15:47] Solving time step 1 / 12 in FEMM
# [20:15:47] Solving time step 4 / 12 in FEMM
# [20:15:47] Solving time step 2 / 12 in FEMM
# [20:15:47] Solving time step 8 / 12 in FEMM
# [20:15:47] Solving time step 3 / 12 in FEMM
# [20:15:47] Solving time step 10 / 12 in FEMM
# [20:15:47] Solving time step 7 / 12 in FEMM
# [20:15:48] Solving time step 12 / 12 in FEMM
# [20:15:48] Solving time step 5 / 12 in FEMM
# [20:15:48] Solving time step 11 / 12 in FEMM
# [20:15:48] Solving time step 9 / 12 in FEMM
# [20:15:49] Solving time step 6 / 12 in FEMM
# [20:15:49] Starting Force module
# [20:15:49] Variable Load Reference Results: N0=1000 [rpm], Id=0 [Arms], Iq=0 [Ar
# [20:16:56] Solving time step 9 / 12 in FEMM
# [20:16:57] Solving time step 6 / 12 in FEMM
# [20:16:57] Solving time step 8 / 12 in FEMM
# [20:16:57] Solving time step 11 / 12 in FEMM
# [20:16:57] Solving time step 12 / 12 in FEMM
# [20:16:58] Solving time step 7 / 12 in FEMM
# [20:16:58] Solving time step 10 / 12 in FEMM
# [20:16:58] Starting Force module
# [20:16:58] Variable Load Results: N0=1000 [rpm], Id=200 [Arms], Iq=200 [Arms], Tem_av=27.1 [N.m], Tem_rip_pp=4.389 [N.m], Tem_rip_norm=0.1619 [-], Pem_av=2838 [W]
# [==================================================] 100%
# [20:16:58] Running Variable Load postprocessings...
# [20:16:59] End of simulation test_EEC_ELUT_PMSM

# %%
OP_list = OP_matrix[:, 1:3].tolist() # tolist list형태로 변환하는 method

ELUT = out.simu.var_simu.postproc_list[0].LUT
#ELUT1=out.simu.var_simu.postproc_list[1].LUT
Phi_dqh_mean = ELUT.get_Phidqh_mean()
Phi_dqh_mean.size
ii = OP_list.index([0, 0])  #[0,0 ]이 있는 위치 반환
print(type(OP_list))


# 무부하에서의 Phi_dqh0
Phi_dqh0 = n2dqh_DataTime(
    ELUT.Phi_wind[ii],
    is_dqh_rms=True,
    phase_dir=ELUT.get_phase_dir(),
)

Phi_dqh0_mean = Phi_dqh0.get_along("time=mean", "phase")[Phi_dqh0.symbol]

Phi_dqh0 = n2dqh_DataTime(
    ELUT.Phi_wind[ii],
    is_dqh_rms=True,
    phase_dir=ELUT.get_phase_dir(),
)


Phi_dqh0.plot_2D_Data(
"time",
"phase[]"
)

# ELUT.Phi_wind[1].plot_2D_Data(
# "time",
# "phase[]"
# )
ELUT.Phi_wind[ii].plot_2D_Data(
"time",
"phase[]"
)
# Out:
# <class 'list'>
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
type(ii)
# Out:
# int

# %%
# Phi_dqh0.plot_2D_Data("time")
for ii in range(12, 24):
    Phi_dqh0 = n2dqh_DataTime(
        ELUT.Phi_wind[ii],
        is_dqh_rms=True,
        phase_dir=ELUT.get_phase_dir(),
    )


    Phi_dqh0.plot_2D_Data(
    "time",
    "phase[]"
    )

    # ELUT.Phi_wind[1].plot_2D_Data(
    # "time",
    # "phase[]"
    # )
    ELUT.Phi_wind[ii].plot_2D_Data(
    "time",
    "phase[]"
    )
# Out:
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\init_fig.py:37: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = subplots(tight_layout=True, figsize=(8, 4))
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Plot - dq평면 토크contour, 전압원

# %%
import matplotlib.pyplot as plt


# Init plot map
dict_map = {
    "Xdata": Id.reshape((n_Iq, n_Id))[0, :],
    "Ydata": Iq.reshape((n_Iq, n_Id))[:, 0],
    "xlabel": "d-axis current [Arms]",
    "ylabel": "q-axis current [Arms]",
    "type_plot": "pcolor",
    "is_contour": True,
#     "is_show_fig": is_show_fig,
}
# Plot torque maps
plot_3D(
    Zdata=Tem_interp.reshape((n_Iq, n_Id)).T,
    zlabel="Average Torque [N.m]",
    title="Torque map in dq plane",
   #save_path=join(save_path, name + "_torque_map.png"),
    **dict_map,
)
# plot 전압원 

plt.contour(
    dict_map["Xdata"],
    dict_map["Ydata"],
    U_max_interp.reshape((n_Iq, n_Id)),
    colors="blue",
    linewidths=0.8,
)
# plot_3D(
#     Zdata=Id.reshape((n_Iq, n_Id)).T,
#     zlabel="Average Torque [N.m]",
#     title="Torque map in dq plane",
#     # save_path=join(save_path, name + "_torque_map.png"),
#     **dict_map,
# )
# plot_3D(
#     Zdata=Iq.reshape((n_Iq, n_Id)).T,
#     zlabel="Average Torque [N.m]",
#     title="Torque map in dq plane",
#     # save_path=join(save_path, name + "_torque_map.png"),
# #     **dict_map,
# )
# Out:
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_3D.py:354: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20032/2057664309.py in <module>
#      25     dict_map["Xdata"],
#      26     dict_map["Ydata"],
# ---> 27     U_max_interp.reshape((n_Iq, n_Id)),
#      28     colors="blue",
#      29     linewidths=0.8,
#
# NameError: name 'U_max_interp' is not defined

# %% [markdown]
# ## 자속맵 (dq평면)

# %%
# Plot Phi_d map
plot_3D(
    Zdata=elec_model.eec.parameters["Phid"].reshape((n_Iq, n_Id)).T,
    zlabel="$\Phi_d$ [Wb]",
    title="Flux linkage map in dq plane (d-axis)",
    #save_path=join(save_path, name + "_phid_map.png"),
    **dict_map,
)


# Plot Phi_q map
plot_3D(
    Zdata=elec_model.eec.parameters["Phiq"].reshape((n_Iq, n_Id)).T,
    zlabel="$\Phi_q$ [Wb]",
    title="Flux linkage map in dq plane (q-axis)",
    #save_path=join(save_path, name + "_phiq_map.png"),
    **dict_map,
)

# plot_3D(
#     Zdata=Tem_sync.reshape((n_Iq, n_Id)).T,
#     zlabel="Synchrnous Torque [N.m]",
#     title="Torque map in dq plane",
#     #save_path=join(save_path, name + "_torque_sync_map.png"),
#     **dict_map,
# )
# plot_3D(
#     Zdata=Tem_rel.reshape((n_Iq, n_Id)).T,
#     zlabel="Reluctant Torque [N.m]",
#     title="Torque map in dq plane",
#     #save_path=join(save_path, name + "_torque_rel_map.png"),
#     **dict_map,
# )

# %% [markdown]
# ## MTPA 계산을 통한 TN curve 작성

# %%
# Maximum current [Arms]
I_max = 250 / np.sqrt(2)
# Maximum voltage [Vrms]
U_max = 400
# Speed vector
Nspeed = 50
N0_min = 50
N0_max = 8000
N0_vect = np.linspace(N0_min, N0_max, Nspeed)
# Maximum load vector
Ntorque = 1
is_braking = False  # True to include negative torque (braking)

if is_braking:
    Ntorque = (
        2 * Ntorque + 1
    )  # Take twice the number of torques + odd to include zero torque
if not is_braking and Ntorque == 1:
    I_max_vect = np.array([I_max])
elif is_braking:
    I_max_vect = np.linspace(-I_max, I_max, Ntorque)
else:
    I_max_vect = np.linspace(0, I_max, Ntorque)

# Init OP_matrix
OP_matrix_MTPA = np.zeros((Nspeed, Ntorque, 4))
U_MTPA = np.zeros((Nspeed, Ntorque, 3))
I_MTPA = np.zeros((Nspeed, Ntorque, 3))

for ii, N0 in enumerate(N0_vect):

    print("Speed " + str(ii + 1) + "/" + str(Nspeed))

    # Update operating point
    OP_ref.N0 = N0
    OP_ref.felec = None

    # Update stator resistance with skin effect
    elec_model.eec.comp_parameters(
        Toyota_Prius,
        OP=OP_ref,
        Tsta=elec_model.Tsta,
        Trot=elec_model.Trot,
    )

    # Calculate voltage
    out_dict = elec_model.eec.solve()
    U_max_interp = np.sqrt(out_dict["Ud"] ** 2 + out_dict["Uq"] ** 2)
    
# ii는 속도의 인덱스
## kk는 토크 인덱스
# j0는 현재 index
# jmax는 MTPA 토크

    for kk, I_max0 in enumerate(I_max_vect):

        if I_max0 == 0:
            # Finding indices of operating points satisfying Vmax voltage for Iq=0 (no torque production)
            j0 = np.logical_and(U_max_interp <= U_max, np.abs(Iq) == 0)

            # Finding index of operating point giving lowest current
            jmax = np.argmin(np.abs(Imax_interp[j0]))

        else:
            # Finding indices of operating points satisfying Vmax and XImax(i) voltage and torque limitations
            j0 = np.logical_and(
                U_max_interp <= U_max, Imax_interp <= np.abs(I_max0)
            )

            if I_max0 > 0:
                # Finding index of operating point giving maximum positive torque among feasible operating points
                jmax = np.argmax(Tem_interp[j0])
            else:
                # Finding index of operating point giving maximum negative torque among feasible operating points
                jmax = np.argmin(Tem_interp[j0])

        # Store values in MTPA
        OP_matrix_MTPA[ii, kk, 0] = N0
        OP_matrix_MTPA[ii, kk, 1] = Id[j0][jmax]
        OP_matrix_MTPA[ii, kk, 2] = Iq[j0][jmax]
        OP_matrix_MTPA[ii, kk, 3] = Tem_interp[j0][jmax]
        U_MTPA[ii, kk, 0] = out_dict["Ud"][j0][jmax]
        U_MTPA[ii, kk, 1] = out_dict["Uq"][j0][jmax]
        U_MTPA[ii, kk, 2] = U_max_interp[j0][jmax]
        I_MTPA[ii, kk, 0] = OP_matrix_MTPA[ii, kk, 1]
        I_MTPA[ii, kk, 1] = OP_matrix_MTPA[ii, kk, 2]
        I_MTPA[ii, kk, 2] = Imax_interp[j0][jmax]

if Ntorque == 1:
    # Plot torque speed curve for each load level
    y_list = list()
    legend_list = list()
    for i_load in range(Ntorque):
        y_list.append(OP_matrix_MTPA[:, i_load, 3])
        #legend_list.append(
        #    "Load level = " + str(int(round(100 * (i_load) / (Ntorque - 1)))) + " %"
        #)
    plot_2D(
        [OP_matrix_MTPA[:, i_load, 0]],
        y_list,
        xlabel="Speed [rpm]",
        ylabel="Average torque [N.m]",
        legend_list=legend_list,
#         save_path=join(save_path, name + "_MTPA_torque_speed.png"),
#         is_show_fig=is_show_fig,
    )
if Ntorque > 1:
    # Plot torque speed curve for each load level
    y_list = list()
    legend_list = list()
    for i_load in range(Ntorque):
        y_list.append(OP_matrix_MTPA[:, i_load, 3])
        #legend_list.append(
        #    "Load level = " + str(int(round(100 * (i_load) / (Ntorque - 1)))) + " %"
        #)
    plot_2D(
        [OP_matrix_MTPA[:, i_load, 0]],
        y_list,
        xlabel="Speed [rpm]",
        ylabel="Average torque [N.m]",
        legend_list=legend_list,
#         save_path=join(save_path, name + "_MTPA_torque_speed.png"),
#         is_show_fig=is_show_fig,
    )


i_load = -1

plot_2D(
    [OP_matrix_MTPA[:, i_load, 0]],
    [I_MTPA[:, i_load, 0], I_MTPA[:, i_load, 1], I_MTPA[:, i_load, 2]],
    xlabel="Speed [rpm]",
    ylabel="Current [Arms]",
    legend_list=["Id", "Iq", "Imax"],
#     save_path=join(save_path, name + "_current_MTPA_OP" + str(i_load) + ".png"),
#     is_show_fig=is_show_fig,
)

plot_2D(
    [OP_matrix_MTPA[:, i_load, 0]],
    [U_MTPA[:, i_load, 0], U_MTPA[:, i_load, 1], U_MTPA[:, i_load, 2]],
    xlabel="Speed [rpm]",
    ylabel="Voltage [Vrms]",
    legend_list=["Ud", "Uq", "Umax"],
#     save_path=join(save_path, name + "_voltage_MTPA_OP" + str(i_load) + ".png"),
#     is_show_fig=is_show_fig,
)
# Out:
# Speed 1/50
# Speed 2/50
# Speed 3/50
# Speed 4/50
# Speed 5/50
# Speed 6/50
# Speed 7/50
# Speed 8/50
# Speed 9/50
# Speed 10/50
# Speed 11/50
# Speed 12/50
# Speed 13/50
# Speed 14/50
# Speed 15/50
# Speed 16/50
# Speed 17/50
# Speed 18/50
# Speed 19/50
# Speed 20/50
# Speed 21/50
# Speed 22/50
# Speed 23/50
# Speed 24/50
# Speed 25/50
# Speed 26/50
# Speed 27/50
# Speed 28/50
# Speed 29/50
# Speed 30/50
# Speed 31/50
# Speed 32/50
# Speed 33/50
# Speed 34/50
# Speed 35/50
# Speed 36/50
# Speed 37/50
# Speed 38/50
# Speed 39/50
# Speed 40/50
# Speed 41/50
# Speed 42/50
# Speed 43/50
# Speed 44/50
# Speed 45/50
# Speed 46/50
# Speed 47/50
# Speed 48/50
# Speed 49/50
# Speed 50/50
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
i_load
Ntorque
print(I_max_vect)
print(abs(I_max_vect))
# Out:
# [176.7766953]
# [176.7766953]

# %% [markdown]
# # Force 계산

# %% [markdown]
# time fft

# %%
out.mag.B.plot_2D_Data("freqs", component_list=["radial"], **dict_2D)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25976/1324697820.py in <module>
# ----> 1 out.mag.B.plot_2D_Data("freqs", component_list=["radial"], **dict_2D)
#
# NameError: name 'out' is not defined

# %% [markdown]
# # Plot space fft

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25976/3168295105.py in <module>
# ----> 1 out.mag.B.plot_spectrogram()
#
# NameError: name 'out' is not defined

# %%
out.mag.B.plot_2D_Data("wavenumber=[0,200]", component_list=["radial"], **dict_2D)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25976/3336770401.py in <module>
# ----> 1 out.mag.B.plot_2D_Data("wavenumber=[0,200]", component_list=["radial"], **dict_2D)
#       2 out.mag.B.plot_spectrogram()
#
# NameError: name 'out' is not defined

# %% [markdown]
# # Deactivate automatic ticks

# %%
out.mag.B.plot_2D_Data("wavenumber=[0,200]", is_auto_ticks=False, component_list=["radial"], **dict_2D)

# %%
out.force.AGSF.plot_2D_Data("freq","wavenumber")
# out.force.AGSF.as_dict()

#---------------------------------------------------------------
# 3D stem plot of 2D fft
out.mag.B.plot_3D_Data(
    "freqs->elec_order=[0,10]", "wavenumber->space_order=[-10,10]", N_stem=50, component_list=["radial"],
)
#---------------------------------------------------------------
# Out:
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_4D.py:271: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# # Normalize frequency axis

# %%
out.mag.B.plot_2D_Data("freqs->elec_order", component_list=["radial"], **dict_2D)

# %%
out.mag.Phi_wind_stator.plot_2D_Data("time", "phase[]", **dict_2D)
# Out:
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# # compare simu and

# %%
out.mag.B.plot_2D_Data(
    "time", component_list=["radial"], data_list=[out.mag.B], legend_list=["Reference", "Open-circuit"], **dict_2D
)
#---------------------------------------------------------------
# Out:
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# # compare simu and simu spectra

# %%
out.mag.B.plot_2D_Data(
    "freqs<1000", component_list=["radial"], data_list=[out.mag.B], legend_list=["Reference", "Open-circuit"], **dict_2D
)
# Out:
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# # 3D plots

# %%
out.mag.B.plot_3D_Data("time", "angle{°}",is_2D_view=False)
out.mag.B.plot_3D_Data("time", "angle{°}", component_list=["radial"], is_2D_view=True,x_max=0.06,**dict_3D)
# Out:
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_3D.py:354: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
out.mag.B.plot_3D_Data("freqs->mech_order", "wavenumber[-16:1:16]", N_stem=2,is_2D_view=True,is_same_size=False)

# %%
out.force.AGSF.plot_3D_Data(
    "freqs->mech_order=[0,96]",
    "wavenumber->space_order=[-48,48]",
    N_stem=100,
    
    component_list=["radial"],
    is_2D_view=False,
    **dict_3D

)
# Out:
# ---------------------------------------------------------------------------
# UnitError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20032/891206277.py in <module>
# ----> 1 out.force.AGSF.plot_3D_Data(
#       2     "freqs->mech_order=[0,96]",
#       3     "wavenumber->space_order=[-48,48]",
#       4     N_stem=100,
#       5
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Methods\VectorField\plot_3D_Data.py in plot_3D_Data(self, axis_data, is_norm, unit, component_list, save_path, x_min, x_max, y_min, y_max, z_min, z_max, z_range, is_auto_ticks, is_auto_range, is_2D_view, is_same_size, N_stem, fig, ax, is_show_fig, is_logscale_x, is_logscale_y, is_logscale_z, thresh, is_switch_axes, colormap, win_title, font_name, font_size_title, font_size_label, font_size_legend, *arg_list)
#     102             save_path_comp = save_path
#     103
# --> 104         self.components[comp].plot_3D_Data(
#     105             arg_list,
#     106             axis_data=axis_data,
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Methods\DataND\plot_3D_Data.py in plot_3D_Data(self, axis_data, is_norm, unit, save_path, x_min, x_max, y_min, y_max, z_min, z_max, z_range, is_auto_ticks, is_auto_range, is_2D_view, is_contour, is_same_size, N_stem, fig, ax, is_show_fig, is_logscale_x, is_logscale_y, is_logscale_z, thresh, is_switch_axes, colormap, win_title, font_name, font_size_title, font_size_label, font_size_legend, xlabel, ylabel, zlabel, title, is_disp_title, *arg_list)
#     163             )
#     164         else:
# --> 165             result = self.get_harmonics(
#     166                 N_stem,
#     167                 arg_list,
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Methods\DataND\get_harmonics.py in get_harmonics(self, N_harm, unit, is_norm, axis_data, is_flat, *args)
#      30     if len(args) == 1 and type(args[0]) == tuple:
#      31         args = args[0]  # if called from another script with *args
# ---> 32     return_dict = self.get_magnitude_along(
#      33         args, unit=unit, is_norm=is_norm, axis_data=axis_data
#      34     )
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Methods\DataND\get_magnitude_along.py in get_magnitude_along(self, unit, is_norm, axis_data, is_squeeze, is_sum, *args)
#     119     else:
#     120
# --> 121         return_dict = self.get_along(
#     122             args, axis_data=axis_data, is_squeeze=is_squeeze, is_magnitude=True
#     123         )
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Methods\DataND\get_along.py in get_along(self, unit, is_norm, axis_data, is_squeeze, is_magnitude, *args)
#      34     axes_list = read_input_strings(args, axis_data)
#      35     # Extract the requested axes (symmetries + unit)
# ---> 36     axes_list, transforms = self._comp_axes(axes_list)
#      37     # Get the field
#      38     values = self._get_field(axes_list)
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Methods\DataND\_comp_axes.py in _comp_axes(self, axes_list)
#      65     # Extract the requested axes (symmetries + unit)
#      66     for axis_requested in axes_list:
# ---> 67         axis_requested.get_axis(self.axes[axis_requested.index], is_real=self.is_real)
#      68     return axes_list, transforms
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Methods\RequestedAxis\get_axis.py in get_axis(self, axis, is_real)
#     153         # if self.corr_unit is None:
#     154         #     self.corr_unit = self.unit
# --> 155         values = axis.get_values(
#     156             is_oneperiod=is_oneperiod,
#     157             is_antiperiod=is_antiperiod,
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Methods\Data1D\get_values.py in get_values(self, unit, is_oneperiod, is_antiperiod, is_smallestperiod, normalization, operation, is_real, corr_unit)
#     110     if unit != "SI" and unit != self.unit:
#     111         if corr_unit is not None:
# --> 112             values = convert(values, corr_unit, unit)
#     113         else:
#     114             values = convert(values, self.unit, unit)
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\conversions.py in convert(values, unit1, unit2)
#     249             dim2_denom = [0, 0, 0, 0, 0, 0]
#     250             prefix2_denom = 1.0
# --> 251         dim2_num, prefix2_num = get_dim_prefix(unit2)
#     252         # Check compatibility
#     253         dim1 = [i - j for i, j in zip(dim1_num, dim1_denom)]
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\conversions.py in get_dim_prefix(unit_str)
#     103                 prefix = (unit_prefixes.get(prefix_str) * key[1]) ** p
#     104             else:
# --> 105                 raise UnitError("Prefix " + prefix_str + " unknown")
#     106             break
#     107     if not dim:
#
# UnitError: Prefix mec unknown

# %%
axis_data=[]
from numpy import pi

# %%
out.mag.B.plot_3D_Data("mag.B", "freqs","wavenumber", component_list=['radial'], is_2D_view=False)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20032/3834835601.py in <module>
# ----> 1 out.mag.B.plot_3D_Data("mag.B", "freqs","wavenumber", component_list=['radial'], is_2D_view=False)
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Methods\VectorField\plot_3D_Data.py in plot_3D_Data(self, axis_data, is_norm, unit, component_list, save_path, x_min, x_max, y_min, y_max, z_min, z_max, z_range, is_auto_ticks, is_auto_range, is_2D_view, is_same_size, N_stem, fig, ax, is_show_fig, is_logscale_x, is_logscale_y, is_logscale_z, thresh, is_switch_axes, colormap, win_title, font_name, font_size_title, font_size_label, font_size_legend, *arg_list)
#     102             save_path_comp = save_path
#     103
# --> 104         self.components[comp].plot_3D_Data(
#     105             arg_list,
#     106             axis_data=axis_data,
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Methods\DataND\plot_3D_Data.py in plot_3D_Data(self, axis_data, is_norm, unit, save_path, x_min, x_max, y_min, y_max, z_min, z_max, z_range, is_auto_ticks, is_auto_range, is_2D_view, is_contour, is_same_size, N_stem, fig, ax, is_show_fig, is_logscale_x, is_logscale_y, is_logscale_z, thresh, is_switch_axes, colormap, win_title, font_name, font_size_title, font_size_label, font_size_legend, xlabel, ylabel, zlabel, title, is_disp_title, *arg_list)
#     365             )
#     366         else:
# --> 367             indices_x = np_any(
#     368                 where(Zdata > abs(thresh * np_max(Zdata)), True, False), axis=1
#     369             )
#
# <__array_function__ internals> in any(*args, **kwargs)
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\numpy\core\fromnumeric.py in any(a, axis, out, keepdims, where)
#    2356
#    2357     """
# -> 2358     return _wrapreduction(a, np.logical_or, 'any', axis, None, out,
#    2359                           keepdims=keepdims, where=where)
#    2360
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
print(out.force.axes_dict)
out.force.AGSF.plot_3D_Data("time","angle", component_list=['radial'], is_2D_view=False)
# Out:
# {'time': <SciDataTool.Classes.DataLinspace.DataLinspace object at 0x0000025178A9A640>, 'angle': <SciDataTool.Classes.DataLinspace.DataLinspace object at 0x000002517ADA7C40>}
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_3D.py:354: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# # Create the Simulation
# mySimu = Simu1(name="Tuto_Force")  
# mySimu.parent = out
# mySimu.force = ForceMT()
# # Run only the force module
# out_mySimu=mySimu.force.run()

#a=simu.parent.force

out.simu.var_simu.postproc_list[0]
out.force.AGSF.plot_2D_Data("angle{°}", **dict_2D)
out.force.AGSF.plot_2D_Data("wavenumber=[0,96]", **dict_2D)
# Out:
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#------------------------------------------------------
# Plot the air-gap force as a function of time with the time fft
out.force.AGSF.plot_2D_Data("time","angle[10]", is_auto_ticks=False, **dict_2D)
out.force.AGSF.plot_2D_Data("freqs=[0,4000]", is_auto_ticks=False, **dict_2D)
#------------------------------------------------------
# Out:
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#------------------------------------------------------
# Plot the tangential force as a function of time and space

out.force.AGSF.plot_3D_Data("time", "angle{°}", is_2D_view=False)
#------------------------------------------------------
# Out:
# C:\Users\user\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\Plot\plot_3D.py:354: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
out.force.AGSF.plot_3D_Data(
    "freqs->mech_order=[0,96]",
    "wavenumber->space_order=[-48,48]",
    N_stem=50,
    component_list=["radial"],
    is_2D_view=False,
)
# Out:
# ---------------------------------------------------------------------------
# UnitError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20032/2695036512.py in <module>
# ----> 1 out.force.AGSF.plot_3D_Data(
#       2     "freqs->mech_order=[0,96]",
#       3     "wavenumber->space_order=[-48,48]",
#       4     N_stem=50,
#       5     component_list=["radial"],
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Methods\VectorField\plot_3D_Data.py in plot_3D_Data(self, axis_data, is_norm, unit, component_list, save_path, x_min, x_max, y_min, y_max, z_min, z_max, z_range, is_auto_ticks, is_auto_range, is_2D_view, is_same_size, N_stem, fig, ax, is_show_fig, is_logscale_x, is_logscale_y, is_logscale_z, thresh, is_switch_axes, colormap, win_title, font_name, font_size_title, font_size_label, font_size_legend, *arg_list)
#     102             save_path_comp = save_path
#     103
# --> 104         self.components[comp].plot_3D_Data(
#     105             arg_list,
#     106             axis_data=axis_data,
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Methods\DataND\plot_3D_Data.py in plot_3D_Data(self, axis_data, is_norm, unit, save_path, x_min, x_max, y_min, y_max, z_min, z_max, z_range, is_auto_ticks, is_auto_range, is_2D_view, is_contour, is_same_size, N_stem, fig, ax, is_show_fig, is_logscale_x, is_logscale_y, is_logscale_z, thresh, is_switch_axes, colormap, win_title, font_name, font_size_title, font_size_label, font_size_legend, xlabel, ylabel, zlabel, title, is_disp_title, *arg_list)
#     163             )
#     164         else:
# --> 165             result = self.get_harmonics(
#     166                 N_stem,
#     167                 arg_list,
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Methods\DataND\get_harmonics.py in get_harmonics(self, N_harm, unit, is_norm, axis_data, is_flat, *args)
#      30     if len(args) == 1 and type(args[0]) == tuple:
#      31         args = args[0]  # if called from another script with *args
# ---> 32     return_dict = self.get_magnitude_along(
#      33         args, unit=unit, is_norm=is_norm, axis_data=axis_data
#      34     )
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Methods\DataND\get_magnitude_along.py in get_magnitude_along(self, unit, is_norm, axis_data, is_squeeze, is_sum, *args)
#     119     else:
#     120
# --> 121         return_dict = self.get_along(
#     122             args, axis_data=axis_data, is_squeeze=is_squeeze, is_magnitude=True
#     123         )
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Methods\DataND\get_along.py in get_along(self, unit, is_norm, axis_data, is_squeeze, is_magnitude, *args)
#      34     axes_list = read_input_strings(args, axis_data)
#      35     # Extract the requested axes (symmetries + unit)
# ---> 36     axes_list, transforms = self._comp_axes(axes_list)
#      37     # Get the field
#      38     values = self._get_field(axes_list)
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Methods\DataND\_comp_axes.py in _comp_axes(self, axes_list)
#      65     # Extract the requested axes (symmetries + unit)
#      66     for axis_requested in axes_list:
# ---> 67         axis_requested.get_axis(self.axes[axis_requested.index], is_real=self.is_real)
#      68     return axes_list, transforms
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Methods\RequestedAxis\get_axis.py in get_axis(self, axis, is_real)
#     153         # if self.corr_unit is None:
#     154         #     self.corr_unit = self.unit
# --> 155         values = axis.get_values(
#     156             is_oneperiod=is_oneperiod,
#     157             is_antiperiod=is_antiperiod,
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Methods\Data1D\get_values.py in get_values(self, unit, is_oneperiod, is_antiperiod, is_smallestperiod, normalization, operation, is_real, corr_unit)
#     110     if unit != "SI" and unit != self.unit:
#     111         if corr_unit is not None:
# --> 112             values = convert(values, corr_unit, unit)
#     113         else:
#     114             values = convert(values, self.unit, unit)
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\conversions.py in convert(values, unit1, unit2)
#     249             dim2_denom = [0, 0, 0, 0, 0, 0]
#     250             prefix2_denom = 1.0
# --> 251         dim2_num, prefix2_num = get_dim_prefix(unit2)
#     252         # Check compatibility
#     253         dim1 = [i - j for i, j in zip(dim1_num, dim1_denom)]
#
# ~\.conda\envs\py38_pylee_backup\lib\site-packages\scidatatool-1.4.25-py3.8.egg\SciDataTool\Functions\conversions.py in get_dim_prefix(unit_str)
#     103                 prefix = (unit_prefixes.get(prefix_str) * key[1]) ** p
#     104             else:
# --> 105                 raise UnitError("Prefix " + prefix_str + " unknown")
#     106             break
#     107     if not dim:
#
# UnitError: Prefix mec unknown
