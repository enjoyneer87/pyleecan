# %% [markdown]
# # Version information

# %%
from datetime import date
print("Running date:", date.today().strftime("%B %d, %Y"))
import pyleecan
print("Pyleecan version:" + pyleecan.__version__)
import SciDataTool
print("SciDataTool version:" + SciDataTool.__version__)
# Out:
# Running date: July 03, 2022
# Pyleecan version:1.3.7
# c:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# c:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# SciDataTool version:1.4.24

# %%
# %matplotlib inline

# Load the machine
from pyleecan.Functions.load import load
from pyleecan.definitions import DATA_DIR
from os.path import join

Toyota_Prius = load(join(DATA_DIR, "Machine", "Toyota_Prius.json"))
Toyota_Prius.plot()
# Out:
# c:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\pyleecan\Methods\Machine\Machine\plot.py:130: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
from pyleecan.Classes.Simu1 import Simu1
from pyleecan.Classes.MagFEMM import MagFEMM
from pyleecan.Classes.InputCurrent import InputCurrent
from pyleecan.Classes.OPdq import OPdq
from numpy import sqrt, pi
from pyleecan.Classes.ForceMT import ForceMT

rpm=2000
simu_noload = Simu1(name="slot_opening", machine=Toyota_Prius)
simu_noload.input = InputCurrent(
    OP=OPdq(Id_ref=0, Iq_ref=0, N0=rpm),
    Ir=None,
    Na_tot=2 ** 16, # angle    
    Nt_tot=2 ** 8, #Time
)

simu_noload.mag = MagFEMM(
    type_BH_stator=0,
    type_BH_rotor=0,
    is_periodicity_a=True,
    is_periodicity_t=True,
    nb_worker=8,
    Kgeo_fineness=1,
)
simu_noload.force = ForceMT(
    is_periodicity_a=True,
    is_periodicity_t=True,
)

simu_noload.elec = None
simu_noload.mag.is_get_meshsolution = True

# %%
out_noload = simu_noload.run()
# Out:
# [13:24:13] Starting running simulation slot_opening (machine=Toyota_Prius)
# [13:24:13] Starting Magnetic module
# [13:24:14] Solving time step 13 / 32 in FEMM
# [13:24:14] Solving time step 9 / 32 in FEMM
# [13:24:14] Solving time step 1 / 32 in FEMM
# [13:24:15] Solving time step 21 / 32 in FEMM
# [13:24:15] Solving time step 25 / 32 in FEMM
# [13:24:16] Solving time step 5 / 32 in FEMM
# [13:24:16] Solving time step 29 / 32 in FEMM
# [13:24:17] Solving time step 17 / 32 in FEMM
# [13:24:22] Solving time step 14 / 32 in FEMM
# [13:24:22] Solving time step 10 / 32 in FEMM
# [13:24:22] Solving time step 22 / 32 in FEMM
# [13:24:22] Solving time step 2 / 32 in FEMM
# [13:24:23] Solving time step 26 / 32 in FEMM
# [13:24:23] Solving time step 6 / 32 in FEMM
# [13:24:24] Solving time step 30 / 32 in FEMM
# [13:24:24] Solving time step 18 / 32 in FEMM
# [13:24:27] Solving time step 15 / 32 in FEMM
# [13:24:28] Solving time step 11 / 32 in FEMM
# [13:24:28] Solving time step 23 / 32 in FEMM
# [13:24:28] Solving time step 3 / 32 in FEMM
# [13:24:29] Solving time step 27 / 32 in FEMM
# [13:24:30] Solving time step 7 / 32 in FEMM
# [13:24:30] Solving time step 31 / 32 in FEMM
# [13:24:30] Solving time step 19 / 32 in FEMM
# [13:24:33] Solving time step 16 / 32 in FEMM
# [13:24:34] Solving time step 12 / 32 in FEMM
# [13:24:34] Solving time step 24 / 32 in FEMM
# [13:24:34] Solving time step 4 / 32 in FEMM
# [13:24:34] Solving time step 28 / 32 in FEMM
# [13:24:35] Solving time step 8 / 32 in FEMM
# [13:24:35] Solving time step 32 / 32 in FEMM
# [13:24:36] Solving time step 20 / 32 in FEMM
# [13:24:40] Starting Force module
# [13:24:40] End of simulation slot_opening

# %% [markdown]
# In this tutorial we will focus on the main magnetic outputs. For example, after the reference simulation:

# %% [markdown]
# Reference torque and current angle vector are:

# %%
from numpy import linspace, array, pi

Tem_av_ref = array([79, 125, 160, 192, 237, 281, 319, 343, 353, 332, 266, 164, 22]) # Yang et al, 2013
Phi0_ref = linspace(60 * pi / 180, 180 * pi / 180, Tem_av_ref.size)
N_speed = Tem_av_ref.size

# %%
from pyleecan.Classes.VarLoadCurrent import VarLoadCurrent
from numpy import zeros, ones, linspace, array, sqrt, arange

# varload = VarLoadCurrent(is_torque=True)
varload=VarLoadCurrent()
varload.type_OP_matrix = 0 # Matrix N0, I0, Phi0

# Creating the Operating point matrix
OP_matrix = zeros((N_speed,4))

# Set N0 = 2000 [rpm] for all simulation
OP_matrix[:,0] = 2000 * ones((N_speed))

# Set I0 = 250 / sqrt(2) [A] (RMS) for all simulation
OP_matrix[:,1] = 250/sqrt(2) * ones((N_speed)) 

# Set Phi0 from 60° to 180°
OP_matrix[:,2] = Phi0_ref

# Set reference torque from Yang et al, 2013
OP_matrix[:,3] = Tem_av_ref

varload.OP_matrix = OP_matrix
print(OP_matrix)

# All the simulation use the same machine
# No need to draw the machine for all OP
varload.is_reuse_femm_file=True
# Out:
# [[2.00000000e+03 1.76776695e+02 1.04719755e+00 7.90000000e+01]
#  [2.00000000e+03 1.76776695e+02 1.22173048e+00 1.25000000e+02]
#  [2.00000000e+03 1.76776695e+02 1.39626340e+00 1.60000000e+02]
#  [2.00000000e+03 1.76776695e+02 1.57079633e+00 1.92000000e+02]
#  [2.00000000e+03 1.76776695e+02 1.74532925e+00 2.37000000e+02]
#  [2.00000000e+03 1.76776695e+02 1.91986218e+00 2.81000000e+02]
#  [2.00000000e+03 1.76776695e+02 2.09439510e+00 3.19000000e+02]
#  [2.00000000e+03 1.76776695e+02 2.26892803e+00 3.43000000e+02]
#  [2.00000000e+03 1.76776695e+02 2.44346095e+00 3.53000000e+02]
#  [2.00000000e+03 1.76776695e+02 2.61799388e+00 3.32000000e+02]
#  [2.00000000e+03 1.76776695e+02 2.79252680e+00 2.66000000e+02]
#  [2.00000000e+03 1.76776695e+02 2.96705973e+00 1.64000000e+02]
#  [2.00000000e+03 1.76776695e+02 3.14159265e+00 2.20000000e+01]]

# %%
simu_vop = simu_noload.copy()
simu_vop.var_simu = varload
simu_vop.var_simu.is_keep_all_output = True

# Speed-up computation (set reference simu input as first OP), here reference is already the 9th simulation
# simu_vop.input.set_OP_from_array(varload.OP_matrix, varload.type_OP_matrix)

# %%
Xout_vop = simu_vop.run()
# Out:
# [13:23:29] Starting running simulation slot_opening (machine=Toyota_Prius)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# z:\01_Codes_Projects\git_pyleecan\NGV_Pyleecan_3_tuto_stator_design_8p48s.ipynb Cell 11' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/z%3A/01_Codes_Projects/git_pyleecan/NGV_Pyleecan_3_tuto_stator_design_8p48s.ipynb#ch0000016?line=0'>1</a> Xout_vop = simu_vop.run()
#
# File c:\Users\KDH2018-PC\anaconda3\envs\py38_NGV\lib\site-packages\pyleecan\Methods\Simulation\Simulation\run.py:38, in run(self)
#      35     self.init_logger(results)
#      37     # Compute the multisimulation
# ---> 38     self.var_simu.run()
#      40 # 'normal' simulation
#      41 else:
#      42     # Output initialization
#      43     if self.parent is None:
#
# File c:\Users\KDH2018-PC\anaconda3\envs\py38_NGV\lib\site-packages\pyleecan\Methods\Simulation\VarSimu\run.py:39, in run(self)
#      36     xoutput.xoutput_dict = dict()
#      38 # Generate simulation list and ParamExplorerValue list
# ---> 39 simu_dict = self.generate_simulation_list(ref_simu)
#      40 # Generate default datakeeper
#      41 self.gen_datakeeper_list(ref_simu)
#
# File c:\Users\KDH2018-PC\anaconda3\envs\py38_NGV\lib\site-packages\pyleecan\Methods\Simulation\VarLoadCurrent\generate_simulation_list.py:42, in generate_simulation_list(self, ref_simu)
#      36     multisim_dict["simulation_list"].append(new_simu)
#      38 # Create ParamExplorerSet
#      39 #   This version uses a single ParamExplorerSet to define the simulation
#      40 #   Other parameters can be stored in a dedicated ParamExplorerSet if needed
#      41 multisim_dict["paramexplorer_list"].append(
# ---> 42     ParamExplorerSet(
#      43         name="InputCurrent",
#      44         symbol="In",
#      45         unit="-",
#      46         setter="simu.input",
#      47         getter="simu.input",
#      48         value=list_input,
#      49     )
#      50 )
#      52 return multisim_dict
#
# File c:\Users\KDH2018-PC\anaconda3\envs\py38_NGV\lib\site-packages\pyleecan\Classes\ParamExplorerSet.py:176, in ParamExplorerSet.__init__(self, value, name, symbol, unit, setter, getter, init_dict, init_str)
#     174 self.value = value
#     175 # Call ParamExplorer init
# --> 176 super(ParamExplorerSet, self).__init__(
#     177     name=name, symbol=symbol, unit=unit, setter=setter, getter=getter
#     178 )
#
# File c:\Users\KDH2018-PC\anaconda3\envs\py38_NGV\lib\site-packages\pyleecan\Classes\ParamExplorer.py:127, in ParamExplorer.__init__(self, name, symbol, unit, setter, getter, init_dict, init_str)
#     125 self.symbol = symbol
#     126 self.unit = unit
# --> 127 self.setter = setter
#     128 self.getter = getter
#     130 # The class is frozen, for now it's impossible to add new properties
#
# File c:\Users\KDH2018-PC\anaconda3\envs\py38_NGV\lib\site-packages\pyleecan\Classes\_frozen.py:35, in FrozenClass.__setattr__(self, key, value)
#      31 if self.__isfrozen and not hasattr(self, key):
#      32     raise FrozenError(
#      33         self.__class__.__name__ + ' class has no "' + key + '" ' "property"
#      34     )
# ---> 35 object.__setattr__(self, key, value)
#
# TypeError: 'property' object is not callable

# %% [markdown]
# The log of the simulation enables to understand step by step the status of the computation. As expected, the reference simulation is computed first. Then each of the 13 simulations is run starting with a message indicating the simulation operating point:
#
# **Running simulation 3/13 with N0=2000 [rpm], Id=30.7 [Arms], Iq=174.1 [Arms]**
#
# And ending with the Datakeepers result for this simulation:
#
# **Variable Load Results: N0=2000 [rpm], Id=30.7 [Arms], Iq=174.1 [Arms], I0=176.8 [A], Phi0=1.396 [], Tem_av_ref=160 [N.m], Tem_av=170.3 [N.m], Tem_rip_pp=53.12 [N.m], Tem_rip_norm=0.312 [-]**
#
# As expected the computation for the 9th simulation was skipped, the operating point and Datakeepers are still displayed as a reminder.
#
# Pyleecan will automatically defines several Datakeeper to extract the main outputs from each simulation. These values are all gathered in the xoutput_dict:

# %%
print("Values available in XOutput:")
print(Xout_vop.xoutput_dict.keys())

print("\nI0 for each simulation:")
print(Xout_vop["I0"].result)
print("\nPhi0 for each simulation:")
print(Xout_vop["Phi0"].result)
print("\nComputed Average Torque for each simulation:")
print(Xout_vop["Tem_av"].result)
print("\nComputed Average Torque of the reference simulation:")
print(Xout_vop["Tem_av"].result_ref)
# Out:
# Values available in XOutput:
# dict_keys(['N0', 'Id', 'Iq', 'I0', 'Phi0', 'Tem_av_ref', 'Tem_av', 'Tem_rip_pp', 'Tem_rip_norm', 'Pem_av'])
#
# I0 for each simulation:
# [176.77669529663686, 176.77669529663686, 176.77669529663683, 176.77669529663686, 176.77669529663683, 176.77669529663686, 176.77669529663686, 176.77669529663686, 176.77669529663686, 176.77669529663686, 176.77669529663683, 176.77669529663683, 176.77669529663686]
#
# Phi0 for each simulation:
# [1.0471975511965976, 1.2217304763960306, 1.3962634015954636, 1.5707963267948966, 1.7453292519943295, 1.9198621771937625, 2.0943951023931957, 2.2689280275926285, 2.443460952792061, 2.6179938779914944, 2.7925268031909276, 2.9670597283903604, 3.141592653589793]
#
# Computed Average Torque for each simulation:
# [82.70058164915343, 126.4346038801843, 171.2892053139925, 215.28492689188755, 256.53629126712804, 293.3305925751831, 323.82251465312413, 345.44714301730926, 353.6879347693815, 336.9703399930378, 270.5958441929039, 151.26679496425805, -5.314356377064621]
#
# Computed Average Torque of the reference simulation:
# 353.6879347693815

# %% [markdown]
# Other Datakeeper can be added in simu.var_simu.datakeeper_list to extract other meaningful (or user-defined) data.
#
# As the option is_keep_all_output was activated, one can also access all the simulation results in the "output_list":

# %%
# Flux of the 3rd simulation
print("Id: "+str(Xout_vop.output_list[2].elec.OP.Id_ref)+" , Iq: "+str(Xout_vop.output_list[2].elec.OP.Iq_ref)+" , Tem_av_ref: "+str(Xout_vop.output_list[2].elec.Tem_av_ref))
Xout_vop.output_list[2].mag.B.plot_2D_Data("angle")

print("Index of the reference simulation in the list: "+str(Xout_vop.xoutput_ref_index))
print("Id: "+str(Xout_vop.output_list[8].elec.OP.Id_ref)+" , Iq: "+str(Xout_vop.output_list[8].elec.OP.Iq_ref)+" , Tem_av_ref: "+str(Xout_vop.output_list[8].elec.Tem_av_ref))
Xout_vop.output_list[8].mag.Tem.plot_2D_Data("time")
# Out:
# Id: 30.69695099224322 , Iq: 174.0910600800047 , Tem_av_ref: None
# <img src="data:image/png;base64,..." width="905.4166666666667">
# <img src="data:image/png;base64,..." width="905.4166666666667">
# Index of the reference simulation in the list: None
# Id: -135.4188051049254 , Iq: 113.62986941801093 , Tem_av_ref: None
# <img src="data:image/png;base64,..." width="905.4166666666667">

# %% [markdown]
# Any parameter in the xOutput_dict can be plot as a function of any other

# %%
fig = Xout_vop.plot_multi("Phi0", "Tem_av")
fig = Xout_vop.plot_multi("Id", "Iq")
# Out:
# <img src="data:image/png;base64,..." width="905.4166666666667">
# <img src="data:image/png;base64,..." width="905.4166666666667">

# %% [markdown]
# ## Slot Opening 최적화

# %%
from pyleecan.Classes.VarParam import VarParam
from pyleecan.Classes.ParamExplorerSet import ParamExplorerSet
from pyleecan.Classes.ParamExplorerInterval import ParamExplorerInterval
from pyleecan.Classes.ParamExplorerSet import ParamExplorerSet

simu_sweep = simu_noload.copy()

sweep = VarParam(
    stop_if_error=True,
    is_reuse_femm_file=False,
    is_keep_all_output=True,
)
simu_sweep.var_simu = sweep
N_sweep = 8

# List of ParamExplorer to define multisimulation input values
simu_sweep.var_simu.paramexplorer_list = [
     ParamExplorerInterval(
        name="Stator slot opening",
        symbol="W0s",
        unit="m",
        setter="simu.machine.stator.slot.W0",
        getter="simu.machine.stator.slot.W0",
        min_value=0.1 * Toyota_Prius.stator.slot.W0,
        max_value=1.4 * Toyota_Prius.stator.slot.W0,
        N=N_sweep,
    )
]

print("Value used in the Parameter sweep: "+str(simu_sweep.var_simu.paramexplorer_list[0].get_value()))
print("Reference machine W0: "+str(Toyota_Prius.stator.slot.W0))
# Out:
# Value used in the Parameter sweep: [0.000193   0.00055143 0.00090986 0.00126829 0.00162671 0.00198514
#  0.00234357 0.002702  ]
# Reference machine W0: 0.00193

# %%
Xout_sweep = simu_sweep.run()
# Out:
# [13:25:28] Starting running simulation slot_opening (machine=Toyota_Prius)
# [13:25:28] Computing reference simulation for Parameter Sweep
# [13:25:28] W0s: 8 values from 0.000193 to 0.002702 (ref=0.00193) [m]
# [13:25:28] Starting Magnetic module
# [13:25:29] Solving time step 5 / 32 in FEMM
# [13:25:29] Solving time step 1 / 32 in FEMM
# [13:25:30] Solving time step 9 / 32 in FEMM
# [13:25:30] Solving time step 25 / 32 in FEMM
# [13:25:30] Solving time step 21 / 32 in FEMM
# [13:25:31] Solving time step 13 / 32 in FEMM
# [13:25:31] Solving time step 29 / 32 in FEMM
# [13:25:32] Solving time step 17 / 32 in FEMM
# [13:25:37] Solving time step 6 / 32 in FEMM
# [13:25:37] Solving time step 2 / 32 in FEMM
# [13:25:37] Solving time step 10 / 32 in FEMM
# [13:25:38] Solving time step 22 / 32 in FEMM
# [13:25:38] Solving time step 26 / 32 in FEMM
# [13:25:38] Solving time step 14 / 32 in FEMM
# [13:25:38] Solving time step 30 / 32 in FEMM
# [13:25:39] Solving time step 18 / 32 in FEMM
# [13:25:43] Solving time step 7 / 32 in FEMM
# [13:25:43] Solving time step 3 / 32 in FEMM
# [13:25:44] Solving time step 11 / 32 in FEMM
# [13:25:44] Solving time step 23 / 32 in FEMM
# [13:25:44] Solving time step 27 / 32 in FEMM
# [13:25:45] Solving time step 15 / 32 in FEMM
# [13:25:45] Solving time step 31 / 32 in FEMM
# [13:25:46] Solving time step 19 / 32 in FEMM
# [13:25:50] Solving time step 8 / 32 in FEMM
# [13:25:50] Solving time step 4 / 32 in FEMM
# [13:25:51] Solving time step 24 / 32 in FEMM
# [13:25:51] Solving time step 28 / 32 in FEMM
# [13:25:52] Solving time step 12 / 32 in FEMM
# [13:25:53] Solving time step 32 / 32 in FEMM
# [13:25:53] Solving time step 16 / 32 in FEMM
# [13:25:54] Solving time step 20 / 32 in FEMM
# [13:25:58] Starting Force module
# [13:25:58] Parameter Sweep Reference Results: N0=2000 [rpm], Id=0 [Arms], Iq=0 [Arms], Tem_av=0.0007064 [N.m], Tem_rip_pp=0.7401 [N.m], Tem_rip_norm=1048 [-], Pem_av=0.1479 [W]
# [=====                                             ]  11%
# [13:25:59] Running simulation 1/8 with W0s=0.000193
# [13:25:59] Starting Magnetic module
# [13:26:00] Solving time step 5 / 32 in FEMM
# [13:26:01] Solving time step 17 / 32 in FEMM
# [13:26:01] Solving time step 1 / 32 in FEMM
# [13:26:01] Solving time step 25 / 32 in FEMM
# [13:26:02] Solving time step 13 / 32 in FEMM
# [13:26:02] Solving time step 9 / 32 in FEMM
# [13:26:03] Solving time step 21 / 32 in FEMM
# [13:26:04] Solving time step 29 / 32 in FEMM
# [13:26:08] Solving time step 18 / 32 in FEMM
# [13:26:08] Solving time step 6 / 32 in FEMM
# [13:26:08] Solving time step 2 / 32 in FEMM
# [13:26:09] Solving time step 26 / 32 in FEMM
# [13:26:09] Solving time step 14 / 32 in FEMM
# [13:26:10] Solving time step 10 / 32 in FEMM
# [13:26:10] Solving time step 22 / 32 in FEMM
# [13:26:11] Solving time step 30 / 32 in FEMM
# [13:26:14] Solving time step 7 / 32 in FEMM
# [13:26:14] Solving time step 3 / 32 in FEMM
# [13:26:14] Solving time step 19 / 32 in FEMM
# [13:26:15] Solving time step 27 / 32 in FEMM
# [13:26:15] Solving time step 15 / 32 in FEMM
# [13:26:16] Solving time step 11 / 32 in FEMM
# [13:26:16] Solving time step 23 / 32 in FEMM
# [13:26:17] Solving time step 31 / 32 in FEMM
# [13:26:20] Solving time step 8 / 32 in FEMM
# [13:26:20] Solving time step 4 / 32 in FEMM
# [13:26:20] Solving time step 20 / 32 in FEMM
# [13:26:21] Solving time step 28 / 32 in FEMM
# [13:26:21] Solving time step 16 / 32 in FEMM
# [13:26:22] Solving time step 12 / 32 in FEMM
# [13:26:22] Solving time step 24 / 32 in FEMM
# [13:26:23] Solving time step 32 / 32 in FEMM
# [13:26:27] Starting Force module
# [13:26:27] Parameter Sweep Results: N0=2000 [rpm], Id=0 [Arms], Iq=0 [Arms], Tem_av=0.001159 [N.m], Tem_rip_pp=0.5647 [N.m], Tem_rip_norm=487.1 [-], Pem_av=0.2428 [W]
# [===========                                       ]  22%
# [13:26:27] Running simulation 2/8 with W0s=0.00055142857
# [13:26:27] Starting Magnetic module
# [13:26:28] Solving time step 13 / 32 in FEMM
# [13:26:28] Solving time step 9 / 32 in FEMM
# [13:26:29] Solving time step 5 / 32 in FEMM
# [13:26:29] Solving time step 1 / 32 in FEMM
# [13:26:29] Solving time step 17 / 32 in FEMM
# [13:26:30] Solving time step 29 / 32 in FEMM
# [13:26:31] Solving time step 25 / 32 in FEMM
# [13:26:31] Solving time step 21 / 32 in FEMM
# [13:26:36] Solving time step 14 / 32 in FEMM
# [13:26:36] Solving time step 6 / 32 in FEMM
# [13:26:36] Solving time step 10 / 32 in FEMM
# [13:26:37] Solving time step 2 / 32 in FEMM
# [13:26:37] Solving time step 18 / 32 in FEMM
# [13:26:38] Solving time step 30 / 32 in FEMM
# [13:26:38] Solving time step 26 / 32 in FEMM
# [13:26:39] Solving time step 22 / 32 in FEMM
# [13:26:42] Solving time step 7 / 32 in FEMM
# [13:26:42] Solving time step 15 / 32 in FEMM
# [13:26:42] Solving time step 11 / 32 in FEMM
# [13:26:42] Solving time step 3 / 32 in FEMM
# [13:26:43] Solving time step 19 / 32 in FEMM
# [13:26:43] Solving time step 31 / 32 in FEMM
# [13:26:44] Solving time step 27 / 32 in FEMM
# [13:26:44] Solving time step 23 / 32 in FEMM
# [13:26:47] Solving time step 8 / 32 in FEMM
# [13:26:47] Solving time step 16 / 32 in FEMM
# [13:26:48] Solving time step 12 / 32 in FEMM
# [13:26:48] Solving time step 4 / 32 in FEMM
# [13:26:48] Solving time step 20 / 32 in FEMM
# [13:26:49] Solving time step 32 / 32 in FEMM
# [13:26:49] Solving time step 28 / 32 in FEMM
# [13:26:50] Solving time step 24 / 32 in FEMM
# [13:26:54] Starting Force module
# [13:26:54] Parameter Sweep Results: N0=2000 [rpm], Id=0 [Arms], Iq=0 [Arms], Tem_av=0.001562 [N.m], Tem_rip_pp=0.6133 [N.m], Tem_rip_norm=392.7 [-], Pem_av=0.3271 [W]
# [================                                  ]  33%
# [13:26:54] Running simulation 3/8 with W0s=0.00090985714
# [13:26:54] Starting Magnetic module
# [13:26:55] Solving time step 1 / 32 in FEMM
# [13:26:56] Solving time step 17 / 32 in FEMM
# [13:26:56] Solving time step 13 / 32 in FEMM
# [13:26:56] Solving time step 9 / 32 in FEMM
# [13:26:57] Solving time step 21 / 32 in FEMM
# [13:26:57] Solving time step 25 / 32 in FEMM
# [13:26:58] Solving time step 29 / 32 in FEMM
# [13:26:59] Solving time step 5 / 32 in FEMM
# [13:27:04] Solving time step 2 / 32 in FEMM
# [13:27:04] Solving time step 18 / 32 in FEMM
# [13:27:04] Solving time step 14 / 32 in FEMM
# [13:27:05] Solving time step 22 / 32 in FEMM
# [13:27:05] Solving time step 26 / 32 in FEMM
# [13:27:06] Solving time step 30 / 32 in FEMM
# [13:27:06] Solving time step 10 / 32 in FEMM
# [13:27:06] Solving time step 6 / 32 in FEMM
# [13:27:10] Solving time step 3 / 32 in FEMM
# [13:27:10] Solving time step 19 / 32 in FEMM
# [13:27:10] Solving time step 15 / 32 in FEMM
# [13:27:11] Solving time step 23 / 32 in FEMM
# [13:27:11] Solving time step 27 / 32 in FEMM
# [13:27:11] Solving time step 31 / 32 in FEMM
# [13:27:12] Solving time step 7 / 32 in FEMM
# [13:27:13] Solving time step 11 / 32 in FEMM
# [13:27:15] Solving time step 20 / 32 in FEMM
# [13:27:15] Solving time step 4 / 32 in FEMM
# [13:27:15] Solving time step 16 / 32 in FEMM
# [13:27:16] Solving time step 24 / 32 in FEMM
# [13:27:16] Solving time step 32 / 32 in FEMM
# [13:27:17] Solving time step 28 / 32 in FEMM
# [13:27:17] Solving time step 8 / 32 in FEMM
# [13:27:19] Solving time step 12 / 32 in FEMM
# [13:27:23] Starting Force module
# [13:27:23] Parameter Sweep Results: N0=2000 [rpm], Id=0 [Arms], Iq=0 [Arms], Tem_av=0.001305 [N.m], Tem_rip_pp=0.6905 [N.m], Tem_rip_norm=529.1 [-], Pem_av=0.2733 [W]
# [======================                            ]  44%
# [13:27:23] Running simulation 4/8 with W0s=0.0012682857
# [13:27:23] Starting Magnetic module
# [13:27:24] Solving time step 9 / 32 in FEMM
# [13:27:24] Solving time step 1 / 32 in FEMM
# [13:27:25] Solving time step 5 / 32 in FEMM
# [13:27:25] Solving time step 13 / 32 in FEMM
# [13:27:25] Solving time step 17 / 32 in FEMM
# [13:27:26] Solving time step 25 / 32 in FEMM
# [13:27:26] Solving time step 29 / 32 in FEMM
# [13:27:27] Solving time step 21 / 32 in FEMM
# [13:27:31] Solving time step 2 / 32 in FEMM
# [13:27:31] Solving time step 6 / 32 in FEMM
# [13:27:32] Solving time step 10 / 32 in FEMM
# [13:27:32] Solving time step 14 / 32 in FEMM
# [13:27:32] Solving time step 18 / 32 in FEMM
# [13:27:33] Solving time step 26 / 32 in FEMM
# [13:27:33] Solving time step 30 / 32 in FEMM
# [13:27:33] Solving time step 22 / 32 in FEMM
# [13:27:37] Solving time step 3 / 32 in FEMM
# [13:27:37] Solving time step 7 / 32 in FEMM
# [13:27:37] Solving time step 11 / 32 in FEMM
# [13:27:37] Solving time step 15 / 32 in FEMM
# [13:27:38] Solving time step 19 / 32 in FEMM
# [13:27:39] Solving time step 27 / 32 in FEMM
# [13:27:39] Solving time step 23 / 32 in FEMM
# [13:27:39] Solving time step 31 / 32 in FEMM
# [13:27:42] Solving time step 8 / 32 in FEMM
# [13:27:43] Solving time step 12 / 32 in FEMM
# [13:27:43] Solving time step 4 / 32 in FEMM
# [13:27:43] Solving time step 16 / 32 in FEMM
# [13:27:44] Solving time step 20 / 32 in FEMM
# [13:27:44] Solving time step 28 / 32 in FEMM
# [13:27:45] Solving time step 24 / 32 in FEMM
# [13:27:45] Solving time step 32 / 32 in FEMM
# [13:27:49] Starting Force module
# [13:27:49] Parameter Sweep Results: N0=2000 [rpm], Id=0 [Arms], Iq=0 [Arms], Tem_av=0.000305 [N.m], Tem_rip_pp=0.7029 [N.m], Tem_rip_norm=2304 [-], Pem_av=0.06389 [W]
# [===========================                       ]  55%
# [13:27:49] Running simulation 5/8 with W0s=0.0016267143
# [13:27:49] Starting Magnetic module
# [13:27:50] Solving time step 5 / 32 in FEMM
# [13:27:51] Solving time step 1 / 32 in FEMM
# [13:27:51] Solving time step 9 / 32 in FEMM
# [13:27:51] Solving time step 13 / 32 in FEMM
# [13:27:52] Solving time step 25 / 32 in FEMM
# [13:27:52] Solving time step 21 / 32 in FEMM
# [13:27:53] Solving time step 29 / 32 in FEMM
# [13:27:53] Solving time step 17 / 32 in FEMM
# [13:27:58] Solving time step 2 / 32 in FEMM
# [13:27:58] Solving time step 6 / 32 in FEMM
# [13:27:58] Solving time step 14 / 32 in FEMM
# [13:27:59] Solving time step 10 / 32 in FEMM
# [13:27:59] Solving time step 26 / 32 in FEMM
# [13:28:00] Solving time step 22 / 32 in FEMM
# [13:28:00] Solving time step 30 / 32 in FEMM
# [13:28:00] Solving time step 18 / 32 in FEMM
# [13:28:04] Solving time step 3 / 32 in FEMM
# [13:28:04] Solving time step 7 / 32 in FEMM
# [13:28:04] Solving time step 15 / 32 in FEMM
# [13:28:05] Solving time step 11 / 32 in FEMM
# [13:28:05] Solving time step 27 / 32 in FEMM
# [13:28:06] Solving time step 23 / 32 in FEMM
# [13:28:06] Solving time step 31 / 32 in FEMM
# [13:28:06] Solving time step 19 / 32 in FEMM
# [13:28:10] Solving time step 4 / 32 in FEMM
# [13:28:10] Solving time step 8 / 32 in FEMM
# [13:28:10] Solving time step 16 / 32 in FEMM
# [13:28:11] Solving time step 12 / 32 in FEMM
# [13:28:11] Solving time step 28 / 32 in FEMM
# [13:28:11] Solving time step 24 / 32 in FEMM
# [13:28:12] Solving time step 32 / 32 in FEMM
# [13:28:12] Solving time step 20 / 32 in FEMM
# [13:28:17] Starting Force module
# [13:28:17] Parameter Sweep Results: N0=2000 [rpm], Id=0 [Arms], Iq=0 [Arms], Tem_av=-8.026e-05 [N.m], Tem_rip_pp=0.7078 [N.m], Tem_rip_norm=-8819 [-], Pem_av=-0.01681 [W]
# [=================================                 ]  66%
# [13:28:17] Running simulation 6/8 with W0s=0.0019851429
# [13:28:17] Starting Magnetic module
# [13:28:18] Solving time step 5 / 32 in FEMM
# [13:28:18] Solving time step 17 / 32 in FEMM
# [13:28:18] Solving time step 9 / 32 in FEMM
# [13:28:19] Solving time step 13 / 32 in FEMM
# [13:28:19] Solving time step 21 / 32 in FEMM
# [13:28:19] Solving time step 1 / 32 in FEMM
# [13:28:20] Solving time step 29 / 32 in FEMM
# [13:28:21] Solving time step 25 / 32 in FEMM
# [13:28:25] Solving time step 6 / 32 in FEMM
# [13:28:25] Solving time step 18 / 32 in FEMM
# [13:28:26] Solving time step 14 / 32 in FEMM
# [13:28:26] Solving time step 10 / 32 in FEMM
# [13:28:26] Solving time step 22 / 32 in FEMM
# [13:28:26] Solving time step 2 / 32 in FEMM
# [13:28:27] Solving time step 30 / 32 in FEMM
# [13:28:28] Solving time step 26 / 32 in FEMM
# [13:28:31] Solving time step 19 / 32 in FEMM
# [13:28:31] Solving time step 7 / 32 in FEMM
# [13:28:32] Solving time step 11 / 32 in FEMM
# [13:28:32] Solving time step 15 / 32 in FEMM
# [13:28:32] Solving time step 23 / 32 in FEMM
# [13:28:33] Solving time step 3 / 32 in FEMM
# [13:28:33] Solving time step 31 / 32 in FEMM
# [13:28:34] Solving time step 27 / 32 in FEMM
# [13:28:37] Solving time step 8 / 32 in FEMM
# [13:28:37] Solving time step 20 / 32 in FEMM
# [13:28:38] Solving time step 16 / 32 in FEMM
# [13:28:38] Solving time step 12 / 32 in FEMM
# [13:28:38] Solving time step 24 / 32 in FEMM
# [13:28:39] Solving time step 4 / 32 in FEMM
# [13:28:40] Solving time step 32 / 32 in FEMM
# [13:28:41] Solving time step 28 / 32 in FEMM
# [13:28:45] Starting Force module
# [13:28:45] Parameter Sweep Results: N0=2000 [rpm], Id=0 [Arms], Iq=0 [Arms], Tem_av=-1.224e-05 [N.m], Tem_rip_pp=0.8023 [N.m], Tem_rip_norm=-6.555e+04 [-], Pem_av=-0.002563 [W]
# [======================================            ]  77%
# [13:28:45] Running simulation 7/8 with W0s=0.0023435714
# [13:28:45] Starting Magnetic module
# [13:28:46] Solving time step 5 / 32 in FEMM
# [13:28:46] Solving time step 1 / 32 in FEMM
# [13:28:47] Solving time step 9 / 32 in FEMM
# [13:28:47] Solving time step 13 / 32 in FEMM
# [13:28:47] Solving time step 25 / 32 in FEMM
# [13:28:48] Solving time step 21 / 32 in FEMM
# [13:28:48] Solving time step 29 / 32 in FEMM
# [13:28:49] Solving time step 17 / 32 in FEMM
# [13:28:55] Solving time step 6 / 32 in FEMM
# [13:28:55] Solving time step 2 / 32 in FEMM
# [13:28:55] Solving time step 10 / 32 in FEMM
# [13:28:55] Solving time step 14 / 32 in FEMM
# [13:28:56] Solving time step 22 / 32 in FEMM
# [13:28:56] Solving time step 26 / 32 in FEMM
# [13:28:56] Solving time step 30 / 32 in FEMM
# [13:28:57] Solving time step 18 / 32 in FEMM
# [13:29:00] Solving time step 7 / 32 in FEMM
# [13:29:00] Solving time step 3 / 32 in FEMM
# [13:29:01] Solving time step 11 / 32 in FEMM
# [13:29:01] Solving time step 15 / 32 in FEMM
# [13:29:02] Solving time step 27 / 32 in FEMM
# [13:29:02] Solving time step 23 / 32 in FEMM
# [13:29:02] Solving time step 31 / 32 in FEMM
# [13:29:03] Solving time step 19 / 32 in FEMM
# [13:29:06] Solving time step 8 / 32 in FEMM
# [13:29:06] Solving time step 4 / 32 in FEMM
# [13:29:07] Solving time step 12 / 32 in FEMM
# [13:29:07] Solving time step 16 / 32 in FEMM
# [13:29:08] Solving time step 28 / 32 in FEMM
# [13:29:08] Solving time step 24 / 32 in FEMM
# [13:29:08] Solving time step 32 / 32 in FEMM
# [13:29:09] Solving time step 20 / 32 in FEMM
# [13:29:14] Starting Force module
# [13:29:14] Parameter Sweep Results: N0=2000 [rpm], Id=0 [Arms], Iq=0 [Arms], Tem_av=0.001303 [N.m], Tem_rip_pp=0.9336 [N.m], Tem_rip_norm=716.4 [-], Pem_av=0.2729 [W]
# [============================================      ]  88%
# [13:29:14] Running simulation 8/8 with W0s=0.002702
# [13:29:14] Starting Magnetic module
# [13:29:15] Solving time step 5 / 32 in FEMM
# [13:29:15] Solving time step 9 / 32 in FEMM
# [13:29:15] Solving time step 1 / 32 in FEMM
# [13:29:16] Solving time step 21 / 32 in FEMM
# [13:29:16] Solving time step 17 / 32 in FEMM
# [13:29:17] Solving time step 13 / 32 in FEMM
# [13:29:17] Solving time step 29 / 32 in FEMM
# [13:29:18] Solving time step 25 / 32 in FEMM
# [13:29:23] Solving time step 6 / 32 in FEMM
# [13:29:23] Solving time step 10 / 32 in FEMM
# [13:29:24] Solving time step 22 / 32 in FEMM
# [13:29:24] Solving time step 2 / 32 in FEMM
# [13:29:24] Solving time step 18 / 32 in FEMM
# [13:29:25] Solving time step 14 / 32 in FEMM
# [13:29:25] Solving time step 30 / 32 in FEMM
# [13:29:26] Solving time step 26 / 32 in FEMM
# [13:29:29] Solving time step 7 / 32 in FEMM
# [13:29:29] Solving time step 11 / 32 in FEMM
# [13:29:30] Solving time step 23 / 32 in FEMM
# [13:29:30] Solving time step 3 / 32 in FEMM
# [13:29:30] Solving time step 19 / 32 in FEMM
# [13:29:31] Solving time step 15 / 32 in FEMM
# [13:29:31] Solving time step 31 / 32 in FEMM
# [13:29:31] Solving time step 27 / 32 in FEMM
# [13:29:34] Solving time step 8 / 32 in FEMM
# [13:29:35] Solving time step 12 / 32 in FEMM
# [13:29:35] Solving time step 4 / 32 in FEMM
# [13:29:35] Solving time step 24 / 32 in FEMM
# [13:29:36] Solving time step 20 / 32 in FEMM
# [13:29:36] Solving time step 16 / 32 in FEMM
# [13:29:37] Solving time step 32 / 32 in FEMM
# [13:29:37] Solving time step 28 / 32 in FEMM
# [13:29:42] Starting Force module
# [13:29:42] Parameter Sweep Results: N0=2000 [rpm], Id=0 [Arms], Iq=0 [Arms], Tem_av=0.00337 [N.m], Tem_rip_pp=1.161 [N.m], Tem_rip_norm=344.6 [-], Pem_av=0.7059 [W]
# [==================================================] 100%
# [13:29:42] End of simulation slot_opening

# %% [markdown]
# The log of the simulation enables to understand step by step the status of the computation. As expected, the reference simulation is computed first (which is still on a single operating point). Then, each of the 8 simulations (ref W0s in not in the value list) is run on the same operating point with a different value for the stator slot opening displayed as:
#
# **Running simulation 7/8 with W0s=0.0020127143**
#
# And ending with the datakeepers result for this simulation:
#
# **Parameter Sweep Results: N0=2000 [rpm], Id=-135.4 [Arms], Iq=113.6 [Arms], Tem_av=353.8 [N.m], Tem_rip_pp=82.94 [N.m], Tem_rip_norm=0.2344 [-]**
#
# When is_keep_all_output is True, the reference output is either stored in the output_list if one of the N simulation matches the reference one or in xoutput_ref otherwise

# %%
print("Xout_sweep.xoutput_ref:" +str(type(Xout_sweep.xoutput_ref)))
# Xout_sweep.output_list[1].simu.machine.stator.slot.plot()
# Xout_sweep.output_list[5].simu.machine.stator.slot.plot()

Xout_sweep[1].force.AGSF.plot_3D_Data(
    "freqs->mech_order=[0,96*2]",
    "wavenumber=[-48,48]",
    N_stem=100,

)
Xout_sweep[6].force.AGSF.plot_3D_Data(
    "freqs->mech_order=[0,96*2]",
    "wavenumber=[-48,48]",
    N_stem=100,

)
# Out:
# Xout_sweep.xoutput_ref:<class 'pyleecan.Classes.Output.Output'>

# %%
print("Xout_sweep.xoutput_ref:" +str(type(Xout_sweep.xoutput_ref)))
print("Xout_sweep.xoutput_ref_index:" +str(Xout_sweep.xoutput_ref_index))
print("\nXout_vop.xoutput_ref:" +str(Xout_vop.xoutput_ref))
print("Xout_vop.xoutput_ref_index:" +str(Xout_vop.xoutput_ref_index))

# A function enables to acces the reference output in all the cases
xoutput_ref = Xout_sweep.get_xoutput_ref()
# Out:
# Xout_sweep.xoutput_ref:<class 'pyleecan.Classes.Output.Output'>
# Xout_sweep.xoutput_ref_index:None
#
# Xout_vop.xoutput_ref:parent = <class 'pyleecan.Classes.XOutput.XOutput'> object
# simu = parent = <class 'pyleecan.Classes.Output.Output'> object
# 	name = "tuto_multi"
# 	desc = ""
# 	machine = parent = <class 'pyleecan.Classes.Simu1.Simu1'> object
# 		frame = None
#
# 		shaft = parent = <class 'pyleecan.Classes.MachineIPMSM.MachineIPMSM'> object
# 			Lshaft = 0.1
# 			mat_type = parent = <class 'pyleecan.Classes.Shaft.Shaft'> object
# 				name = "M400-50A"
# 				is_isotropic = False
# 				elec = parent = <class 'pyleecan.Classes.Material.Material'> object
# 					rho = 1
# 					epsr = 1
# 					alpha = 1
# 				mag = parent = <class 'pyleecan.Classes.Material.Material'> object
# 					mur_lin = 2500.0
# 					Hc = 0
# 					Brm20 = 0
# 					alpha_Br = 0
# 					Wlam = 0.0005
# 					BH_curve = parent = <class 'pyleecan.Classes.MatMagnetics.MatMagnetics'> object
# 						is_transpose = False
# 						value =
# 						[[0.000e+00 0.000e+00]
#  [1.000e+02 5.000e-01]
#  [1.500e+02 7.000e-01]
#  [1.800e+02 8.000e-01]
#  [2.000e+02 9.000e-01]
#  [2.500e+02 1.000e+00]
#  [3.000e+02 1.050e+00]
#  [3.500e+02 1.100e+00]
#  [4.500e+02 1.150e+00]
#  [5.500e+02 1.200e+00]
#  [6.500e+02 1.225e+00]
#  [7.500e+02 1.250e+00]
#  [8.500e+02 1.275e+00]
#  [9.500e+02 1.300e+00]
#  [1.100e+03 1.325e+00]
#  [1.250e+03 1.350e+00]
#  [1.400e+03 1.375e+00]
#  [1.550e+03 1.400e+00]
#  [1.700e+03 1.425e+00]
#  [1.900e+03 1.450e+00]
#  [2.150e+03 1.475e+00]
#  [2.450e+03 1.500e+00]
#  [2.750e+03 1.525e+00]
#  [3.150e+03 1.550e+00]
#  [3.600e+03 1.575e+00]
#  [4.100e+03 1.600e+00]
#  [4.700e+03 1.625e+00]
#  [5.250e+03 1.650e+00]
#  [6.000e+03 1.675e+00]
#  [6.700e+03 1.700e+00]
#  [7.500e+03 1.725e+00]
#  [8.650e+03 1.750e+00]
#  [9.500e+03 1.775e+00]
#  [1.075e+04 1.800e+00]
#  [1.450e+04 1.850e+00]
#  [1.950e+04 1.900e+00]
#  [2.500e+04 1.950e+00]
#  [3.300e+04 2.000e+00]
#  [4.400e+04 2.050e+00]
#  [5.700e+04 2.100e+00]
#  [7.400e+04 2.150e+00]
#  [9.600e+04 2.200e+00]
#  [1.300e+05 2.250e+00]
#  [1.700e+05 2.300e+00]]
#
# 					LossData = parent = <class 'pyleecan.Classes.MatMagnetics.MatMagnetics'> object
# 						is_transpose = False
# 					ModelBH = parent = <class 'pyleecan.Classes.MatMagnetics.MatMagnetics'> object
# 						Bmax = 2.31
# 						Hmax = None
# 						delta = 100
# 					is_BH_extrapolate = False
# 				struct = parent = <class 'pyleecan.Classes.Material.Material'> object
# 					rho = 7650.0
# 					Ex = 215000000000.0
# 					Ey = 215000000000.0
# 					Ez = 80000000000.0
# 					nu_xy = 0.3
# 					nu_xz = 0.03
# 					nu_yz = 0.03
# 					Gxz = 2000000000.0
# 					Gxy = 0.0
# 					Gyz = 2000000000.0
# 				HT = parent = <class 'pyleecan.Classes.Material.Material'> object
# 					lambda_x = 1
# 					lambda_y = 1
# 					lambda_z = 1
# 					Cp = 1
# 					alpha = 0.00393
# 				eco = parent = <class 'pyleecan.Classes.Material.Material'> object
# 					cost_unit = 0.127
# 					unit_name = "$"
# 				desc = "Lamination M400-50A"
# 				path = "M400-50A.json"
# 			Drsh = 0.11064
# 		name = "Toyota_Prius"
# 		desc = "TOYOTA Prius 2004 interior magnet (V shape) with distributed winding"
# 		type_machine = 1
# 		logger_name = "tuto_multi.Machine"
# 		rotor = parent = <class 'pyleecan.Classes.MachineIPMSM.MachineIPMSM'> object
# 			L1 = 0.08382
# 			mat_type = parent = <class 'pyleecan.Classes.LamHole.LamHole'> object
# 				name = "M400-50A"
# 				is_isotropic = False
# 				elec = parent = <class 'pyleecan.Classes.Material.Material'> object
# 					rho = 1
# 					epsr = 1
# 					alpha = 1
# 				mag = parent = <class 'pyleecan.Classes.Material.Material'> object
# 					mur_lin = 2500.0
# 					Hc = 0
# 					Brm20 = 0
# 					alpha_Br = 0
# 					Wlam = 0.0005
# 					BH_curve = parent = <class 'pyleecan.Classes.MatMagnetics.MatMagnetics'> object
# 						is_transpose = False
# 						value =
# 						[[0.000e+00 0.000e+00]
#  [1.000e+02 5.000e-01]
#  [1.500e+02 7.000e-01]
#  [1.800e+02 8.000e-01]
#  [2.000e+02 9.000e-01]
#  [2.500e+02 1.000e+00]
#  [3.000e+02 1.050e+00]
#  [3.500e+02 1.100e+00]
#  [4.500e+02 1.150e+00]
#  [5.500e+02 1.200e+00]
#  [6.500e+02 1.225e+00]
#  [7.500e+02 1.250e+00]
#  [8.500e+02 1.275e+00]
#  [9.500e+02 1.300e+00]
#  [1.100e+03 1.325e+00]
#  [1.250e+03 1.350e+00]
#  [1.400e+03 1.375e+00]
#  [1.550e+03 1.400e+00]
#  [1.700e+03 1.425e+00]
#  [1.900e+03 1.450e+00]
#  [2.150e+03 1.475e+00]
#  [2.450e+03 1.500e+00]
#  [2.750e+03 1.525e+00]
#  [3.150e+03 1.550e+00]
#  [3.600e+03 1.575e+00]
#  [4.100e+03 1.600e+00]
#  [4.700e+03 1.625e+00]
#  [5.250e+03 1.650e+00]
#  [6.000e+03 1.675e+00]
#  [6.700e+03 1.700e+00]
#  [7.500e+03 1.725e+00]
#  [8.650e+03 1.750e+00]
#  [9.500e+03 1.775e+00]
#  [1.075e+04 1.800e+00]
#  [1.450e+04 1.850e+00]
#  [1.950e+04 1.900e+00]
#  [2.500e+04 1.950e+00]
#  [3.300e+04 2.000e+00]
#  [4.400e+04 2.050e+00]
#  [5.700e+04 2.100e+00]
#  [7.400e+04 2.150e+00]
#  [9.600e+04 2.200e+00]
#  [1.300e+05 2.250e+00]
#  [1.700e+05 2.300e+00]]
#
# 					LossData = parent = <class 'pyleecan.Classes.MatMagnetics.MatMagnetics'> object
# 						is_transpose = False
# 					ModelBH = parent = <class 'pyleecan.Classes.MatMagnetics.MatMagnetics'> object
# 						Bmax = 2.31
# 						Hmax = None
# 						delta = 100
# 					is_BH_extrapolate = False
# 				struct = parent = <class 'pyleecan.Classes.Material.Material'> object
# 					rho = 7650.0
# 					Ex = 215000000000.0
# 					Ey = 215000000000.0
# 					Ez = 80000000000.0
# 					nu_xy = 0.3
# 					nu_xz = 0.03
# 					nu_yz = 0.03
# 					Gxz = 2000000000.0
# 					Gxy = 0.0
# 					Gyz = 2000000000.0
# 				HT = parent = <class 'pyleecan.Classes.Material.Material'> object
# 					lambda_x = 1
# 					lambda_y = 1
# 					lambda_z = 1
# 					Cp = 1
# 					alpha = 0.00393
# 				eco = parent = <class 'pyleecan.Classes.Material.Material'> object
# 					cost_unit = 0.127
# 					unit_name = "$"
# 				desc = "Lamination M400-50A"
# 				path = "M400-50A.json"
# 			Nrvd = 0
# 			Wrvd = 0
# 			Kf1 = 0.95
# 			is_internal = True
# 			Rint = 0.05532
# 			Rext = 0.0802
# 			is_stator = False
# 			axial_vent = []
# 			notch = []
# 			skew = None
#
# 			yoke_notch = []
# 			bore = None
#
# 			hole[0] =parent = <class 'pyleecan.Classes.LamHole.LamHole'> object
# 				Zh = 8
# 				mat_void = parent = <class 'pyleecan.Classes.HoleM50.HoleM50'> object
# 					name = "Air"
# 					is_isotropic = True
# 					elec = parent = <class 'pyleecan.Classes.Material.Material'> object
# 						rho = 1
# 						epsr = 1
# 						alpha = 1
# 					mag = parent = <class 'pyleecan.Classes.Material.Material'> object
# 						mur_lin = 1
# 						Hc = 0
# 						Brm20 = 0
# 						alpha_Br = 0
# 						Wlam = 0
# 						BH_curve = parent = <class 'pyleecan.Classes.MatMagnetics.MatMagnetics'> object
# 							is_transpose = False
# 						LossData = parent = <class 'pyleecan.Classes.MatMagnetics.MatMagnetics'> object
# 							is_transpose = False
# 						ModelBH = parent = <class 'pyleecan.Classes.MatMagnetics.MatMagnetics'> object
# 							Bmax = 2.31
# 							Hmax = None
# 							delta = 100
# 						is_BH_extrapolate = False
# 					struct = parent = <class 'pyleecan.Classes.Material.Material'> object
# 						rho = 1.2044
# 						Ex = 215000000000.0
# 						Ey = 215000000000.0
# 						Ez = 80000000000
# 						nu_xy = 0.3
# 						nu_xz = 0.03
# 						nu_yz = 0.03
# 						Gxz = 2000000000
# 						Gxy = 0
# 						Gyz = 2000000000
# 					HT = parent = <class 'pyleecan.Classes.Material.Material'> object
# 						lambda_x = 0.0257
# 						lambda_y = 0.0257
# 						lambda_z = 0.0257
# 						Cp = 1007
# 						alpha = 0.00343
# 					eco = parent = <class 'pyleecan.Classes.Material.Material'> object
# 						cost_unit = 0.127
# 						unit_name = "$"
# 					desc = "Air"
# 					path = ""
# 				magnetization_dict_offset = None
# 				Alpha0 = 0
# 				H0 = 0.01096
# 				W0 = 0.042
# 				H1 = 0.0015
# 				W1 = 0
# 				H2 = 0.001
# 				W2 = 0
# 				H3 = 0.0065
# 				W3 = 0.014
# 				H4 = 0
# 				W4 = 0.0189
# 				magnet_0 = parent = <class 'pyleecan.Classes.HoleM50.HoleM50'> object
# 					mat_type = parent = <class 'pyleecan.Classes.Magnet.Magnet'> object
# 						name = "MagnetPrius"
# 						is_isotropic = True
# 						elec = parent = <class 'pyleecan.Classes.Material.Material'> object
# 							rho = 1.6e-06
# 							epsr = None
# 							alpha = 1
# 						mag = parent = <class 'pyleecan.Classes.Material.Material'> object
# 							mur_lin = 1.05
# 							Hc = 902181.163126629
# 							Brm20 = 1.24
# 							alpha_Br = -0.001
# 							Wlam = 0
# 							BH_curve = parent = <class 'pyleecan.Classes.MatMagnetics.MatMagnetics'> object
# 								is_transpose = False
# 							LossData = parent = <class 'pyleecan.Classes.MatMagnetics.MatMagnetics'> object
# 								is_transpose = False
# 							ModelBH = parent = <class 'pyleecan.Classes.MatMagnetics.MatMagnetics'> object
# 								Bmax = 2.31
# 								Hmax = None
# 								delta = 100
# 							is_BH_extrapolate = False
# 						struct = parent = <class 'pyleecan.Classes.Material.Material'> object
# 							rho = 7500.0
# 							Ex = 15500000000
# 							Ey = None
# 							Ez = None
# 							nu_xy = 0.3
# 							nu_xz = None
# 							nu_yz = None
# 							Gxz = None
# 							Gxy = None
# 							Gyz = None
# 						HT = parent = <class 'pyleecan.Classes.Material.Material'> object
# 							lambda_x = 8.5
# 							lambda_y = 8.5
# 							lambda_z = 8.5
# 							Cp = 450.0
# 							alpha = None
# 						eco = parent = <class 'pyleecan.Classes.Material.Material'> object
# 							cost_unit = 252.0
# 							unit_name = "$"
# 						desc = "MAGNET1 for SIPMSM"
# 						path = "MagnetPrius.json"
# 					type_magnetization = 1
# 					Lmag = 0.08382
# 				magnet_1 = parent = <class 'pyleecan.Classes.HoleM50.HoleM50'> object
# 					mat_type = parent = <class 'pyleecan.Classes.Magnet.Magnet'> object
# 						name = "MagnetPrius"
# 						is_isotropic = True
# 						elec = parent = <class 'pyleecan.Classes.Material.Material'> object
# 							rho = 1.6e-06
# 							epsr = None
# 							alpha = 1
# 						mag = parent = <class 'pyleecan.Classes.Material.Material'> object
# 							mur_lin = 1.05
# 							Hc = 902181.163126629
# 							Brm20 = 1.24
# 							alpha_Br = -0.001
# 							Wlam = 0
# 							BH_curve = parent = <class 'pyleecan.Classes.MatMagnetics.MatMagnetics'> object
# 								is_transpose = False
# 							LossData = parent = <class 'pyleecan.Classes.MatMagnetics.MatMagnetics'> object
# 								is_transpose = False
# 							ModelBH = parent = <class 'pyleecan.Classes.MatMagnetics.MatMagnetics'> object
# 								Bmax = 2.31
# 								Hmax = None
# 								delta = 100
# 							is_BH_extrapolate = False
# 						struct = parent = <class 'pyleecan.Classes.Material.Material'> object
# 							rho = 7500.0
# 							Ex = 15500000000
# 							Ey = None
# 							Ez = None
# 							nu_xy = 0.3
# 							nu_xz = None
# 							nu_yz = None
# 							Gxz = None
# 							Gxy = None
# 							Gyz = None
# 						HT = parent = <class 'pyleecan.Classes.Material.Material'> object
# 							lambda_x = 8.5
# 							lambda_y = 8.5
# 							lambda_z = 8.5
# 							Cp = 450.0
# 							alpha = None
# 						eco = parent = <class 'pyleecan.Classes.Material.Material'> object
# 							cost_unit = 252.0
# 							unit_name = "$"
# 						desc = "MAGNET1 for SIPMSM"
# 						path = "MagnetPrius.json"
# 					type_magnetization = 1
# 					Lmag = 0.08382
#
#
#
# 		stator = parent = <class 'pyleecan.Classes.MachineIPMSM.MachineIPMSM'> object
# 			L1 = 0.08382
# 			mat_type = parent = <class 'pyleecan.Classes.LamSlotWind.LamSlotWind'> object
# 				name = "M400-50A"
# 				is_isotropic = False
# 				elec = parent = <class 'pyleecan.Classes.Material.Material'> object
# 					rho = 1
# 					epsr = 1
# 					alpha = 1
# 				mag = parent = <class 'pyleecan.Classes.Material.Material'> object
# 					mur_lin = 2500.0
# 					Hc = 0
# 					Brm20 = 0
# 					alpha_Br = 0
# 					Wlam = 0.0005
# 					BH_curve = parent = <class 'pyleecan.Classes.MatMagnetics.MatMagnetics'> object
# 						is_transpose = False
# 						value =
# 						[[0.000e+00 0.000e+00]
#  [1.000e+02 5.000e-01]
#  [1.500e+02 7.000e-01]
#  [1.800e+02 8.000e-01]
#  [2.000e+02 9.000e-01]
#  [2.500e+02 1.000e+00]
#  [3.000e+02 1.050e+00]
#  [3.500e+02 1.100e+00]
#  [4.500e+02 1.150e+00]
#  [5.500e+02 1.200e+00]
#  [6.500e+02 1.225e+00]
#  [7.500e+02 1.250e+00]
#  [8.500e+02 1.275e+00]
#  [9.500e+02 1.300e+00]
#  [1.100e+03 1.325e+00]
#  [1.250e+03 1.350e+00]
#  [1.400e+03 1.375e+00]
#  [1.550e+03 1.400e+00]
#  [1.700e+03 1.425e+00]
#  [1.900e+03 1.450e+00]
#  [2.150e+03 1.475e+00]
#  [2.450e+03 1.500e+00]
#  [2.750e+03 1.525e+00]
#  [3.150e+03 1.550e+00]
#  [3.600e+03 1.575e+00]
#  [4.100e+03 1.600e+00]
#  [4.700e+03 1.625e+00]
#  [5.250e+03 1.650e+00]
#  [6.000e+03 1.675e+00]
#  [6.700e+03 1.700e+00]
#  [7.500e+03 1.725e+00]
#  [8.650e+03 1.750e+00]
#  [9.500e+03 1.775e+00]
#  [1.075e+04 1.800e+00]
#  [1.450e+04 1.850e+00]
#  [1.950e+04 1.900e+00]
#  [2.500e+04 1.950e+00]
#  [3.300e+04 2.000e+00]
#  [4.400e+04 2.050e+00]
#  [5.700e+04 2.100e+00]
#  [7.400e+04 2.150e+00]
#  [9.600e+04 2.200e+00]
#  [1.300e+05 2.250e+00]
#  [1.700e+05 2.300e+00]]
#
# 					LossData = parent = <class 'pyleecan.Classes.MatMagnetics.MatMagnetics'> object
# 						is_transpose = False
# 					ModelBH = parent = <class 'pyleecan.Classes.MatMagnetics.MatMagnetics'> object
# 						Bmax = 2.31
# 						Hmax = None
# 						delta = 100
# 					is_BH_extrapolate = False
# 				struct = parent = <class 'pyleecan.Classes.Material.Material'> object
# 					rho = 7650.0
# 					Ex = 215000000000.0
# 					Ey = 215000000000.0
# 					Ez = 80000000000.0
# 					nu_xy = 0.3
# 					nu_xz = 0.03
# 					nu_yz = 0.03
# 					Gxz = 2000000000.0
# 					Gxy = 0.0
# 					Gyz = 2000000000.0
# 				HT = parent = <class 'pyleecan.Classes.Material.Material'> object
# 					lambda_x = 1
# 					lambda_y = 1
# 					lambda_z = 1
# 					Cp = 1
# 					alpha = 0.00393
# 				eco = parent = <class 'pyleecan.Classes.Material.Material'> object
# 					cost_unit = 0.127
# 					unit_name = "$"
# 				desc = "Lamination M400-50A"
# 				path = "M400-50A.json"
# 			Nrvd = 0
# 			Wrvd = 0
# 			Kf1 = 0.95
# 			is_internal = False
# 			Rint = 0.08095
# 			Rext = 0.13462
# 			is_stator = True
# 			axial_vent = []
# 			notch = []
# 			skew = None
#
# 			yoke_notch = []
# 			bore = None
#
# 			slot = parent = <class 'pyleecan.Classes.LamSlotWind.LamSlotWind'> object
# 				Zs = 48
# 				W0 = 0.00193
# 				H0 = 0.001
# 				H1 = 0
# 				H1_is_rad = False
# 				W1 = 0.005
# 				H2 = 0.0333
# 				W2 = 0.008
# 				R1 = 0.004
# 			Ksfill = None
# 			winding = parent = <class 'pyleecan.Classes.LamSlotWind.LamSlotWind'> object
# 				is_reverse_wind = False
# 				Nslot_shift_wind = 0
# 				qs = 3
# 				Ntcoil = 9
# 				Npcp = 1
# 				type_connection = 0
# 				p = 4
# 				Lewout = 0.019366
# 				conductor = parent = <class 'pyleecan.Classes.Winding.Winding'> object
# 					cond_mat = parent = <class 'pyleecan.Classes.CondType12.CondType12'> object
# 						name = "Copper1"
# 						is_isotropic = True
# 						elec = parent = <class 'pyleecan.Classes.Material.Material'> object
# 							rho = 1.73e-08
# 							epsr = None
# 							alpha = 1
# 						mag = None
#
# 						struct = parent = <class 'pyleecan.Classes.Material.Material'> object
# 							rho = 8900.0
# 							Ex = 115000000000.0
# 							Ey = 115000000000.0
# 							Ez = 115000000000.0
# 							nu_xy = None
# 							nu_xz = None
# 							nu_yz = None
# 							Gxz = None
# 							Gxy = None
# 							Gyz = None
# 						HT = parent = <class 'pyleecan.Classes.Material.Material'> object
# 							lambda_x = 385.0
# 							lambda_y = 385.0
# 							lambda_z = 385.0
# 							Cp = 381.0
# 							alpha = 0.00393
# 						eco = parent = <class 'pyleecan.Classes.Material.Material'> object
# 							cost_unit = 60.0
# 							unit_name = "$"
# 						desc = "COPPER WINDING"
# 						path = "Copper1.json"
# 					ins_mat = parent = <class 'pyleecan.Classes.CondType12.CondType12'> object
# 						name = "Insulator1"
# 						is_isotropic = True
# 						elec = parent = <class 'pyleecan.Classes.Material.Material'> object
# 							rho = None
# 							epsr = None
# 							alpha = 1
# 						mag = None
#
# 						struct = parent = <class 'pyleecan.Classes.Material.Material'> object
# 							rho = 1200.0
# 							Ex = None
# 							Ey = None
# 							Ez = None
# 							nu_xy = None
# 							nu_xz = None
# 							nu_yz = None
# 							Gxz = None
# 							Gxy = None
# 							Gyz = None
# 						HT = parent = <class 'pyleecan.Classes.Material.Material'> object
# 							lambda_x = 0.2
# 							lambda_y = 0.2
# 							lambda_z = 0.2
# 							Cp = 671.0
# 							alpha = None
# 						eco = parent = <class 'pyleecan.Classes.Material.Material'> object
# 							cost_unit = None
# 							unit_name = "$"
# 						desc = "INSULATOR1"
# 						path = "Insulator1.json"
# 					Wwire = 0.000912
# 					Wins_cond = 0.015
# 					Nwppc = 13
# 					Wins_wire = 1e-06
# 					Kwoh = 0.5
# 				coil_pitch = 6
# 				wind_mat =
# 				[[[[ 9.  0.  0.]
#    [ 9.  0.  0.]
#    [ 0.  0. -9.]
#    [ 0.  0. -9.]
#    [ 0.  9.  0.]
#    [ 0.  9.  0.]
#    [-9.  0.  0.]
#    [-9.  0.  0.]
#    [ 0.  0.  9.]
#    [ 0.  0.  9.]
#    [ 0. -9.  0.]
#    [ 0. -9.  0.]
#    [ 9.  0.  0.]
#    [ 9.  0.  0.]
#    [ 0.  0. -9.]
#    [ 0.  0. -9.]
#    [ 0.  9.  0.]
#    [ 0.  9.  0.]
#    [-9.  0.  0.]
#    [-9.  0.  0.]
#    [ 0.  0.  9.]
#    [ 0.  0.  9.]
#    [ 0. -9.  0.]
#    [ 0. -9.  0.]
#    [ 9.  0.  0.]
#    [ 9.  0.  0.]
#    [ 0.  0. -9.]
#    [ 0.  0. -9.]
#    [ 0.  9.  0.]
#    [ 0.  9.  0.]
#    [-9.  0.  0.]
#    [-9.  0.  0.]
#    [ 0.  0.  9.]
#    [ 0.  0.  9.]
#    [ 0. -9.  0.]
#    [ 0. -9.  0.]
#    [ 9.  0.  0.]
#    [ 9.  0.  0.]
#    [ 0.  0. -9.]
#    [ 0.  0. -9.]
#    [ 0.  9.  0.]
#    [ 0.  9.  0.]
#    [-9.  0.  0.]
#    [-9.  0.  0.]
#    [ 0.  0.  9.]
#    [ 0.  0.  9.]
#    [ 0. -9.  0.]
#    [ 0. -9.  0.]]]]
#
# 				Nlayer = 1
# 				per_a = 8
# 				is_aper_a = True
# 				end_winding = parent = <class 'pyleecan.Classes.Winding.Winding'> object
# 				is_reverse_layer = False
# 				is_change_layer = False
# 				is_permute_B_C = False
# 	input = parent = <class 'pyleecan.Classes.Simu1.Simu1'> object
# 		time = None
#
# 		angle = None
#
# 		Nt_tot = 128
# 		Nrev = None
# 		Na_tot = 2048
# 		OP = parent = <class 'pyleecan.Classes.OutElec.OutElec'> object
# 			N0 = 2000
# 			felec = 133.33333333333334
# 			Tem_av_ref = 353
# 			Pem_av_ref = None
# 			Id_ref = -135.4188051049254
# 			Iq_ref = 113.62986941801093
# 			Ud_ref = None
# 			Uq_ref = None
# 		rot_dir = -1
# 		angle_rotor_initial = 0.9149888603580274
# 		PWM = None
#
# 		phase_dir = -1
# 		current_dir = -1
# 		Is = None
#
# 		Ir = None
#
# 	logger_name = "tuto_multi"
# 	var_simu = None
#
# 	postproc_list = []
# 	index = None
# 	path_result = "None"
# 	layer = 1
# 	layer_log_warn = None
# 	elec = None
#
# 	mag = parent = <class 'pyleecan.Classes.Simu1.Simu1'> object
# 		is_remove_slotS = False
# 		is_remove_slotR = False
# 		is_remove_ventS = False
# 		is_remove_ventR = False
# 		is_mmfs = True
# 		is_mmfr = True
# 		type_BH_stator = 0
# 		type_BH_rotor = 0
# 		is_periodicity_t = True
# 		is_periodicity_a = True
# 		angle_stator_shift = 0.0
# 		angle_rotor_shift = 0.0
# 		logger_name = "tuto_multi.Magnetics"
# 		Slice_enforced = parent = <class 'pyleecan.Classes.OutMag.OutMag'> object
# 			type_distribution = "None"
# 			Nslices = 2
# 			z_list =
# 			[-0.04191, 0.04191]
# 			angle_rotor =
# 			[0. 0.]
#
# 			angle_stator =
# 			[0. 0.]
#
# 			L = 0.08382
# 			is_step = True
# 			is_skew = False
# 		Nslices_enforced = None
# 		type_distribution_enforced = "None"
# 		is_current_harm = True
# 		Kmesh_fineness = 1
# 		Kgeo_fineness = 1
# 		type_calc_leakage = 0
# 		file_name = ""
# 		FEMM_dict_enforced = {}
# 		is_get_meshsolution = False
# 		is_save_meshsolution_as_file = False
# 		is_sliding_band = True
# 		transform_list =
# 		[]
# 		rotor_dxf = None
#
# 		stator_dxf = None
#
# 		import_file = "None"
# 		is_close_femm = True
# 		nb_worker = 4
# 		Rag_enforced = None
# 		is_set_previous = True
# 	struct = None
#
# 	force = None
#
# 	loss = None
#
# path_result = "D:\GitHub\pyleecan-public\pyleecan\Results\tuto_multi"
# geo = parent = <class 'pyleecan.Classes.Output.Output'> object
# 	stator = parent = <class 'pyleecan.Classes.OutGeo.OutGeo'> object
# 		name_phase =
# 		['A', 'B', 'C']
# 		BH_curve =
# 		[[0.000e+00 0.000e+00]
#  [1.000e+02 5.000e-01]
#  [1.500e+02 7.000e-01]
#  [1.800e+02 8.000e-01]
#  [2.000e+02 9.000e-01]
#  [2.500e+02 1.000e+00]
#  [3.000e+02 1.050e+00]
#  [3.500e+02 1.100e+00]
#  [4.500e+02 1.150e+00]
#  [5.500e+02 1.200e+00]
#  [6.500e+02 1.225e+00]
#  [7.500e+02 1.250e+00]
#  [8.500e+02 1.275e+00]
#  [9.500e+02 1.300e+00]
#  [1.100e+03 1.325e+00]
#  [1.250e+03 1.350e+00]
#  [1.400e+03 1.375e+00]
#  [1.550e+03 1.400e+00]
#  [1.700e+03 1.425e+00]
#  [1.900e+03 1.450e+00]
#  [2.150e+03 1.475e+00]
#  [2.450e+03 1.500e+00]
#  [2.750e+03 1.525e+00]
#  [3.150e+03 1.550e+00]
#  [3.600e+03 1.575e+00]
#  [4.100e+03 1.600e+00]
#  [4.700e+03 1.625e+00]
#  [5.250e+03 1.650e+00]
#  [6.000e+03 1.675e+00]
#  [6.700e+03 1.700e+00]
#  [7.500e+03 1.725e+00]
#  [8.650e+03 1.750e+00]
#  [9.500e+03 1.775e+00]
#  [1.075e+04 1.800e+00]
#  [1.450e+04 1.850e+00]
#  [1.950e+04 1.900e+00]
#  [2.500e+04 1.950e+00]
#  [3.300e+04 2.000e+00]
#  [4.400e+04 2.050e+00]
#  [5.700e+04 2.100e+00]
#  [7.400e+04 2.150e+00]
#  [9.600e+04 2.200e+00]
#  [1.300e+05 2.250e+00]
#  [1.700e+05 2.300e+00]]
#
# 		Ksfill = 0.35452872589129897
# 		S_slot = 0.0002175053401956612
# 		S_slot_wind = 0.0002155827412287184
# 		S_wind_act = None
# 		per_a = None
# 		is_antiper_a = None
# 		per_t = None
# 		is_antiper_t = None
# 	rotor = parent = <class 'pyleecan.Classes.OutGeo.OutGeo'> object
# 		name_phase =
# 		[]
# 		BH_curve =
# 		[[0.000e+00 0.000e+00]
#  [1.000e+02 5.000e-01]
#  [1.500e+02 7.000e-01]
#  [1.800e+02 8.000e-01]
#  [2.000e+02 9.000e-01]
#  [2.500e+02 1.000e+00]
#  [3.000e+02 1.050e+00]
#  [3.500e+02 1.100e+00]
#  [4.500e+02 1.150e+00]
#  [5.500e+02 1.200e+00]
#  [6.500e+02 1.225e+00]
#  [7.500e+02 1.250e+00]
#  [8.500e+02 1.275e+00]
#  [9.500e+02 1.300e+00]
#  [1.100e+03 1.325e+00]
#  [1.250e+03 1.350e+00]
#  [1.400e+03 1.375e+00]
#  [1.550e+03 1.400e+00]
#  [1.700e+03 1.425e+00]
#  [1.900e+03 1.450e+00]
#  [2.150e+03 1.475e+00]
#  [2.450e+03 1.500e+00]
#  [2.750e+03 1.525e+00]
#  [3.150e+03 1.550e+00]
#  [3.600e+03 1.575e+00]
#  [4.100e+03 1.600e+00]
#  [4.700e+03 1.625e+00]
#  [5.250e+03 1.650e+00]
#  [6.000e+03 1.675e+00]
#  [6.700e+03 1.700e+00]
#  [7.500e+03 1.725e+00]
#  [8.650e+03 1.750e+00]
#  [9.500e+03 1.775e+00]
#  [1.075e+04 1.800e+00]
#  [1.450e+04 1.850e+00]
#  [1.950e+04 1.900e+00]
#  [2.500e+04 1.950e+00]
#  [3.300e+04 2.000e+00]
#  [4.400e+04 2.050e+00]
#  [5.700e+04 2.100e+00]
#  [7.400e+04 2.150e+00]
#  [9.600e+04 2.200e+00]
#  [1.300e+05 2.250e+00]
#  [1.700e+05 2.300e+00]]
#
# 		Ksfill = None
# 		S_slot = None
# 		S_slot_wind = None
# 		S_wind_act = None
# 		per_a = None
# 		is_antiper_a = None
# 		per_t = None
# 		is_antiper_t = None
# 	Wgap_mec = 0.0007500000000000007
# 	Wgap_mag = 0.0007500000000000007
# 	Rgap_mec = 0.080575
# 	Lgap = 0.08382
# 	logger_name = "Pyleecan.OutGeo"
# 	angle_rotor_initial = 0.9149888603580274
# 	rot_dir = -1
# 	per_a = 4
# 	is_antiper_a = True
# 	per_t_S = 4
# 	is_antiper_t_S = True
# 	axes_dict = {'time': <SciDataTool.Classes.DataLinspace.DataLinspace object at 0x0000012966D2CEE0>, 'angle': <SciDataTool.Classes.DataLinspace.DataLinspace object at 0x00000129669B20A0>}
#
# 	per_t_R = 4
# 	is_antiper_t_R = False
# elec = parent = <class 'pyleecan.Classes.Output.Output'> object
# 	axes_dict = {'time': <SciDataTool.Classes.DataLinspace.DataLinspace object at 0x00000129669B2220>, 'phase_Stator-0': <SciDataTool.Classes.Data1D.Data1D object at 0x00000129669B2250>}
#
# 	Is = parent = None
# 	symbol = "I_s"
# 	name = "Stator current"
# 	unit = "A"
# 	normalizations = dict()
# 	axes = [<SciDataTool.Classes.DataLinspace.DataLinspace object at 0x00000129669B2310>, <SciDataTool.Classes.Data1D.Data1D object at 0x00000129669B2250>]
#
# 	FTparameters = {}
# 	values =
# 	[[-191.51111078  234.9231552   -43.41204442]
#  [-156.48086805  247.09037762  -90.60950957]
#  [-115.43715331  249.7620554  -134.32490209]
#  [ -69.95725351  242.83551745 -172.87826395]
#  [ -21.78893569  226.57694676 -204.78801107]
#  [  27.21671871  201.61115107 -228.82786978]
#  [  75.17644988  168.8975519  -244.07400178]
#  [ 120.24719223  129.69331454 -249.94050677]
#  [ 160.69690242   85.50503583 -246.20193825]
#  [ 194.97112077   38.03084655 -233.00196732]
#  [ 221.75270829  -10.90484684 -210.84786145]
#  [ 240.0124636   -59.42147308 -180.59099051]
#  [ 249.04867452 -105.65456544 -143.39410909]
#  [ 248.51408456 -147.82741209 -100.68667246]
#  [ 238.42923769 -184.3193342   -54.10990348]
#  [ 219.18168893 -213.72796767   -5.45372126]]
#
# 	is_real = True
#
#
# 	Ir = None
#
# 	logger_name = "Pyleecan.Electrical"
# 	Pj_losses = None
# 	Us = None
#
# 	internal = None
#
# 	Us_PWM = None
#
# 	OP = parent = <class 'pyleecan.Classes.OutElec.OutElec'> object
# 		N0 = 2000
# 		felec = 133.33333333333334
# 		Tem_av_ref = 353
# 		Pem_av_ref = None
# 		Id_ref = -135.4188051049254
# 		Iq_ref = 113.62986941801093
# 		Ud_ref = None
# 		Uq_ref = None
# 	Pem_av_ref = None
# 	Tem_av_ref = None
# 	Is_harm = None
#
# 	phase_dir = -1
# 	current_dir = -1
# mag = parent = <class 'pyleecan.Classes.Output.Output'> object
# 	axes_dict = {'time': <SciDataTool.Classes.DataLinspace.DataLinspace object at 0x00000129669B2310>, 'angle': <SciDataTool.Classes.DataLinspace.DataLinspace object at 0x00000129669B2520>, 'z': <SciDataTool.Classes.DataPattern.DataPattern object at 0x00000129669B24C0>, 'time_Tem': <SciDataTool.Classes.DataLinspace.DataLinspace object at 0x00000129669B2490>}
#
# 	B = parent = None
# 	name = "Airgap flux density"
# 	symbol = "B"
# 	components = {'radial': <SciDataTool.Classes.DataTime.DataTime object at 0x00000129669B26D0>, 'tangential': <SciDataTool.Classes.DataTime.DataTime object at 0x00000129669B27C0>}
#
#
#
# 	Tem = parent = None
# 	symbol = "T_{em}"
# 	name = "Electromagnetic torque"
# 	unit = "Nm"
# 	normalizations = dict()
# 	axes = [<SciDataTool.Classes.DataLinspace.DataLinspace object at 0x00000129669BA130>]
#
# 	FTparameters = {}
# 	values =
# 	[394.14438979 325.31895614 367.79221479 340.38661417 332.34562852
#  402.71573024 333.37066243 345.71271835 366.62085138 319.67355885
#  389.08028079 360.34653031 329.76753327 376.10009538 317.31620417
#  358.31498773]
#
# 	is_real = True
#
#
# 	Tem_av = 353.6879347693815
# 	Tem_rip_norm = 0.24145445086204817
# 	Tem_rip_pp = 85.39952606627293
# 	Phi_wind_stator = parent = <class 'pyleecan.Classes.OutMag.OutMag'> object
# 	symbol = "Phi_{wind}"
# 	name = "Stator Winding Flux"
# 	unit = "Wb"
# 	normalizations = dict()
# 	axes = [<SciDataTool.Classes.DataLinspace.DataLinspace object at 0x00000129669BAEB0>, <SciDataTool.Classes.Data1D.Data1D object at 0x00000129669BAF70>]
#
# 	FTparameters = {}
# 	values =
# 	[[-0.03023377  0.31243808 -0.24794098]
#  [ 0.03552911  0.26070145 -0.30950081]
#  [ 0.09025938  0.20457384 -0.33997941]
#  [ 0.15100558  0.14470655 -0.35222978]
#  [ 0.20125172  0.09323944 -0.35250886]
#  [ 0.23031692  0.05015546 -0.32718281]
#  [ 0.29088792 -0.01458913 -0.27853842]
#  [ 0.33419333 -0.07303554 -0.22328668]
#  [ 0.34822573 -0.1292013  -0.16479762]
#  [ 0.3550768  -0.18793116 -0.10875597]
#  [ 0.33858621 -0.21934082 -0.06559525]
#  [ 0.29556099 -0.26979477 -0.00738565]
#  [ 0.24194617 -0.32420233  0.05519892]
#  [ 0.18484758 -0.3439788   0.10859188]
#  [ 0.12600533 -0.35488774  0.17100382]
#  [ 0.07951533 -0.34726828  0.21089165]]
#
# 	is_real = True
#
#
# 	Phi_wind = {'Stator-0': <SciDataTool.Classes.DataTime.DataTime object at 0x00000129669BABE0>}
#
# 	emf = None
#
# 	meshsolution = parent = <class 'pyleecan.Classes.OutMag.OutMag'> object
# 		label = ""
# 		mesh = []
# 		is_same_mesh = True
# 		solution = []
# 		group = None
# 		dimension = 2
# 		path = "None"
# 	logger_name = "tuto_multi.Magnetics"
# 	internal = parent = <class 'pyleecan.Classes.OutMag.OutMag'> object
# 		FEMM_dict = {'is_close_model': 0, 'acsolver': 0, 'pbtype': 'planar', 'precision': 1e-08, 'minangle': 15, 'freqpb': 0, 'smart_mesh': 0, 'automesh': 0, 'automesh_airgap': 0, 'automesh_segments': 0, 'maxsegdeg': 1, 'maxelementsize': 1, 'arcspan': 1.0, 'Lfemm': 1, 'meshsize_slotS': 0.004286780992830325, 'elementsize_slotS': 0.004286780992830325, 'meshsize_yokeS': 0.004843938014339348, 'elementsize_yokeS': 0.004843938014339348, 'meshsize_slotR': 0.0019374401600209274, 'elementsize_slotR': 0.0019374401600209274, 'meshsize_yokeR': 0.0019374401600209274, 'elementsize_yokeR': 0.0019374401600209274, 'meshsize_airgap': 0.0002500000000000002, 'elementsize_airgap': 0.0002500000000000002, 'meshsize_magnetS': None, 'meshsize_magnetR': 0.00390755983997907, 'elementsize_magnetR': 0.00390755983997907, 'meshsize_air': 0.0019374401600209274, 'meshsize_wedge': 0.00171471239713213, 'groups': {'GROUP_AG': 0, 'GROUP_AGM': 1, 'GROUP_SC': 10, 'GROUP_SW': 11, 'GROUP_SM': 12, 'GROUP_SN': 13, 'GROUP_SV': 14, 'GROUP_SSI': 15, 'GROUP_SH': 16, 'GROUP_RC': 20, 'GROUP_RW': 21, 'GROUP_RM': 22, 'GROUP_RN': 23, 'GROUP_RV': 24, 'GROUP_RSI': 25, 'GROUP_RH': 26, 'GROUP_IN': 30, 'GROUP_FM': 31, 'GROUP_FR': 32}, 'path_save': 'D:\\GitHub\\pyleecan-public\\pyleecan\\Results\\tuto_multi\\Femm\\Toyota_Prius_model.fem', 'materials': ['Airgap', 'Rotor-0 Iron', 'Air', 'MagnetPrius', 'Stator-0 Iron', 'Js0+', 'Js2-', 'Js1+'], 'circuits': ['Circs0', 'Circs2', 'Circs1']}
# 		handler_list[0] =<pyleecan.Classes._FEMMHandler._FEMMHandler object at 0x00000129669BA070>
#
#
# 		handler_list[1] =<pyleecan.Classes._FEMMHandler._FEMMHandler object at 0x00000129669BAD30>
#
#
# 		handler_list[2] =<pyleecan.Classes._FEMMHandler._FEMMHandler object at 0x00000129669BABB0>
#
#
# 		handler_list[3] =<pyleecan.Classes._FEMMHandler._FEMMHandler object at 0x00000129669BAF40>
#
#
# 	Rag = 0.080575
# 	Pem_av = 74076.22783565566
# 	Slice = parent = <class 'pyleecan.Classes.OutMag.OutMag'> object
# 		type_distribution = "None"
# 		Nslices = 2
# 		z_list =
# 		[-0.04191, 0.04191]
# 		angle_rotor =
# 		[0. 0.]
#
# 		angle_stator =
# 		[0. 0.]
#
# 		L = 0.08382
# 		is_step = True
# 		is_skew = False
# 	Tem_slice = parent = None
# 	symbol = "T_{em}"
# 	name = "Electromagnetic torque (axial density)"
# 	unit = "N"
# 	normalizations = dict()
# 	axes = [<SciDataTool.Classes.DataLinspace.DataLinspace object at 0x00000129669B2490>, <SciDataTool.Classes.DataPattern.DataPattern object at 0x00000129669B24C0>]
#
# 	FTparameters = {}
# 	values =
# 	[[4702.27141248]
#  [3881.16149061]
#  [4387.88135045]
#  [4060.92357634]
#  [3964.99198897]
#  [4804.53030586]
#  [3977.2209787 ]
#  [4124.46574023]
#  [4373.90660205]
#  [3813.81005545]
#  [4641.85493668]
#  [4299.05190056]
#  [3934.23446988]
#  [4486.99708161]
#  [3785.68604355]
#  [4274.81493355]]
#
# 	is_real = True
#
#
# 	Phi_wind_slice = {'Stator-0': <SciDataTool.Classes.DataTime.DataTime object at 0x00000129669BA1F0>}
#
# struct = parent = <class 'pyleecan.Classes.Output.Output'> object
# 	axes_dict = None
#
# 	logger_name = "tuto_multi.Structural"
# 	meshsolution = parent = <class 'pyleecan.Classes.OutStruct.OutStruct'> object
# 		label = ""
# 		mesh = []
# 		is_same_mesh = True
# 		solution = []
# 		group = None
# 		dimension = 2
# 		path = "None"
# 	FEA_dict = None
# post = parent = <class 'pyleecan.Classes.Output.Output'> object
# 	legend_name = ""
# 	line_color = ""
# logger_name = "tuto_multi"
# force = parent = <class 'pyleecan.Classes.Output.Output'> object
# 	axes_dict = None
#
# 	AGSF = None
#
# 	logger_name = "tuto_multi.Force"
# 	Rag = None
# 	meshsolution = None
#
# loss = parent = <class 'pyleecan.Classes.Output.Output'> object
# 	loss_list = None
#
# 	meshsol_list = []
# 	loss_index = {}
# 	logger_name = "Pyleecan.Loss"
#
# Xout_vop.xoutput_ref_index:None

# %% [markdown]
# output_list, xoutput_dict and the respective plot commands work the same way as for VarLoadCurrent. The ParamExplorer are also available for plot_multi:

# %%
Xout_sweep.plot_multi("W0s","Tem_av")
# Out:
# c:\Users\KDH2018-PC\anaconda3\envs\py38_pyleecan_v1\lib\site-packages\SciDataTool\Functions\Plot\plot_2D.py:443: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# As a reminder, each output contains the simulation that computed it. Using Parameter sweep with is_keep_all_output enables to access each generated simulation and machine in the output_list. The following code will extract the machine with the highest torque. To get the corresponding W0s, the ParamExplorerInterval was converted to a ParamExplorerSet to store the actual values used during the simulation.

# %%
from numpy import argmax, max as np_max
# Find the simulation with the most torque
Tmax = np_max(Xout_sweep.xoutput_dict["Tem_av"].result)
Tmax_id = int(argmax(Xout_sweep.xoutput_dict["Tem_av"].result))
print("Max Torque is "+str(Tmax)+" [N.m], for simulation index "+str(Tmax_id))

# Find the corresponding W0s
print(type(Xout_sweep.paramexplorer_list[0]))
W0s_val = Xout_sweep.paramexplorer_list[0].get_value()
print(W0s_val)

print("Corresponding W0s is " + str(W0s_val[Tmax_id]))

# To save the simulation or machine for further modifications/computations
# Xout_sweep.output_list[Tmax_id].simu.save(path/to/json/file)
# Xout_sweep.output_list[Tmax_id].simu.machine.save(path/to/json/file)
# Out:
# Max Torque is 354.6024461757492 [N.m], for simulation index 7
# <class 'pyleecan.Classes.ParamExplorerSet.ParamExplorerSet'>
# [0.00019300000000000003, 0.0005514285714285714, 0.0009098571428571429, 0.0012682857142857144, 0.0016267142857142858, 0.001985142857142857, 0.002343571428571429, 0.002702]
# Corresponding W0s is 0.002702

# %% [markdown]
# It is also possible to access the machine plot command to check the modifications:

# %%
Xout_sweep.output_list[0].simu.machine.stator.slot.plot()
Xout_sweep.xoutput_ref.simu.machine.stator.slot.plot()
Xout_sweep.output_list[-1].simu.machine.stator.slot.plot()
# Out:
# <img src="data:image/png;base64,..." width="724.3333333333334">
# <img src="data:image/png;base64,..." width="724.3333333333334">
# <img src="data:image/png;base64,..." width="724.3333333333334">

# %% [markdown]
# ## Both multi-simulation layers: Parameter-sweep of variable speed simulation

# %% [markdown]
# For now, we have set the var_simu property of Simulation with a VarSimu object to define a multi-simulation. To define a multi-simulation of multi-simulation, we can use the var_simu property of VarSimu which also take a VarSimu object. This definition principal has no limit in the number of "simulation layer" but no usage should require more than two layers.

# %%
multi_simu = simu_ref.copy()
multi_simu.var_simu = sweep.copy()
multi_simu.var_simu.var_simu = varload.copy()

# %% [markdown]
# The workflow of this simulation is the following:
# - Pyleecan checks simu.var_simu => VarParam.run
# - VarParam defines its reference simulation with simu.var_simu = simu.var_simu.var_simu
# - VarParam run its referencece simulation, check simu.var_simu => VarLoadCurrent.run
# - The reference simulation of VarParam is a VarLoadCurrent simulation that defines its own reference simulation with simu.var_simu = simu.var_simu.var_simu (which is None)
# - When running the reference simulation of VarLoadCurrent, simu.var_simu is None so we run the models (this simulation is then exaclty simu_ref defined previously)
# - Pyleecan run the N_speed simulations of the VarLoadCurrent
# - Pyleecan generates the N_sweep simulations of the VarParam which are VarLoadCurrent and run them all
# - For each VarLoadCurrent simulation, a reference simulation is defined then the N_speed simulations
#
# So this simulation will run (1+N_sweep) * (1+N_speed) simulations. This is why it is important to make sure that the reference simulation is part of the N simulations to skip one computation on both sides.
#
# Each simulation layer has its own properties which enables to do the following:

# %%
# VarParam => All machine are different
multi_simu.var_simu.is_reuse_femm_file = False
# VarLoadCurrent => All machines are the same
multi_simu.var_simu.var_simu.is_reuse_femm_file = True

# %% [markdown]
# To explain the output structure, this tutorial will again use the is_keep_all_output option. To speed up the computation and reduce the memory usage the number of simulation is reduced:

# %%
# VarParam
multi_simu.var_simu.is_keep_all_output = True
multi_simu.var_simu.datakeeper_list = list()  # reset datakeeper list
multi_simu.var_simu.paramexplorer_list[0].N = 4
multi_simu.var_simu.paramexplorer_list[0].max_value = Toyota_Prius.stator.slot.W0  # Ref is in the N simu
# VarLoadCurrent
multi_simu.var_simu.var_simu.is_keep_all_output = True
multi_simu.var_simu.var_simu.datakeeper_list = list()  # reset datakeeper list
multi_simu.var_simu.var_simu.OP_matrix = OP_matrix[:-4, :]
print("OP matrix")
print(multi_simu.var_simu.var_simu.OP_matrix)
# Reference simulation
multi_simu.input.Nt_tot = 64
# Out:
# OP matrix
# [[2.00000000e+03 1.76776695e+02 1.04719755e+00 7.90000000e+01]
#  [2.00000000e+03 1.76776695e+02 1.22173048e+00 1.25000000e+02]
#  [2.00000000e+03 1.76776695e+02 1.39626340e+00 1.60000000e+02]
#  [2.00000000e+03 1.76776695e+02 1.57079633e+00 1.92000000e+02]
#  [2.00000000e+03 1.76776695e+02 1.74532925e+00 2.37000000e+02]
#  [2.00000000e+03 1.76776695e+02 1.91986218e+00 2.81000000e+02]
#  [2.00000000e+03 1.76776695e+02 2.09439510e+00 3.19000000e+02]
#  [2.00000000e+03 1.76776695e+02 2.26892803e+00 3.43000000e+02]
#  [2.00000000e+03 1.76776695e+02 2.44346095e+00 3.53000000e+02]]

# %% [markdown]
# For a better understanding of the logs, the VarLoadCurrent simulation log can be filtered with:

# %%
multi_simu.layer_log_warn = 2

# %%
Xout_multi = multi_simu.run()
# Out:
# [16:52:52] Starting running simulation tuto_multi (machine=Toyota_Prius)
# [16:52:52] Computing reference simulation for Parameter Sweep
# [16:52:52] W0s: 4 values from 0.000193 to 0.00193 (ref=0.00193) [m]
# [16:52:52] Reference Operating point is not in OP_matrix, one extra simulation will be computed
# [16:52:52]     Computing reference simulation for Variable Load
# [16:53:06]     Variable Load Reference Results: N0=2000 [rpm], Id=-135.4 [Arms], Iq=113.6 [Arms], I0=176.8 [A], Phi0=2.443 [], Tem_av_ref=None [N.m], Tem_av=353.8 [N.m], Tem_rip_pp=76.83 [N.m], Tem_rip_norm=0.2171 [-], Pem_av=7.41e+04 [W]
#                [=====                                             ]  10%
# [16:53:06]     Variable Load: Using same FEMM file for all simulation (D:\GitHub\pyleecan-public\pyleecan\Results\tuto_multi\Femm\Toyota_Prius_model.fem)
# [16:53:06]     Running simulation 1/9 with N0=2000 [rpm], Id=88.39 [Arms], Iq=153.1 [Arms]
# [16:53:19]     Variable Load Results: N0=2000 [rpm], Id=88.39 [Arms], Iq=153.1 [Arms], I0=176.8 [A], Phi0=1.047 [], Tem_av_ref=None [N.m], Tem_av=82.94 [N.m], Tem_rip_pp=24.08 [N.m], Tem_rip_norm=0.2904 [-], Pem_av=1.737e+04 [W]
#                [==========                                        ]  20%
# [16:53:19]     Running simulation 2/9 with N0=2000 [rpm], Id=60.46 [Arms], Iq=166.1 [Arms]
# [16:53:29]     Variable Load Results: N0=2000 [rpm], Id=60.46 [Arms], Iq=166.1 [Arms], I0=176.8 [A], Phi0=1.222 [], Tem_av_ref=None [N.m], Tem_av=126.7 [N.m], Tem_rip_pp=38.78 [N.m], Tem_rip_norm=0.306 [-], Pem_av=2.654e+04 [W]
#                [===============                                   ]  30%
# [16:53:29]     Running simulation 3/9 with N0=2000 [rpm], Id=30.7 [Arms], Iq=174.1 [Arms]
# [16:53:40]     Variable Load Results: N0=2000 [rpm], Id=30.7 [Arms], Iq=174.1 [Arms], I0=176.8 [A], Phi0=1.396 [], Tem_av_ref=None [N.m], Tem_av=171.5 [N.m], Tem_rip_pp=52.62 [N.m], Tem_rip_norm=0.3068 [-], Pem_av=3.592e+04 [W]
#                [====================                              ]  40%
# [16:53:40]     Running simulation 4/9 with N0=2000 [rpm], Id=0 [Arms], Iq=176.8 [Arms]
# [16:53:53]     Variable Load Results: N0=2000 [rpm], Id=0 [Arms], Iq=176.8 [Arms], I0=176.8 [A], Phi0=1.571 [], Tem_av_ref=None [N.m], Tem_av=215.5 [N.m], Tem_rip_pp=49.22 [N.m], Tem_rip_norm=0.2284 [-], Pem_av=4.513e+04 [W]
#                [=========================                         ]  50%
# [16:53:53]     Running simulation 5/9 with N0=2000 [rpm], Id=-30.7 [Arms], Iq=174.1 [Arms]
# [16:54:02]     Variable Load Results: N0=2000 [rpm], Id=-30.7 [Arms], Iq=174.1 [Arms], I0=176.8 [A], Phi0=1.745 [], Tem_av_ref=None [N.m], Tem_av=256.7 [N.m], Tem_rip_pp=54.29 [N.m], Tem_rip_norm=0.2114 [-], Pem_av=5.377e+04 [W]
#                [==============================                    ]  60%
# [16:54:02]     Running simulation 6/9 with N0=2000 [rpm], Id=-60.46 [Arms], Iq=166.1 [Arms]
# [16:54:11]     Variable Load Results: N0=2000 [rpm], Id=-60.46 [Arms], Iq=166.1 [Arms], I0=176.8 [A], Phi0=1.92 [], Tem_av_ref=None [N.m], Tem_av=293.5 [N.m], Tem_rip_pp=69.27 [N.m], Tem_rip_norm=0.236 [-], Pem_av=6.147e+04 [W]
#                [===================================               ]  70%
# [16:54:11]     Running simulation 7/9 with N0=2000 [rpm], Id=-88.39 [Arms], Iq=153.1 [Arms]
# [16:54:20]     Variable Load Results: N0=2000 [rpm], Id=-88.39 [Arms], Iq=153.1 [Arms], I0=176.8 [A], Phi0=2.094 [], Tem_av_ref=None [N.m], Tem_av=324 [N.m], Tem_rip_pp=80.18 [N.m], Tem_rip_norm=0.2475 [-], Pem_av=6.785e+04 [W]
#                [========================================          ]  80%
# [16:54:20]     Running simulation 8/9 with N0=2000 [rpm], Id=-113.6 [Arms], Iq=135.4 [Arms]
# [16:54:30]     Variable Load Results: N0=2000 [rpm], Id=-113.6 [Arms], Iq=135.4 [Arms], I0=176.8 [A], Phi0=2.269 [], Tem_av_ref=None [N.m], Tem_av=345.5 [N.m], Tem_rip_pp=84.44 [N.m], Tem_rip_norm=0.2444 [-], Pem_av=7.237e+04 [W]
#                [=============================================     ]  90%
# [16:54:30]     Running simulation 9/9 with N0=2000 [rpm], Id=-135.4 [Arms], Iq=113.6 [Arms]
# [16:54:39]     Variable Load Results: N0=2000 [rpm], Id=-135.4 [Arms], Iq=113.6 [Arms], I0=176.8 [A], Phi0=2.443 [], Tem_av_ref=None [N.m], Tem_av=353.8 [N.m], Tem_rip_pp=76.83 [N.m], Tem_rip_norm=0.2171 [-], Pem_av=7.41e+04 [W]
#                [==================================================] 100%
# [16:54:39] Parameter Sweep Reference Results: Max_Tem_av=353.8 [N.m], Max_Tem_rip_pp=84.44 [N.m], Max_Tem_rip_norm=0.3068 [-]
# [==========                                        ]  20%
# [16:54:39] Running simulation 1/4 with W0s=0.000193
# [16:54:39] Reference Operating point is not in OP_matrix, one extra simulation will be computed
# [16:54:39]     Computing reference simulation for Variable Load
# [16:54:50]     Variable Load Reference Results: N0=2000 [rpm], Id=-135.4 [Arms], Iq=113.6 [Arms], I0=176.8 [A], Phi0=2.443 [], Tem_av_ref=None [N.m], Tem_av=345 [N.m], Tem_rip_pp=81.17 [N.m], Tem_rip_norm=0.2353 [-], Pem_av=7.226e+04 [W]
#                [=====                                             ]  10%
# [16:54:50]     Variable Load: Using same FEMM file for all simulation (D:\GitHub\pyleecan-public\pyleecan\Results\tuto_multi\Femm\Toyota_Prius_model.fem)
# [16:54:50]     Running simulation 1/9 with N0=2000 [rpm], Id=88.39 [Arms], Iq=153.1 [Arms]
# [16:54:59]     Variable Load Results: N0=2000 [rpm], Id=88.39 [Arms], Iq=153.1 [Arms], I0=176.8 [A], Phi0=1.047 [], Tem_av_ref=None [N.m], Tem_av=80.95 [N.m], Tem_rip_pp=25.42 [N.m], Tem_rip_norm=0.314 [-], Pem_av=1.695e+04 [W]
#                [==========                                        ]  20%
# [16:54:59]     Running simulation 2/9 with N0=2000 [rpm], Id=60.46 [Arms], Iq=166.1 [Arms]
# [16:55:07]     Variable Load Results: N0=2000 [rpm], Id=60.46 [Arms], Iq=166.1 [Arms], I0=176.8 [A], Phi0=1.222 [], Tem_av_ref=None [N.m], Tem_av=123.6 [N.m], Tem_rip_pp=30.63 [N.m], Tem_rip_norm=0.2479 [-], Pem_av=2.588e+04 [W]
#                [===============                                   ]  30%
# [16:55:07]     Running simulation 3/9 with N0=2000 [rpm], Id=30.7 [Arms], Iq=174.1 [Arms]
# [16:55:15]     Variable Load Results: N0=2000 [rpm], Id=30.7 [Arms], Iq=174.1 [Arms], I0=176.8 [A], Phi0=1.396 [], Tem_av_ref=None [N.m], Tem_av=167.4 [N.m], Tem_rip_pp=41.58 [N.m], Tem_rip_norm=0.2484 [-], Pem_av=3.506e+04 [W]
#                [====================                              ]  40%
# [16:55:15]     Running simulation 4/9 with N0=2000 [rpm], Id=0 [Arms], Iq=176.8 [Arms]
# [16:55:22]     Variable Load Results: N0=2000 [rpm], Id=0 [Arms], Iq=176.8 [Arms], I0=176.8 [A], Phi0=1.571 [], Tem_av_ref=None [N.m], Tem_av=210.7 [N.m], Tem_rip_pp=37.48 [N.m], Tem_rip_norm=0.1779 [-], Pem_av=4.412e+04 [W]
#                [=========================                         ]  50%
# [16:55:22]     Running simulation 5/9 with N0=2000 [rpm], Id=-30.7 [Arms], Iq=174.1 [Arms]
# [16:55:30]     Variable Load Results: N0=2000 [rpm], Id=-30.7 [Arms], Iq=174.1 [Arms], I0=176.8 [A], Phi0=1.745 [], Tem_av_ref=None [N.m], Tem_av=251.3 [N.m], Tem_rip_pp=45.9 [N.m], Tem_rip_norm=0.1826 [-], Pem_av=5.264e+04 [W]
#                [==============================                    ]  60%
# [16:55:30]     Running simulation 6/9 with N0=2000 [rpm], Id=-60.46 [Arms], Iq=166.1 [Arms]
# [16:55:37]     Variable Load Results: N0=2000 [rpm], Id=-60.46 [Arms], Iq=166.1 [Arms], I0=176.8 [A], Phi0=1.92 [], Tem_av_ref=None [N.m], Tem_av=287.3 [N.m], Tem_rip_pp=64.21 [N.m], Tem_rip_norm=0.2235 [-], Pem_av=6.016e+04 [W]
#                [===================================               ]  70%
# [16:55:37]     Running simulation 7/9 with N0=2000 [rpm], Id=-88.39 [Arms], Iq=153.1 [Arms]
# [16:55:44]     Variable Load Results: N0=2000 [rpm], Id=-88.39 [Arms], Iq=153.1 [Arms], I0=176.8 [A], Phi0=2.094 [], Tem_av_ref=None [N.m], Tem_av=316.8 [N.m], Tem_rip_pp=79.74 [N.m], Tem_rip_norm=0.2517 [-], Pem_av=6.635e+04 [W]
#                [========================================          ]  80%
# [16:55:44]     Running simulation 8/9 with N0=2000 [rpm], Id=-113.6 [Arms], Iq=135.4 [Arms]
# [16:55:51]     Variable Load Results: N0=2000 [rpm], Id=-113.6 [Arms], Iq=135.4 [Arms], I0=176.8 [A], Phi0=2.269 [], Tem_av_ref=None [N.m], Tem_av=337.7 [N.m], Tem_rip_pp=91.1 [N.m], Tem_rip_norm=0.2698 [-], Pem_av=7.072e+04 [W]
#                [=============================================     ]  90%
# [16:55:51]     Running simulation 9/9 with N0=2000 [rpm], Id=-135.4 [Arms], Iq=113.6 [Arms]
# [16:55:59]     Variable Load Results: N0=2000 [rpm], Id=-135.4 [Arms], Iq=113.6 [Arms], I0=176.8 [A], Phi0=2.443 [], Tem_av_ref=None [N.m], Tem_av=345 [N.m], Tem_rip_pp=81.17 [N.m], Tem_rip_norm=0.2353 [-], Pem_av=7.226e+04 [W]
#                [==================================================] 100%
# [16:55:59] Parameter Sweep Results: Max_Tem_av=345 [N.m], Max_Tem_rip_pp=91.1 [N.m], Max_Tem_rip_norm=0.314 [-]
# [====================                              ]  40%
# [16:55:59] Running simulation 2/4 with W0s=0.000772
# [16:56:00] Reference Operating point is not in OP_matrix, one extra simulation will be computed
# [16:56:00]     Computing reference simulation for Variable Load
# [16:56:09]     Variable Load Reference Results: N0=2000 [rpm], Id=-135.4 [Arms], Iq=113.6 [Arms], I0=176.8 [A], Phi0=2.443 [], Tem_av_ref=None [N.m], Tem_av=349.8 [N.m], Tem_rip_pp=77.97 [N.m], Tem_rip_norm=0.2229 [-], Pem_av=7.325e+04 [W]
#                [=====                                             ]  10%
# [16:56:09]     Variable Load: Using same FEMM file for all simulation (D:\GitHub\pyleecan-public\pyleecan\Results\tuto_multi\Femm\Toyota_Prius_model.fem)
# [16:56:09]     Running simulation 1/9 with N0=2000 [rpm], Id=88.39 [Arms], Iq=153.1 [Arms]
# [16:56:16]     Variable Load Results: N0=2000 [rpm], Id=88.39 [Arms], Iq=153.1 [Arms], I0=176.8 [A], Phi0=1.047 [], Tem_av_ref=None [N.m], Tem_av=81.94 [N.m], Tem_rip_pp=25.13 [N.m], Tem_rip_norm=0.3067 [-], Pem_av=1.716e+04 [W]
#                [==========                                        ]  20%
# [16:56:16]     Running simulation 2/9 with N0=2000 [rpm], Id=60.46 [Arms], Iq=166.1 [Arms]
# [16:56:22]     Variable Load Results: N0=2000 [rpm], Id=60.46 [Arms], Iq=166.1 [Arms], I0=176.8 [A], Phi0=1.222 [], Tem_av_ref=None [N.m], Tem_av=125.4 [N.m], Tem_rip_pp=34.52 [N.m], Tem_rip_norm=0.2754 [-], Pem_av=2.625e+04 [W]
#                [===============                                   ]  30%
# [16:56:22]     Running simulation 3/9 with N0=2000 [rpm], Id=30.7 [Arms], Iq=174.1 [Arms]
# [16:56:32]     Variable Load Results: N0=2000 [rpm], Id=30.7 [Arms], Iq=174.1 [Arms], I0=176.8 [A], Phi0=1.396 [], Tem_av_ref=None [N.m], Tem_av=169.8 [N.m], Tem_rip_pp=46.65 [N.m], Tem_rip_norm=0.2747 [-], Pem_av=3.556e+04 [W]
#                [====================                              ]  40%
# [16:56:32]     Running simulation 4/9 with N0=2000 [rpm], Id=0 [Arms], Iq=176.8 [Arms]
# [16:56:39]     Variable Load Results: N0=2000 [rpm], Id=0 [Arms], Iq=176.8 [Arms], I0=176.8 [A], Phi0=1.571 [], Tem_av_ref=None [N.m], Tem_av=213.5 [N.m], Tem_rip_pp=41.4 [N.m], Tem_rip_norm=0.1939 [-], Pem_av=4.472e+04 [W]
#                [=========================                         ]  50%
# [16:56:39]     Running simulation 5/9 with N0=2000 [rpm], Id=-30.7 [Arms], Iq=174.1 [Arms]
# [16:56:47]     Variable Load Results: N0=2000 [rpm], Id=-30.7 [Arms], Iq=174.1 [Arms], I0=176.8 [A], Phi0=1.745 [], Tem_av_ref=None [N.m], Tem_av=254.5 [N.m], Tem_rip_pp=46.88 [N.m], Tem_rip_norm=0.1842 [-], Pem_av=5.33e+04 [W]
#                [==============================                    ]  60%
# [16:56:47]     Running simulation 6/9 with N0=2000 [rpm], Id=-60.46 [Arms], Iq=166.1 [Arms]
# [16:56:54]     Variable Load Results: N0=2000 [rpm], Id=-60.46 [Arms], Iq=166.1 [Arms], I0=176.8 [A], Phi0=1.92 [], Tem_av_ref=None [N.m], Tem_av=290.7 [N.m], Tem_rip_pp=63.4 [N.m], Tem_rip_norm=0.2181 [-], Pem_av=6.089e+04 [W]
#                [===================================               ]  70%
# [16:56:54]     Running simulation 7/9 with N0=2000 [rpm], Id=-88.39 [Arms], Iq=153.1 [Arms]
# [16:57:02]     Variable Load Results: N0=2000 [rpm], Id=-88.39 [Arms], Iq=153.1 [Arms], I0=176.8 [A], Phi0=2.094 [], Tem_av_ref=None [N.m], Tem_av=320.8 [N.m], Tem_rip_pp=79.23 [N.m], Tem_rip_norm=0.247 [-], Pem_av=6.718e+04 [W]
#                [========================================          ]  80%
# [16:57:02]     Running simulation 8/9 with N0=2000 [rpm], Id=-113.6 [Arms], Iq=135.4 [Arms]
# [16:57:11]     Variable Load Results: N0=2000 [rpm], Id=-113.6 [Arms], Iq=135.4 [Arms], I0=176.8 [A], Phi0=2.269 [], Tem_av_ref=None [N.m], Tem_av=342 [N.m], Tem_rip_pp=87.54 [N.m], Tem_rip_norm=0.256 [-], Pem_av=7.162e+04 [W]
#                [=============================================     ]  90%
# [16:57:11]     Running simulation 9/9 with N0=2000 [rpm], Id=-135.4 [Arms], Iq=113.6 [Arms]
# [16:57:19]     Variable Load Results: N0=2000 [rpm], Id=-135.4 [Arms], Iq=113.6 [Arms], I0=176.8 [A], Phi0=2.443 [], Tem_av_ref=None [N.m], Tem_av=349.8 [N.m], Tem_rip_pp=77.97 [N.m], Tem_rip_norm=0.2229 [-], Pem_av=7.325e+04 [W]
#                [==================================================] 100%
# [16:57:19] Parameter Sweep Results: Max_Tem_av=349.8 [N.m], Max_Tem_rip_pp=87.54 [N.m], Max_Tem_rip_norm=0.3067 [-]
# [==============================                    ]  60%
# [16:57:19] Running simulation 3/4 with W0s=0.001351
# [16:57:19] Reference Operating point is not in OP_matrix, one extra simulation will be computed
# [16:57:19]     Computing reference simulation for Variable Load
# [16:57:28]     Variable Load Reference Results: N0=2000 [rpm], Id=-135.4 [Arms], Iq=113.6 [Arms], I0=176.8 [A], Phi0=2.443 [], Tem_av_ref=None [N.m], Tem_av=352.2 [N.m], Tem_rip_pp=75.73 [N.m], Tem_rip_norm=0.215 [-], Pem_av=7.377e+04 [W]
#                [=====                                             ]  10%
# [16:57:28]     Variable Load: Using same FEMM file for all simulation (D:\GitHub\pyleecan-public\pyleecan\Results\tuto_multi\Femm\Toyota_Prius_model.fem)
# [16:57:28]     Running simulation 1/9 with N0=2000 [rpm], Id=88.39 [Arms], Iq=153.1 [Arms]
# [16:57:35]     Variable Load Results: N0=2000 [rpm], Id=88.39 [Arms], Iq=153.1 [Arms], I0=176.8 [A], Phi0=1.047 [], Tem_av_ref=None [N.m], Tem_av=82.41 [N.m], Tem_rip_pp=25.07 [N.m], Tem_rip_norm=0.3043 [-], Pem_av=1.726e+04 [W]
#                [==========                                        ]  20%
# [16:57:35]     Running simulation 2/9 with N0=2000 [rpm], Id=60.46 [Arms], Iq=166.1 [Arms]
# [16:57:42]     Variable Load Results: N0=2000 [rpm], Id=60.46 [Arms], Iq=166.1 [Arms], I0=176.8 [A], Phi0=1.222 [], Tem_av_ref=None [N.m], Tem_av=126 [N.m], Tem_rip_pp=37.13 [N.m], Tem_rip_norm=0.2946 [-], Pem_av=2.64e+04 [W]
#                [===============                                   ]  30%
# [16:57:42]     Running simulation 3/9 with N0=2000 [rpm], Id=30.7 [Arms], Iq=174.1 [Arms]
# [16:57:49]     Variable Load Results: N0=2000 [rpm], Id=30.7 [Arms], Iq=174.1 [Arms], I0=176.8 [A], Phi0=1.396 [], Tem_av_ref=None [N.m], Tem_av=170.7 [N.m], Tem_rip_pp=50.56 [N.m], Tem_rip_norm=0.2961 [-], Pem_av=3.576e+04 [W]
#                [====================                              ]  40%
# [16:57:49]     Running simulation 4/9 with N0=2000 [rpm], Id=0 [Arms], Iq=176.8 [Arms]
# [16:57:56]     Variable Load Results: N0=2000 [rpm], Id=0 [Arms], Iq=176.8 [Arms], I0=176.8 [A], Phi0=1.571 [], Tem_av_ref=None [N.m], Tem_av=214.7 [N.m], Tem_rip_pp=45.87 [N.m], Tem_rip_norm=0.2137 [-], Pem_av=4.496e+04 [W]
#                [=========================                         ]  50%
# [16:57:56]     Running simulation 5/9 with N0=2000 [rpm], Id=-30.7 [Arms], Iq=174.1 [Arms]
# [16:58:05]     Variable Load Results: N0=2000 [rpm], Id=-30.7 [Arms], Iq=174.1 [Arms], I0=176.8 [A], Phi0=1.745 [], Tem_av_ref=None [N.m], Tem_av=255.8 [N.m], Tem_rip_pp=50.91 [N.m], Tem_rip_norm=0.199 [-], Pem_av=5.358e+04 [W]
#                [==============================                    ]  60%
# [16:58:05]     Running simulation 6/9 with N0=2000 [rpm], Id=-60.46 [Arms], Iq=166.1 [Arms]
# [16:58:14]     Variable Load Results: N0=2000 [rpm], Id=-60.46 [Arms], Iq=166.1 [Arms], I0=176.8 [A], Phi0=1.92 [], Tem_av_ref=None [N.m], Tem_av=292.4 [N.m], Tem_rip_pp=66.79 [N.m], Tem_rip_norm=0.2284 [-], Pem_av=6.124e+04 [W]
#                [===================================               ]  70%
# [16:58:14]     Running simulation 7/9 with N0=2000 [rpm], Id=-88.39 [Arms], Iq=153.1 [Arms]
# [16:58:24]     Variable Load Results: N0=2000 [rpm], Id=-88.39 [Arms], Iq=153.1 [Arms], I0=176.8 [A], Phi0=2.094 [], Tem_av_ref=None [N.m], Tem_av=322.7 [N.m], Tem_rip_pp=80.13 [N.m], Tem_rip_norm=0.2483 [-], Pem_av=6.758e+04 [W]
#                [========================================          ]  80%
# [16:58:24]     Running simulation 8/9 with N0=2000 [rpm], Id=-113.6 [Arms], Iq=135.4 [Arms]
# [16:58:33]     Variable Load Results: N0=2000 [rpm], Id=-113.6 [Arms], Iq=135.4 [Arms], I0=176.8 [A], Phi0=2.269 [], Tem_av_ref=None [N.m], Tem_av=344.1 [N.m], Tem_rip_pp=85.27 [N.m], Tem_rip_norm=0.2478 [-], Pem_av=7.207e+04 [W]
#                [=============================================     ]  90%
# [16:58:33]     Running simulation 9/9 with N0=2000 [rpm], Id=-135.4 [Arms], Iq=113.6 [Arms]
# [16:58:41]     Variable Load Results: N0=2000 [rpm], Id=-135.4 [Arms], Iq=113.6 [Arms], I0=176.8 [A], Phi0=2.443 [], Tem_av_ref=None [N.m], Tem_av=352.2 [N.m], Tem_rip_pp=75.73 [N.m], Tem_rip_norm=0.215 [-], Pem_av=7.377e+04 [W]
#                [==================================================] 100%
# [16:58:41] Parameter Sweep Results: Max_Tem_av=352.2 [N.m], Max_Tem_rip_pp=85.27 [N.m], Max_Tem_rip_norm=0.3043 [-]
# [========================================          ]  80%
# [16:58:41] Running simulation 4/4 with W0s=0.00193
# [16:58:41] Simulation matches reference one: Skipping computation
# [16:58:41] Parameter Sweep Results: Max_Tem_av=353.8 [N.m], Max_Tem_rip_pp=84.44 [N.m], Max_Tem_rip_norm=0.3068 [-]
# [==================================================] 100%
# [16:58:41] End of simulation tuto_multi

# %% [markdown]
# Again, the logs enable to follow step by step each layer of the simulation with their corresponding input and output.
# The datakeeper of the VarLoadCurrent are the same as previously:
# **Variable Load Results: N0=2000 [rpm], Id=-135.4 [Arms], Iq=113.6 [Arms], I0=176.8 [A], Phi0=2.443 [], Tem_av_ref=353 [N.m], Tem_av=353.3 [N.m], Tem_rip_pp=73.53 [N.m], Tem_rip_norm=0.2081 [-]**
#
# But the VarParam Datakeeper are now:
#
# **Parameter Sweep Results: Max_Tem_av=345 [N.m], Max_Tem_rip_pp=90.72 [N.m], Max_Tem_rip_norm=0.3105 [-]**
#
# The reason is that now the parameter sweep is running on a multi-simulation. Thus, Tem_av is now an array as a function of the operating point. So instead of storing Tem_av, the datakeeper now store the maximum of the Tem_av DataKeeper of the VarLoadCurrent simulation ("max(output.xoutput_dict['Tem_av'].result)")
#
# The xoutput_dict contains only the information related to the VarParm:

# %%
print("Values available in XOutput:")
print(Xout_multi.xoutput_dict.keys())

print("\nMaximum Torque for each Design:")
print(Xout_multi.xoutput_dict["Max_Tem_av"].result)
print("W0s for each Design:")
print(Xout_multi.paramexplorer_list[0].get_value())

Xout_multi.plot_multi("W0s", "Max_Tem_av")
# Out:
# Values available in XOutput:
# dict_keys(['Max_Tem_av', 'Max_Tem_rip_pp', 'Max_Tem_rip_norm'])
#
# Maximum Torque for each Design:
# [345.0304985573581, 349.7642780183083, 352.22143610291545, 353.80472945261613]
# W0s for each Design:
# [0.00019300000000000003, 0.000772, 0.001351, 0.00193]
# <img src="data:image/png;base64,..." width="905.4166666666667">

# %%
Xout_multi.xoutput_dict["Max_Tem_av"].result
# Out:
# [345.0304985573581, 349.7642780183083, 352.22143610291545, 353.80472945261613]

# %% [markdown]
# As the is_keep_all_output option was activated, output_list is available but now it contains the xouput resulting from the VarLoadCurrent computation. Then all the VarLoadCurrent DataKeeper are available.

# %%
print(type(Xout_multi.output_list[0]))
print(type(Xout_sweep.output_list[0]))

print("\nDatakeeper of VarLoadCurrent simulation of Design 0")
print(Xout_multi.output_list[0].xoutput_dict.keys())
print("Average torque for each operating point of Design 0")
print(Xout_multi.output_list[0].xoutput_dict["Tem_av"].result)

# To save the VarLoadCurrent simulation or machine for further modifications/computations
# Xout_multi.output_list[0].simu.save(path/to/json/file)
# Xout_multi.output_list[0].simu.machine.save(path/to/json/file)
# Out:
# <class 'pyleecan.Classes.XOutput.XOutput'>
# <class 'pyleecan.Classes.Output.Output'>
#
# Datakeeper of VarLoadCurrent simulation of Design 0
# dict_keys(['N0', 'Id', 'Iq', 'I0', 'Phi0', 'Tem_av_ref', 'Tem_av', 'Tem_rip_pp', 'Tem_rip_norm', 'Pem_av'])
# Average torque for each operating point of Design 0
# [80.94610281890381, 123.5638043502944, 167.40952551307998, 210.67150583907878, 251.3183718014907, 287.2531533915088, 316.82132486878527, 337.65567569144696, 345.0304985573581]

# %% [markdown]
# As the VarLoadCurrent also have the is_keep_all_output option activated, the output of each simulation is available and  it is possible to call the corresponding plot command

# %%
Xout_multi.output_list[-1].plot_multi("Phi0", "Tem_av")
# Torque at the first Operating point for the Last design
Xout_multi.output_list[-1].output_list[0].mag.Tem.plot_2D_Data("time")
# Flux of the 4th Operating point for the Last design
Xout_multi.output_list[-1].output_list[3].mag.B.plot_2D_Data("angle")
# Out:
# <img src="data:image/png;base64,..." width="905.4166666666667">
# <img src="data:image/png;base64,..." width="905.4166666666667">
# <img src="data:image/png;base64,..." width="905.4166666666667">
# <img src="data:image/png;base64,..." width="905.4166666666667">
